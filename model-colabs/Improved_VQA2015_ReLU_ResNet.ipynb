# %%
import os
import time
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms
from torchsummary import summary

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
from torch.utils.data import Dataset, TensorDataset, ChainDataset, DataLoader
from sklearn.feature_extraction.text import CountVectorizer

# %%
device = torch.device('cuda')
print(device)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
if not os.path.exists('annotation_map.save'):
    # !unzip '/content/gdrive/My Drive/aidl/r50_embeddings.zip'
# Out:
# Archive:  /content/gdrive/My Drive/aidl/r50_embeddings.zip
#   inflating: annotation_map.save
#   inflating: image_embeddings_train.save
#   inflating: question_embeddings_train.save
#   inflating: annotations_train.save
#   inflating: metadatas_train.save
#   inflating: image_embeddings_test.save
#   inflating: question_embeddings_test.save
#   inflating: annotations_test.save
#   inflating: metadatas_test.save

# %%
dataset_root = "/content"
answer2idx = torch.load(os.path.join(dataset_root,'annotation_map.save'))
idx2answer = { idx: answer for answer, idx in answer2idx.items() }

# %%
image_embeddings_train = torch.load(os.path.join(dataset_root,'image_embeddings_train.save'))
#question_embeddings_train = torch.load(os.path.join(dataset_root,'question_embeddings_train.save'))
annotations_train = torch.load(os.path.join(dataset_root,'annotations_train.save'))

# %%
image_embeddings_test = torch.load(os.path.join(dataset_root,'image_embeddings_test.save'))
#question_embeddings_test = torch.load(os.path.join(dataset_root,'question_embeddings_test.save'))
annotations_test = torch.load(os.path.join(dataset_root,'annotations_test.save'))

# %%
metadatas_train = torch.load(os.path.join(dataset_root,'metadatas_train.save'))
df_train = pd.DataFrame(metadatas_train)
questions_train = df_train['question_text'].to_list()

metadatas_test = torch.load(os.path.join(dataset_root,'metadatas_test.save'))
df_test = pd.DataFrame(metadatas_test)
questions_test = df_test['question_text'].to_list()

# %%
countVec = CountVectorizer(stop_words=['?'],min_df=5)
countVec.fit_transform(df_train['question_text'])

word2idx = countVec.vocabulary_
idx2word = { idx: word for word, idx in word2idx.items() }

print(len(word2idx))
# Out:
# 3209

# %%
#   Create list a2mfa to reindex annotations for a fixed size classifier output (1000)

most_freq_answers = torch.load('/content/gdrive/My Drive/aidl/stats/1000w.save')
most_freq_answers_dict = { ans: answer2idx[ans] for ans in most_freq_answers }

new_idx = 0
answer2mfa = [999] * len(answer2idx)
for ans,idx in answer2idx.items():
  if ans in most_freq_answers:
    answer2mfa[idx] = new_idx
    new_idx += 1

# %%
'''
count = 0
for ans in annotations_train:
    if ans in most_freq_answers_idx:
        count +=1
print(count)
print(round(count/len(annotations_train)*100,2),'%')

OUT:
78619
86.27 %
'''
# Out:
# "\ncount = 0\nfor ans in annotations_train:\n    if ans in most_freq_answers_idx:\n        count +=1\nprint(count)\nprint(round(count/len(annotations_train)*100,2),'%')\n\nOUT:\n78619\n86.27 %\n"

# %%
'''
count = 0
for ans in annotations_test:
    if ans in most_freq_answers_idx:
        count +=1
print(count)
print(round(count/len(annotations_test)*100,2),'%')

OUT:
878
87.8 %
'''
# Out:
# "\ncount = 0\nfor ans in annotations_test:\n    if ans in most_freq_answers_idx:\n        count +=1\nprint(count)\nprint(round(count/len(annotations_test)*100,2),'%')\n\nOUT:\n878\n87.8 %\n"

# %%
class CustomDataset(Dataset):
    def __init__(self, questions, images, answers):

        assert len(questions) == len(images) & len(images) == len(answers), 'Different Lenghts!'

        self.questions = questions
        self.images = images
        self.answers = answers

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        return self.questions[idx], self.images[idx], self.answers[idx]

train_dataset = CustomDataset(image_embeddings_train,questions_train,annotations_train)
test_dataset = CustomDataset(image_embeddings_test,questions_test,annotations_test)

batch_size = 400
train_dataloader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
test_dataloader = DataLoader(test_dataset,batch_size=batch_size,shuffle=True)

# %%
class VQA2015(nn.Module):
    
    def __init__(self, embedding_dim, hidden_dim, vocab_size, image_dim, tagset_size):
        
        super(VQA2015, self).__init__()
        
        # Branca Llenguatge

        self.hidden_dim = hidden_dim
        
        self.word_embeddings = nn.Embedding(vocab_size + 1, embedding_dim, padding_idx = vocab_size)

        self.relu = nn.ReLU() # https://discuss.pytorch.org/t/torch-tanh-vs-torch-nn-functional-tanh/15897/7

        self.lstm = nn.LSTM(embedding_dim, hidden_dim,batch_first=True)

        self.txt_fcl = nn.Sequential(
            nn.Linear(2*hidden_dim, 2*hidden_dim),
            nn.ReLU()
            )
        
        # Branca Imatge (VGG16)

        self.img_fcl = nn.Sequential(
            nn.Linear(image_dim, 2*hidden_dim), 
            nn.ReLU()
            )

        # Classificador
                
        self.classificador = nn.Sequential(
            nn.Linear(2*hidden_dim, 1000),
            nn.ReLU(),
            nn.BatchNorm1d(num_features=1000),
            #nn.Dropout(),
            nn.Linear(1000, 1000),
            nn.ReLU(),
            nn.BatchNorm1d(num_features=1000),
            #nn.Dropout(),
            nn.Linear(1000, 1000),
            nn.BatchNorm1d(num_features=1000),
            nn.ReLU(),
            #nn.Dropout(),
            nn.Linear(1000, tagset_size),
          )
                
    def forward(self,sentence,image,questionLengths):

        # Question
        embeds = self.word_embeddings(sentence) # batch_size x seq_len x embedding_dim

        #embeds = self.relu(embeds) # batch_size x seq_len x embedding_dim

        embeds = pack_padded_sequence(embeds, questionLengths, batch_first=True, enforce_sorted = False)

        hidden0 = ( torch.zeros(1, batch_size, hidden_dim).to(device).detach(),
                    torch.zeros(1, batch_size, hidden_dim).to(device).detach() )

        _, hidden = self.lstm(embeds,hidden0) # ht i ct:  num_layer*num_directions x batch_size x hidden_dim

        lstm_out = torch.cat(hidden,2) # num_layer*num_directions x batch_size x 2*hidden_dim
        lstm_out = lstm_out.reshape((-1,2*self.hidden_dim)) # batch_size x 2*hidden_dim

        txt_embed = self.txt_fcl(lstm_out) # batch_size x tagset_size = vocab_size
        
        # Image
        
        img_embed = self.img_fcl(image)
        
        # Join

        txt_embed = F.normalize(txt_embed)
        img_embed = F.normalize(img_embed)
        
        txt_img_embed = txt_embed*img_embed
        tag_scores = self.classificador(txt_img_embed)
        
        return tag_scores

# %%
# Instancia Model

embedding_dim = 300
hidden_dim = 512
image_dim = 2048 # ResNet50
vocab_size = len(word2idx)
tagset_size = 1000
    
modelVQA2015 = VQA2015(embedding_dim, hidden_dim, vocab_size, image_dim,tagset_size)
modelVQA2015 = modelVQA2015.to(device)

loss_function = nn.CrossEntropyLoss(ignore_index=999)
optimizer = optim.Adam(modelVQA2015.parameters(), lr=0.001)

# %%
for i, (imageBatch, questionBatch, answerBatch) in enumerate(train_dataloader):
     break

# %%
start = time.time()

wordIndices = [ torch.tensor(countVec.transform([question]).nonzero()[-1]) for question in questionBatch ]
paddedWordIndices = pad_sequence(wordIndices,batch_first=True,padding_value=vocab_size).long()

questionLengths = torch.tensor([ len(seq) for seq in wordIndices ]).to('cpu')
paddedWordIndices = paddedWordIndices.to(device)
imageBatch = imageBatch.to(device)

tag_scores = modelVQA2015(paddedWordIndices,imageBatch,questionLengths)

targets = torch.tensor([ answer2mfa[answer] for answer in answerBatch ]).to(device)

tag_scores = torch.nn.functional.log_softmax(tag_scores,dim=1)
tag_scores = torch.argmax(tag_scores,dim=1)

hits = (tag_scores == targets) & (tag_scores != 999)

end = time.time()
print(end - start)
# Out:
# 0.22995519638061523

# %%
#torch.argmax(tag_scores,dim=1)
#tag_scores
#[idx2answer[int(ans)] for ans in answerBatch]
#[idx2answer[int(ans)] for ans in targets]
#[idx2answer[int(ans)] for ans in most_freq_answers]
#most_freq_answers
#answerBatch
#[ answer2mfa.index(idx) for idx in targets ]
#targets

# %%
# Funció per evaluar l'accuracy d'un dataset

def VQA2015_model_accuracy(eval_model,eval_dataset,eval_batch_size,eval_countVec,eval_answer2mfa, ignore=999,eval=False):

    eval_dataloader = DataLoader(eval_dataset,batch_size=eval_batch_size)

    count = 0
    total = 0

    eval_L = []

    eval_model.eval()

    with torch.no_grad():

        for i, (eval_imageBatch, eval_questionBatch, eval_answerBatch) in enumerate(eval_dataloader):

            if eval:
                if i % 10 == 0: print('Batch',i)

            # Transofrma
          
            eval_wordIndices = [ torch.tensor(eval_countVec.transform([question]).nonzero()[-1]) for question in eval_questionBatch ]
            eval_paddedWordIndices = pad_sequence(eval_wordIndices,batch_first=True,padding_value=vocab_size).long()
            eval_questionLengths = torch.tensor([ len(seq) for seq in eval_wordIndices ]).to('cpu')
          
            eval_paddedWordIndices = eval_paddedWordIndices.to(device)
            eval_imageBatch = eval_imageBatch.to(device)
          
            eval_targets = torch.tensor([ eval_answer2mfa[answer] for answer in eval_answerBatch ]).to(device)
            
            # Run our forward pass.

            eval_tag_scores = eval_model(eval_paddedWordIndices,eval_imageBatch,eval_questionLengths)

            # Compute Loss
        
            eval_loss = loss_function(eval_tag_scores, eval_targets)
            eval_L.append(float(eval_loss))

            # Compute Accuracy

            eval_tag_scores = torch.nn.functional.log_softmax(eval_tag_scores,dim=1)
            eval_tag_scores = torch.argmax(eval_tag_scores,dim=1)

            eval_hits = (eval_tag_scores == eval_targets) & (eval_tag_scores != ignore)
          
            count += eval_hits.sum().item()
            total += len(eval_answerBatch)

    return count/total, sum(eval_L)/len(eval_L)

# %%
start = time.time()

pretrain_test_accuracy, pretrain_test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
print('\nAccuracy = %5.2f%%' % (pretrain_test_accuracy*100))
print('Loss  = %5.2f' % pretrain_test_loss )

end = time.time()
print(end - start,'seconds')
# Out:
# Accuracy =  0.00%
# Loss  =  6.89
# 0.22429609298706055 seconds

# %%
def compute_batch_accuracy(tag_scores,targets,ignore=999):

  pred = torch.nn.functional.log_softmax(tag_scores,dim=1) 
  pred = torch.argmax(pred,dim=1)
  hits = (pred == targets) & (pred != ignore)
   
  return hits.sum().item()/len(pred)

# %%
# %% Train: basat en el link més algunes modificacions per adaptar-ho al cas

start = time.time()

ignore = 999

L = [] # loss

train_mean_epoch_accuracy = []
test_epoch_accuracy = []
test_epoch_loss = []

num_epochs = 100

for epoch in range(num_epochs):  # again, normally you would NOT do 300 epochs, it is toy data
    
    print('Epoch', epoch)

    modelVQA2015.train()

    hidden = ( torch.zeros(1, batch_size, hidden_dim).to(device),
               torch.zeros(1, batch_size, hidden_dim).to(device) )

    train_batch_accuracy = []

    for i, (imageBatch, questionBatch, answerBatch) in enumerate(train_dataloader):
        
        if i % 20 == 0: print('\tBatch', '%3d' % i, end = ', ')
                    
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        
        optimizer.zero_grad()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.

        wordIndices = [ torch.tensor(countVec.transform([question]).nonzero()[-1]) for question in questionBatch ]
        paddedWordIndices = pad_sequence(wordIndices,batch_first=True,padding_value=vocab_size).long()
        questionLengths = torch.tensor([ len(seq) for seq in wordIndices ]).to('cpu')
        
        paddedWordIndices = paddedWordIndices.to(device)
        imageBatch = imageBatch.to(device)
        
        # Step 3. Run our forward pass.

        tag_scores = modelVQA2015(paddedWordIndices,imageBatch,questionLengths)

        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()        
        
        targets = torch.tensor([ answer2mfa[answer] for answer in answerBatch ]).to(device)
        
        loss = loss_function(tag_scores, targets)
        
        loss.backward()
        optimizer.step()

        # Monitoritza el procés

        batch_accuracy = compute_batch_accuracy(tag_scores,targets)

        train_batch_accuracy.append(batch_accuracy)

        L.append(float(loss))

        if len(L) >= 100:
          rolling_loss = sum(L[-100:])/100
        else:
          rolling_loss = sum(L)/len(L)

        if i % 20 == 0: print('Loss =',round(float(loss),4),', Rolling Mean Loss =',round(rolling_loss,4),', Batch Accuracy =',round(100*batch_accuracy,2))

    train_mean_epoch_accuracy.append( sum(train_batch_accuracy)/len(train_batch_accuracy) )
    print('\tTrain Accuracy (mean) = ',round(100*train_mean_epoch_accuracy[-1],2))

    test_accuracy, test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
    test_epoch_accuracy.append(test_accuracy)
    test_epoch_loss.append(test_loss)
    print('\tTest Accuracy         = ',round(100*test_epoch_accuracy[-1],2))

print('')

print('Final Loss =',round(float(loss),4))
print('Final Rolling Loss =',round(float(rolling_loss),4))

print('')
final_test_accuracy, final_test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
print('Final Test Accuracy  = %5.2f%%' % (100*final_test_accuracy))

final_train_accuracy, final_train_loss = VQA2015_model_accuracy(modelVQA2015,train_dataset,batch_size,countVec,answer2mfa)
print('Final Train Accuracy = %5.2f%%' % (100*final_train_accuracy))

print('')
end = time.time()
total_time = round(end -start)
print('Running Time =', total_time//60,'min,',total_time % 60, 'sec.')
# Out:
# Epoch 0
# 	Batch   0, Loss = 6.9091 , Rolling Mean Loss = 6.9091 , Batch Accuracy = 0.0
# 	Batch  20, Loss = 3.3325 , Rolling Mean Loss = 3.6903 , Batch Accuracy = 23.25
# 	Batch  40, Loss = 2.785 , Rolling Mean Loss = 3.3915 , Batch Accuracy = 28.5
# 	Batch  60, Loss = 2.985 , Rolling Mean Loss = 3.241 , Batch Accuracy = 25.5
# 	Batch  80, Loss = 2.6716 , Rolling Mean Loss = 3.1483 , Batch Accuracy = 31.25
# 	Batch 100, Loss = 2.7978 , Rolling Mean Loss = 3.0484 , Batch Accuracy = 28.75
# 	Batch 120, Loss = 2.5368 , Rolling Mean Loss = 2.8772 , Batch Accuracy = 29.25
# 	Batch 140, Loss = 2.7099 , Rolling Mean Loss = 2.7758 , Batch Accuracy = 32.25
# 	Batch 160, Loss = 2.4907 , Rolling Mean Loss = 2.7026 , Batch Accuracy = 31.75
# 	Batch 180, Loss = 2.2519 , Rolling Mean Loss = 2.626 , Batch Accuracy = 35.5
# 	Batch 200, Loss = 2.3769 , Rolling Mean Loss = 2.544 , Batch Accuracy = 33.25
# 	Batch 220, Loss = 2.2902 , Rolling Mean Loss = 2.4818 , Batch Accuracy = 31.0
# 	Train Accuracy (mean) =  29.93
# 	Test Accuracy         =  31.3
# Epoch 1
# 	Batch   0, Loss = 2.3071 , Rolling Mean Loss = 2.4638 , Batch Accuracy = 31.25
# 	Batch  20, Loss = 2.2878 , Rolling Mean Loss = 2.3989 , Batch Accuracy = 31.75
# 	Batch  40, Loss = 1.992 , Rolling Mean Loss = 2.3283 , Batch Accuracy = 40.0
# 	Batch  60, Loss = 1.9731 , Rolling Mean Loss = 2.27 , Batch Accuracy = 40.5
# 	Batch  80, Loss = 2.3199 , Rolling Mean Loss = 2.2245 , Batch Accuracy = 34.0
# 	Batch 100, Loss = 1.97 , Rolling Mean Loss = 2.1793 , Batch Accuracy = 37.0
# 	Batch 120, Loss = 2.258 , Rolling Mean Loss = 2.1524 , Batch Accuracy = 36.25
# 	Batch 140, Loss = 1.9072 , Rolling Mean Loss = 2.1284 , Batch Accuracy = 41.0
# 	Batch 160, Loss = 2.0697 , Rolling Mean Loss = 2.1052 , Batch Accuracy = 39.0
# 	Batch 180, Loss = 2.1079 , Rolling Mean Loss = 2.0809 , Batch Accuracy = 35.25
# 	Batch 200, Loss = 2.0803 , Rolling Mean Loss = 2.0532 , Batch Accuracy = 35.0
# 	Batch 220, Loss = 1.8645 , Rolling Mean Loss = 2.0249 , Batch Accuracy = 40.25
# 	Train Accuracy (mean) =  37.27
# 	Test Accuracy         =  37.1
# Epoch 2
# 	Batch   0, Loss = 1.9121 , Rolling Mean Loss = 2.0082 , Batch Accuracy = 40.25
# 	Batch  20, Loss = 1.7674 , Rolling Mean Loss = 1.9668 , Batch Accuracy = 42.0
# 	Batch  40, Loss = 1.8723 , Rolling Mean Loss = 1.9196 , Batch Accuracy = 38.75
# 	Batch  60, Loss = 1.8242 , Rolling Mean Loss = 1.8837 , Batch Accuracy = 43.75
# 	Batch  80, Loss = 1.8321 , Rolling Mean Loss = 1.8363 , Batch Accuracy = 40.0
# 	Batch 100, Loss = 1.6485 , Rolling Mean Loss = 1.8068 , Batch Accuracy = 39.75
# 	Batch 120, Loss = 1.7474 , Rolling Mean Loss = 1.8059 , Batch Accuracy = 45.0
# 	Batch 140, Loss = 1.8282 , Rolling Mean Loss = 1.8057 , Batch Accuracy = 39.75
# 	Batch 160, Loss = 1.8915 , Rolling Mean Loss = 1.7959 , Batch Accuracy = 37.25
# 	Batch 180, Loss = 1.7522 , Rolling Mean Loss = 1.7956 , Batch Accuracy = 42.25
# 	Batch 200, Loss = 1.6371 , Rolling Mean Loss = 1.7914 , Batch Accuracy = 41.75
# 	Batch 220, Loss = 1.6739 , Rolling Mean Loss = 1.7793 , Batch Accuracy = 42.5
# 	Train Accuracy (mean) =  41.3
# 	Test Accuracy         =  37.3
# Epoch 3
# 	Batch   0, Loss = 1.633 , Rolling Mean Loss = 1.7758 , Batch Accuracy = 43.25
# 	Batch  20, Loss = 1.5633 , Rolling Mean Loss = 1.74 , Batch Accuracy = 45.75
# 	Batch  40, Loss = 1.7254 , Rolling Mean Loss = 1.6938 , Batch Accuracy = 44.25
# 	Batch  60, Loss = 1.5829 , Rolling Mean Loss = 1.6522 , Batch Accuracy = 45.25
# 	Batch  80, Loss = 1.5988 , Rolling Mean Loss = 1.6169 , Batch Accuracy = 42.0
# 	Batch 100, Loss = 1.6365 , Rolling Mean Loss = 1.588 , Batch Accuracy = 41.0
# 	Batch 120, Loss = 1.5052 , Rolling Mean Loss = 1.5866 , Batch Accuracy = 47.5
# 	Batch 140, Loss = 1.5665 , Rolling Mean Loss = 1.5923 , Batch Accuracy = 47.5
# 	Batch 160, Loss = 1.6403 , Rolling Mean Loss = 1.6002 , Batch Accuracy = 45.25
# 	Batch 180, Loss = 1.4472 , Rolling Mean Loss = 1.5982 , Batch Accuracy = 48.75
# 	Batch 200, Loss = 1.5973 , Rolling Mean Loss = 1.591 , Batch Accuracy = 44.25
# 	Batch 220, Loss = 1.4012 , Rolling Mean Loss = 1.592 , Batch Accuracy = 49.25
# 	Train Accuracy (mean) =  44.68
# 	Test Accuracy         =  41.3
# Epoch 4
# 	Batch   0, Loss = 1.3918 , Rolling Mean Loss = 1.5848 , Batch Accuracy = 45.25
# 	Batch  20, Loss = 1.2967 , Rolling Mean Loss = 1.5411 , Batch Accuracy = 49.25
# 	Batch  40, Loss = 1.3296 , Rolling Mean Loss = 1.4959 , Batch Accuracy = 48.5
# 	Batch  60, Loss = 1.6206 , Rolling Mean Loss = 1.457 , Batch Accuracy = 44.5
# 	Batch  80, Loss = 1.3202 , Rolling Mean Loss = 1.4287 , Batch Accuracy = 48.5
# 	Batch 100, Loss = 1.5268 , Rolling Mean Loss = 1.398 , Batch Accuracy = 44.0
# 	Batch 120, Loss = 1.4143 , Rolling Mean Loss = 1.4107 , Batch Accuracy = 50.5
# 	Batch 140, Loss = 1.5752 , Rolling Mean Loss = 1.4355 , Batch Accuracy = 46.75
# 	Batch 160, Loss = 1.3919 , Rolling Mean Loss = 1.4431 , Batch Accuracy = 47.25
# 	Batch 180, Loss = 1.3359 , Rolling Mean Loss = 1.4466 , Batch Accuracy = 47.5
# 	Batch 200, Loss = 1.5829 , Rolling Mean Loss = 1.4594 , Batch Accuracy = 44.75
# 	Batch 220, Loss = 1.417 , Rolling Mean Loss = 1.4542 , Batch Accuracy = 49.5
# 	Train Accuracy (mean) =  47.73
# 	Test Accuracy         =  41.4
# Epoch 5
# 	Batch   0, Loss = 1.2212 , Rolling Mean Loss = 1.4432 , Batch Accuracy = 52.0
# 	Batch  20, Loss = 1.1406 , Rolling Mean Loss = 1.3933 , Batch Accuracy = 57.75
# 	Batch  40, Loss = 1.2738 , Rolling Mean Loss = 1.3538 , Batch Accuracy = 44.75
# 	Batch  60, Loss = 1.2478 , Rolling Mean Loss = 1.309 , Batch Accuracy = 51.75
# 	Batch  80, Loss = 1.4086 , Rolling Mean Loss = 1.2692 , Batch Accuracy = 48.75
# 	Batch 100, Loss = 1.2318 , Rolling Mean Loss = 1.239 , Batch Accuracy = 54.5
# 	Batch 120, Loss = 1.1726 , Rolling Mean Loss = 1.2485 , Batch Accuracy = 51.5
# 	Batch 140, Loss = 1.3534 , Rolling Mean Loss = 1.2663 , Batch Accuracy = 51.5
# 	Batch 160, Loss = 1.3213 , Rolling Mean Loss = 1.2822 , Batch Accuracy = 49.5
# 	Batch 180, Loss = 1.3053 , Rolling Mean Loss = 1.2889 , Batch Accuracy = 47.75
# 	Batch 200, Loss = 1.1828 , Rolling Mean Loss = 1.2985 , Batch Accuracy = 53.25
# 	Batch 220, Loss = 1.4082 , Rolling Mean Loss = 1.3141 , Batch Accuracy = 47.75
# 	Train Accuracy (mean) =  50.95
# 	Test Accuracy         =  40.0
# Epoch 6
# 	Batch   0, Loss = 1.0205 , Rolling Mean Loss = 1.3106 , Batch Accuracy = 56.25
# 	Batch  20, Loss = 0.9335 , Rolling Mean Loss = 1.2621 , Batch Accuracy = 59.5
# 	Batch  40, Loss = 1.106 , Rolling Mean Loss = 1.2117 , Batch Accuracy = 56.25
# 	Batch  60, Loss = 1.1024 , Rolling Mean Loss = 1.1746 , Batch Accuracy = 58.25
# 	Batch  80, Loss = 0.9933 , Rolling Mean Loss = 1.1271 , Batch Accuracy = 58.5
# 	Batch 100, Loss = 1.0159 , Rolling Mean Loss = 1.0903 , Batch Accuracy = 58.5
# 	Batch 120, Loss = 1.1509 , Rolling Mean Loss = 1.1073 , Batch Accuracy = 54.0
# 	Batch 140, Loss = 1.1156 , Rolling Mean Loss = 1.1204 , Batch Accuracy = 53.5
# 	Batch 160, Loss = 1.1723 , Rolling Mean Loss = 1.1327 , Batch Accuracy = 55.5
# 	Batch 180, Loss = 1.0781 , Rolling Mean Loss = 1.1438 , Batch Accuracy = 55.5
# 	Batch 200, Loss = 1.0602 , Rolling Mean Loss = 1.1451 , Batch Accuracy = 56.75
# 	Batch 220, Loss = 1.3012 , Rolling Mean Loss = 1.1492 , Batch Accuracy = 49.75
# 	Train Accuracy (mean) =  54.63
# 	Test Accuracy         =  40.3
# Epoch 7
# 	Batch   0, Loss = 0.9108 , Rolling Mean Loss = 1.1511 , Batch Accuracy = 61.0
# 	Batch  20, Loss = 0.8928 , Rolling Mean Loss = 1.1005 , Batch Accuracy = 59.25
# 	Batch  40, Loss = 0.9087 , Rolling Mean Loss = 1.0561 , Batch Accuracy = 58.5
# 	Batch  60, Loss = 0.864 , Rolling Mean Loss = 1.0089 , Batch Accuracy = 62.0
# 	Batch  80, Loss = 0.9549 , Rolling Mean Loss = 0.9697 , Batch Accuracy = 56.25
# 	Batch 100, Loss = 0.9348 , Rolling Mean Loss = 0.9314 , Batch Accuracy = 60.75
# 	Batch 120, Loss = 1.1848 , Rolling Mean Loss = 0.9548 , Batch Accuracy = 52.0
# 	Batch 140, Loss = 1.0457 , Rolling Mean Loss = 0.9733 , Batch Accuracy = 56.25
# 	Batch 160, Loss = 0.9843 , Rolling Mean Loss = 0.9881 , Batch Accuracy = 59.0
# 	Batch 180, Loss = 0.9666 , Rolling Mean Loss = 1.0024 , Batch Accuracy = 61.75
# 	Batch 200, Loss = 0.9744 , Rolling Mean Loss = 1.0207 , Batch Accuracy = 59.5
# 	Batch 220, Loss = 0.972 , Rolling Mean Loss = 1.0163 , Batch Accuracy = 56.0
# 	Train Accuracy (mean) =  58.27
# 	Test Accuracy         =  42.0
# Epoch 8
# 	Batch   0, Loss = 0.7609 , Rolling Mean Loss = 1.0168 , Batch Accuracy = 64.75
# 	Batch  20, Loss = 0.7979 , Rolling Mean Loss = 0.9709 , Batch Accuracy = 62.25
# 	Batch  40, Loss = 0.8479 , Rolling Mean Loss = 0.9207 , Batch Accuracy = 66.75
# 	Batch  60, Loss = 0.8068 , Rolling Mean Loss = 0.8685 , Batch Accuracy = 61.0
# 	Batch  80, Loss = 0.9185 , Rolling Mean Loss = 0.825 , Batch Accuracy = 60.5
# 	Batch 100, Loss = 0.8463 , Rolling Mean Loss = 0.7877 , Batch Accuracy = 64.0
# 	Batch 120, Loss = 0.934 , Rolling Mean Loss = 0.8097 , Batch Accuracy = 58.25
# 	Batch 140, Loss = 0.8723 , Rolling Mean Loss = 0.825 , Batch Accuracy = 58.5
# 	Batch 160, Loss = 0.9155 , Rolling Mean Loss = 0.8465 , Batch Accuracy = 62.0
# 	Batch 180, Loss = 0.8477 , Rolling Mean Loss = 0.862 , Batch Accuracy = 60.0
# 	Batch 200, Loss = 0.8652 , Rolling Mean Loss = 0.8813 , Batch Accuracy = 57.0
# 	Batch 220, Loss = 0.9468 , Rolling Mean Loss = 0.8836 , Batch Accuracy = 60.25
# 	Train Accuracy (mean) =  61.9
# 	Test Accuracy         =  41.6
# Epoch 9
# 	Batch   0, Loss = 0.6761 , Rolling Mean Loss = 0.8863 , Batch Accuracy = 65.0
# 	Batch  20, Loss = 0.7039 , Rolling Mean Loss = 0.8565 , Batch Accuracy = 68.25
# 	Batch  40, Loss = 0.7019 , Rolling Mean Loss = 0.8063 , Batch Accuracy = 67.25
# 	Batch  60, Loss = 0.6761 , Rolling Mean Loss = 0.7574 , Batch Accuracy = 66.5
# 	Batch  80, Loss = 0.7496 , Rolling Mean Loss = 0.7151 , Batch Accuracy = 64.25
# 	Batch 100, Loss = 0.7379 , Rolling Mean Loss = 0.6825 , Batch Accuracy = 63.0
# 	Batch 120, Loss = 0.6801 , Rolling Mean Loss = 0.688 , Batch Accuracy = 64.25
# 	Batch 140, Loss = 0.7067 , Rolling Mean Loss = 0.7082 , Batch Accuracy = 66.0
# 	Batch 160, Loss = 0.7657 , Rolling Mean Loss = 0.7262 , Batch Accuracy = 65.5
# 	Batch 180, Loss = 0.8228 , Rolling Mean Loss = 0.7439 , Batch Accuracy = 63.5
# 	Batch 200, Loss = 0.8448 , Rolling Mean Loss = 0.7492 , Batch Accuracy = 62.5
# 	Batch 220, Loss = 0.72 , Rolling Mean Loss = 0.7623 , Batch Accuracy = 65.5
# 	Train Accuracy (mean) =  65.17
# 	Test Accuracy         =  39.7
# Epoch 10
# 	Batch   0, Loss = 0.5809 , Rolling Mean Loss = 0.7623 , Batch Accuracy = 67.5
# 	Batch  20, Loss = 0.5992 , Rolling Mean Loss = 0.7248 , Batch Accuracy = 66.5
# 	Batch  40, Loss = 0.4568 , Rolling Mean Loss = 0.6847 , Batch Accuracy = 72.5
# 	Batch  60, Loss = 0.4991 , Rolling Mean Loss = 0.6456 , Batch Accuracy = 72.75
# 	Batch  80, Loss = 0.5877 , Rolling Mean Loss = 0.6144 , Batch Accuracy = 70.5
# 	Batch 100, Loss = 0.5192 , Rolling Mean Loss = 0.577 , Batch Accuracy = 69.75
# 	Batch 120, Loss = 0.6136 , Rolling Mean Loss = 0.5895 , Batch Accuracy = 69.75
# 	Batch 140, Loss = 0.6391 , Rolling Mean Loss = 0.6061 , Batch Accuracy = 65.25
# 	Batch 160, Loss = 0.6327 , Rolling Mean Loss = 0.6177 , Batch Accuracy = 67.5
# 	Batch 180, Loss = 0.6028 , Rolling Mean Loss = 0.6255 , Batch Accuracy = 66.0
# 	Batch 200, Loss = 0.629 , Rolling Mean Loss = 0.641 , Batch Accuracy = 68.25
# 	Batch 220, Loss = 0.5953 , Rolling Mean Loss = 0.6442 , Batch Accuracy = 69.75
# 	Train Accuracy (mean) =  68.28
# 	Test Accuracy         =  40.4
# Epoch 11
# 	Batch   0, Loss = 0.4756 , Rolling Mean Loss = 0.6472 , Batch Accuracy = 74.5
# 	Batch  20, Loss = 0.4982 , Rolling Mean Loss = 0.6161 , Batch Accuracy = 71.75
# 	Batch  40, Loss = 0.4953 , Rolling Mean Loss = 0.5783 , Batch Accuracy = 71.75
# 	Batch  60, Loss = 0.451 , Rolling Mean Loss = 0.5445 , Batch Accuracy = 71.5
# 	Batch  80, Loss = 0.4434 , Rolling Mean Loss = 0.5137 , Batch Accuracy = 74.5
# 	Batch 100, Loss = 0.4856 , Rolling Mean Loss = 0.4964 , Batch Accuracy = 72.75
# 	Batch 120, Loss = 0.5283 , Rolling Mean Loss = 0.5056 , Batch Accuracy = 70.5
# 	Batch 140, Loss = 0.563 , Rolling Mean Loss = 0.5212 , Batch Accuracy = 70.5
# 	Batch 160, Loss = 0.5401 , Rolling Mean Loss = 0.5379 , Batch Accuracy = 70.5
# 	Batch 180, Loss = 0.556 , Rolling Mean Loss = 0.5476 , Batch Accuracy = 65.5
# 	Batch 200, Loss = 0.5325 , Rolling Mean Loss = 0.5515 , Batch Accuracy = 70.25
# 	Batch 220, Loss = 0.5557 , Rolling Mean Loss = 0.5567 , Batch Accuracy = 67.5
# 	Train Accuracy (mean) =  70.74
# 	Test Accuracy         =  40.4
# Epoch 12
# 	Batch   0, Loss = 0.3407 , Rolling Mean Loss = 0.5567 , Batch Accuracy = 76.75
# 	Batch  20, Loss = 0.3805 , Rolling Mean Loss = 0.529 , Batch Accuracy = 78.25
# 	Batch  40, Loss = 0.4341 , Rolling Mean Loss = 0.494 , Batch Accuracy = 73.5
# 	Batch  60, Loss = 0.4235 , Rolling Mean Loss = 0.4633 , Batch Accuracy = 75.0
# 	Batch  80, Loss = 0.5099 , Rolling Mean Loss = 0.4344 , Batch Accuracy = 67.0
# 	Batch 100, Loss = 0.4906 , Rolling Mean Loss = 0.414 , Batch Accuracy = 70.75
# 	Batch 120, Loss = 0.4547 , Rolling Mean Loss = 0.4263 , Batch Accuracy = 72.5
# 	Batch 140, Loss = 0.3942 , Rolling Mean Loss = 0.4406 , Batch Accuracy = 73.75
# 	Batch 160, Loss = 0.4999 , Rolling Mean Loss = 0.4516 , Batch Accuracy = 69.75
# 	Batch 180, Loss = 0.4702 , Rolling Mean Loss = 0.4579 , Batch Accuracy = 72.5
# 	Batch 200, Loss = 0.4667 , Rolling Mean Loss = 0.4669 , Batch Accuracy = 76.5
# 	Batch 220, Loss = 0.4687 , Rolling Mean Loss = 0.4772 , Batch Accuracy = 73.0
# 	Train Accuracy (mean) =  73.12
# 	Test Accuracy         =  39.0
# Epoch 13
# 	Batch   0, Loss = 0.3297 , Rolling Mean Loss = 0.4795 , Batch Accuracy = 78.75
# 	Batch  20, Loss = 0.3375 , Rolling Mean Loss = 0.4557 , Batch Accuracy = 72.75
# 	Batch  40, Loss = 0.3997 , Rolling Mean Loss = 0.4374 , Batch Accuracy = 73.25
# 	Batch  60, Loss = 0.3479 , Rolling Mean Loss = 0.4092 , Batch Accuracy = 74.75
# 	Batch  80, Loss = 0.3082 , Rolling Mean Loss = 0.3826 , Batch Accuracy = 76.5
# 	Batch 100, Loss = 0.4034 , Rolling Mean Loss = 0.3562 , Batch Accuracy = 74.75
# 	Batch 120, Loss = 0.4206 , Rolling Mean Loss = 0.3646 , Batch Accuracy = 74.75
# 	Batch 140, Loss = 0.4018 , Rolling Mean Loss = 0.373 , Batch Accuracy = 75.25
# 	Batch 160, Loss = 0.5457 , Rolling Mean Loss = 0.3899 , Batch Accuracy = 67.5
# 	Batch 180, Loss = 0.3833 , Rolling Mean Loss = 0.3988 , Batch Accuracy = 73.5
# 	Batch 200, Loss = 0.4261 , Rolling Mean Loss = 0.4123 , Batch Accuracy = 74.75
# 	Batch 220, Loss = 0.5229 , Rolling Mean Loss = 0.422 , Batch Accuracy = 70.75
# 	Train Accuracy (mean) =  74.74
# 	Test Accuracy         =  39.5
# Epoch 14
# 	Batch   0, Loss = 0.2691 , Rolling Mean Loss = 0.4228 , Batch Accuracy = 80.0
# 	Batch  20, Loss = 0.3114 , Rolling Mean Loss = 0.4008 , Batch Accuracy = 76.0
# 	Batch  40, Loss = 0.2927 , Rolling Mean Loss = 0.3761 , Batch Accuracy = 80.75
# 	Batch  60, Loss = 0.3154 , Rolling Mean Loss = 0.3482 , Batch Accuracy = 75.25
# 	Batch  80, Loss = 0.3869 , Rolling Mean Loss = 0.3222 , Batch Accuracy = 73.75
# 	Batch 100, Loss = 0.4288 , Rolling Mean Loss = 0.3029 , Batch Accuracy = 74.75
# 	Batch 120, Loss = 0.3909 , Rolling Mean Loss = 0.3157 , Batch Accuracy = 75.25
# 	Batch 140, Loss = 0.3747 , Rolling Mean Loss = 0.3281 , Batch Accuracy = 72.0
# 	Batch 160, Loss = 0.3166 , Rolling Mean Loss = 0.342 , Batch Accuracy = 76.5
# 	Batch 180, Loss = 0.379 , Rolling Mean Loss = 0.3541 , Batch Accuracy = 77.25
# 	Batch 200, Loss = 0.3907 , Rolling Mean Loss = 0.365 , Batch Accuracy = 76.25
# 	Batch 220, Loss = 0.4314 , Rolling Mean Loss = 0.3712 , Batch Accuracy = 70.0
# 	Train Accuracy (mean) =  76.3
# 	Test Accuracy         =  39.5
# Epoch 15
# 	Batch   0, Loss = 0.31 , Rolling Mean Loss = 0.3723 , Batch Accuracy = 75.0
# 	Batch  20, Loss = 0.2074 , Rolling Mean Loss = 0.3538 , Batch Accuracy = 80.75
# 	Batch  40, Loss = 0.2649 , Rolling Mean Loss = 0.3362 , Batch Accuracy = 78.0
# 	Batch  60, Loss = 0.2194 , Rolling Mean Loss = 0.3137 , Batch Accuracy = 80.0
# 	Batch  80, Loss = 0.3069 , Rolling Mean Loss = 0.2994 , Batch Accuracy = 75.5
# 	Batch 100, Loss = 0.2585 , Rolling Mean Loss = 0.2788 , Batch Accuracy = 76.75
# 	Batch 120, Loss = 0.315 , Rolling Mean Loss = 0.2873 , Batch Accuracy = 77.5
# 	Batch 140, Loss = 0.2546 , Rolling Mean Loss = 0.2975 , Batch Accuracy = 76.75
# 	Batch 160, Loss = 0.234 , Rolling Mean Loss = 0.3018 , Batch Accuracy = 80.5
# 	Batch 180, Loss = 0.4343 , Rolling Mean Loss = 0.3027 , Batch Accuracy = 73.0
# 	Batch 200, Loss = 0.302 , Rolling Mean Loss = 0.3058 , Batch Accuracy = 78.5
# 	Batch 220, Loss = 0.3664 , Rolling Mean Loss = 0.3088 , Batch Accuracy = 76.0
# 	Train Accuracy (mean) =  77.57
# 	Test Accuracy         =  41.1
# Epoch 16
# 	Batch   0, Loss = 0.2177 , Rolling Mean Loss = 0.3105 , Batch Accuracy = 78.5
# 	Batch  20, Loss = 0.2034 , Rolling Mean Loss = 0.2945 , Batch Accuracy = 83.5
# 	Batch  40, Loss = 0.1704 , Rolling Mean Loss = 0.2777 , Batch Accuracy = 84.0
# 	Batch  60, Loss = 0.231 , Rolling Mean Loss = 0.2617 , Batch Accuracy = 79.25
# 	Batch  80, Loss = 0.2455 , Rolling Mean Loss = 0.2414 , Batch Accuracy = 78.25
# 	Batch 100, Loss = 0.2165 , Rolling Mean Loss = 0.2236 , Batch Accuracy = 79.25
# 	Batch 120, Loss = 0.2866 , Rolling Mean Loss = 0.2282 , Batch Accuracy = 77.5
# 	Batch 140, Loss = 0.2193 , Rolling Mean Loss = 0.2384 , Batch Accuracy = 79.0
# 	Batch 160, Loss = 0.2858 , Rolling Mean Loss = 0.2504 , Batch Accuracy = 77.0
# 	Batch 180, Loss = 0.3119 , Rolling Mean Loss = 0.2604 , Batch Accuracy = 79.75
# 	Batch 200, Loss = 0.2534 , Rolling Mean Loss = 0.271 , Batch Accuracy = 79.25
# 	Batch 220, Loss = 0.2783 , Rolling Mean Loss = 0.2819 , Batch Accuracy = 78.0
# 	Train Accuracy (mean) =  78.8
# 	Test Accuracy         =  38.3
# Epoch 17
# 	Batch   0, Loss = 0.2103 , Rolling Mean Loss = 0.2815 , Batch Accuracy = 81.0
# 	Batch  20, Loss = 0.2233 , Rolling Mean Loss = 0.2695 , Batch Accuracy = 81.5
# 	Batch  40, Loss = 0.2016 , Rolling Mean Loss = 0.256 , Batch Accuracy = 78.75
# 	Batch  60, Loss = 0.2103 , Rolling Mean Loss = 0.2411 , Batch Accuracy = 82.25
# 	Batch  80, Loss = 0.2306 , Rolling Mean Loss = 0.2246 , Batch Accuracy = 77.5
# 	Batch 100, Loss = 0.1812 , Rolling Mean Loss = 0.2079 , Batch Accuracy = 82.5
# 	Batch 120, Loss = 0.221 , Rolling Mean Loss = 0.211 , Batch Accuracy = 78.75
# 	Batch 140, Loss = 0.1705 , Rolling Mean Loss = 0.2181 , Batch Accuracy = 80.5
# 	Batch 160, Loss = 0.2828 , Rolling Mean Loss = 0.2253 , Batch Accuracy = 79.5
# 	Batch 180, Loss = 0.2471 , Rolling Mean Loss = 0.2351 , Batch Accuracy = 80.75
# 	Batch 200, Loss = 0.2364 , Rolling Mean Loss = 0.2447 , Batch Accuracy = 80.75
# 	Batch 220, Loss = 0.2339 , Rolling Mean Loss = 0.2504 , Batch Accuracy = 79.0
# 	Train Accuracy (mean) =  79.45
# 	Test Accuracy         =  39.5
# Epoch 18
# 	Batch   0, Loss = 0.1734 , Rolling Mean Loss = 0.2504 , Batch Accuracy = 83.25
# 	Batch  20, Loss = 0.1999 , Rolling Mean Loss = 0.2381 , Batch Accuracy = 80.5
# 	Batch  40, Loss = 0.1984 , Rolling Mean Loss = 0.2207 , Batch Accuracy = 82.0
# 	Batch  60, Loss = 0.1678 , Rolling Mean Loss = 0.2021 , Batch Accuracy = 81.75
# 	Batch  80, Loss = 0.2369 , Rolling Mean Loss = 0.1907 , Batch Accuracy = 80.0
# 	Batch 100, Loss = 0.1879 , Rolling Mean Loss = 0.1812 , Batch Accuracy = 80.75
# 	Batch 120, Loss = 0.1674 , Rolling Mean Loss = 0.1867 , Batch Accuracy = 82.25
# 	Batch 140, Loss = 0.2229 , Rolling Mean Loss = 0.194 , Batch Accuracy = 82.25
# 	Batch 160, Loss = 0.2373 , Rolling Mean Loss = 0.2074 , Batch Accuracy = 81.75
# 	Batch 180, Loss = 0.2733 , Rolling Mean Loss = 0.2149 , Batch Accuracy = 76.0
# 	Batch 200, Loss = 0.2552 , Rolling Mean Loss = 0.2186 , Batch Accuracy = 75.5
# 	Batch 220, Loss = 0.2391 , Rolling Mean Loss = 0.2222 , Batch Accuracy = 79.5
# 	Train Accuracy (mean) =  80.37
# 	Test Accuracy         =  40.5
# Epoch 19
# 	Batch   0, Loss = 0.152 , Rolling Mean Loss = 0.2247 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.143 , Rolling Mean Loss = 0.2129 , Batch Accuracy = 82.75
# 	Batch  40, Loss = 0.1757 , Rolling Mean Loss = 0.1987 , Batch Accuracy = 78.5
# 	Batch  60, Loss = 0.1712 , Rolling Mean Loss = 0.1845 , Batch Accuracy = 81.0
# 	Batch  80, Loss = 0.1762 , Rolling Mean Loss = 0.1729 , Batch Accuracy = 78.5
# 	Batch 100, Loss = 0.1845 , Rolling Mean Loss = 0.1652 , Batch Accuracy = 81.75
# 	Batch 120, Loss = 0.1961 , Rolling Mean Loss = 0.1723 , Batch Accuracy = 82.25
# 	Batch 140, Loss = 0.1899 , Rolling Mean Loss = 0.1772 , Batch Accuracy = 79.5
# 	Batch 160, Loss = 0.2215 , Rolling Mean Loss = 0.1856 , Batch Accuracy = 82.25
# 	Batch 180, Loss = 0.1864 , Rolling Mean Loss = 0.194 , Batch Accuracy = 78.0
# 	Batch 200, Loss = 0.2637 , Rolling Mean Loss = 0.1989 , Batch Accuracy = 78.75
# 	Batch 220, Loss = 0.165 , Rolling Mean Loss = 0.2052 , Batch Accuracy = 84.75
# 	Train Accuracy (mean) =  80.85
# 	Test Accuracy         =  40.2
# Epoch 20
# 	Batch   0, Loss = 0.1427 , Rolling Mean Loss = 0.2066 , Batch Accuracy = 83.25
# 	Batch  20, Loss = 0.1142 , Rolling Mean Loss = 0.2004 , Batch Accuracy = 84.0
# 	Batch  40, Loss = 0.1089 , Rolling Mean Loss = 0.1914 , Batch Accuracy = 84.0
# 	Batch  60, Loss = 0.1815 , Rolling Mean Loss = 0.181 , Batch Accuracy = 80.25
# 	Batch  80, Loss = 0.176 , Rolling Mean Loss = 0.1655 , Batch Accuracy = 81.5
# 	Batch 100, Loss = 0.1782 , Rolling Mean Loss = 0.1565 , Batch Accuracy = 80.0
# 	Batch 120, Loss = 0.2029 , Rolling Mean Loss = 0.161 , Batch Accuracy = 75.75
# 	Batch 140, Loss = 0.1182 , Rolling Mean Loss = 0.1637 , Batch Accuracy = 81.75
# 	Batch 160, Loss = 0.3021 , Rolling Mean Loss = 0.17 , Batch Accuracy = 76.75
# 	Batch 180, Loss = 0.2227 , Rolling Mean Loss = 0.1753 , Batch Accuracy = 83.25
# 	Batch 200, Loss = 0.1901 , Rolling Mean Loss = 0.1822 , Batch Accuracy = 79.5
# 	Batch 220, Loss = 0.1594 , Rolling Mean Loss = 0.1908 , Batch Accuracy = 80.5
# 	Train Accuracy (mean) =  81.17
# 	Test Accuracy         =  41.0
# Epoch 21
# 	Batch   0, Loss = 0.1787 , Rolling Mean Loss = 0.1932 , Batch Accuracy = 82.25
# 	Batch  20, Loss = 0.1217 , Rolling Mean Loss = 0.1874 , Batch Accuracy = 83.0
# 	Batch  40, Loss = 0.1699 , Rolling Mean Loss = 0.1781 , Batch Accuracy = 81.75
# 	Batch  60, Loss = 0.1688 , Rolling Mean Loss = 0.1708 , Batch Accuracy = 81.5
# 	Batch  80, Loss = 0.1032 , Rolling Mean Loss = 0.1577 , Batch Accuracy = 82.0
# 	Batch 100, Loss = 0.2106 , Rolling Mean Loss = 0.1481 , Batch Accuracy = 79.5
# 	Batch 120, Loss = 0.1512 , Rolling Mean Loss = 0.1481 , Batch Accuracy = 83.5
# 	Batch 140, Loss = 0.1334 , Rolling Mean Loss = 0.1539 , Batch Accuracy = 83.25
# 	Batch 160, Loss = 0.1804 , Rolling Mean Loss = 0.1562 , Batch Accuracy = 81.75
# 	Batch 180, Loss = 0.1797 , Rolling Mean Loss = 0.1618 , Batch Accuracy = 80.25
# 	Batch 200, Loss = 0.2151 , Rolling Mean Loss = 0.1677 , Batch Accuracy = 79.25
# 	Batch 220, Loss = 0.1871 , Rolling Mean Loss = 0.1755 , Batch Accuracy = 79.5
# 	Train Accuracy (mean) =  81.53
# 	Test Accuracy         =  40.3
# Epoch 22
# 	Batch   0, Loss = 0.1757 , Rolling Mean Loss = 0.177 , Batch Accuracy = 80.0
# 	Batch  20, Loss = 0.1181 , Rolling Mean Loss = 0.1727 , Batch Accuracy = 83.5
# 	Batch  40, Loss = 0.111 , Rolling Mean Loss = 0.1672 , Batch Accuracy = 84.0
# 	Batch  60, Loss = 0.1415 , Rolling Mean Loss = 0.1562 , Batch Accuracy = 80.25
# 	Batch  80, Loss = 0.1275 , Rolling Mean Loss = 0.1431 , Batch Accuracy = 81.0
# 	Batch 100, Loss = 0.1432 , Rolling Mean Loss = 0.1304 , Batch Accuracy = 83.5
# 	Batch 120, Loss = 0.1805 , Rolling Mean Loss = 0.1298 , Batch Accuracy = 79.25
# 	Batch 140, Loss = 0.1317 , Rolling Mean Loss = 0.1319 , Batch Accuracy = 81.5
# 	Batch 160, Loss = 0.2217 , Rolling Mean Loss = 0.1365 , Batch Accuracy = 78.75
# 	Batch 180, Loss = 0.1455 , Rolling Mean Loss = 0.1446 , Batch Accuracy = 81.75
# 	Batch 200, Loss = 0.1901 , Rolling Mean Loss = 0.1541 , Batch Accuracy = 77.0
# 	Batch 220, Loss = 0.231 , Rolling Mean Loss = 0.1617 , Batch Accuracy = 77.5
# 	Train Accuracy (mean) =  81.97
# 	Test Accuracy         =  40.6
# Epoch 23
# 	Batch   0, Loss = 0.0966 , Rolling Mean Loss = 0.1643 , Batch Accuracy = 81.5
# 	Batch  20, Loss = 0.1206 , Rolling Mean Loss = 0.156 , Batch Accuracy = 84.25
# 	Batch  40, Loss = 0.127 , Rolling Mean Loss = 0.1445 , Batch Accuracy = 82.25
# 	Batch  60, Loss = 0.1059 , Rolling Mean Loss = 0.1369 , Batch Accuracy = 80.75
# 	Batch  80, Loss = 0.0934 , Rolling Mean Loss = 0.1256 , Batch Accuracy = 82.5
# 	Batch 100, Loss = 0.1279 , Rolling Mean Loss = 0.114 , Batch Accuracy = 79.75
# 	Batch 120, Loss = 0.0936 , Rolling Mean Loss = 0.1185 , Batch Accuracy = 81.75
# 	Batch 140, Loss = 0.1372 , Rolling Mean Loss = 0.125 , Batch Accuracy = 85.25
# 	Batch 160, Loss = 0.1428 , Rolling Mean Loss = 0.127 , Batch Accuracy = 80.0
# 	Batch 180, Loss = 0.1493 , Rolling Mean Loss = 0.1321 , Batch Accuracy = 81.5
# 	Batch 200, Loss = 0.1424 , Rolling Mean Loss = 0.1391 , Batch Accuracy = 81.0
# 	Batch 220, Loss = 0.1306 , Rolling Mean Loss = 0.1424 , Batch Accuracy = 82.5
# 	Train Accuracy (mean) =  82.53
# 	Test Accuracy         =  41.9
# Epoch 24
# 	Batch   0, Loss = 0.1213 , Rolling Mean Loss = 0.1429 , Batch Accuracy = 86.75
# 	Batch  20, Loss = 0.1009 , Rolling Mean Loss = 0.1373 , Batch Accuracy = 81.25
# 	Batch  40, Loss = 0.134 , Rolling Mean Loss = 0.132 , Batch Accuracy = 83.75
# 	Batch  60, Loss = 0.0823 , Rolling Mean Loss = 0.124 , Batch Accuracy = 80.5
# 	Batch  80, Loss = 0.0994 , Rolling Mean Loss = 0.1121 , Batch Accuracy = 84.0
# 	Batch 100, Loss = 0.0998 , Rolling Mean Loss = 0.1074 , Batch Accuracy = 82.75
# 	Batch 120, Loss = 0.1001 , Rolling Mean Loss = 0.1104 , Batch Accuracy = 84.5
# 	Batch 140, Loss = 0.1009 , Rolling Mean Loss = 0.1156 , Batch Accuracy = 81.75
# 	Batch 160, Loss = 0.1645 , Rolling Mean Loss = 0.1223 , Batch Accuracy = 78.5
# 	Batch 180, Loss = 0.0977 , Rolling Mean Loss = 0.1302 , Batch Accuracy = 82.25
# 	Batch 200, Loss = 0.1499 , Rolling Mean Loss = 0.1345 , Batch Accuracy = 80.5
# 	Batch 220, Loss = 0.1725 , Rolling Mean Loss = 0.1413 , Batch Accuracy = 80.75
# 	Train Accuracy (mean) =  82.6
# 	Test Accuracy         =  41.8
# Epoch 25
# 	Batch   0, Loss = 0.096 , Rolling Mean Loss = 0.1419 , Batch Accuracy = 82.75
# 	Batch  20, Loss = 0.0567 , Rolling Mean Loss = 0.1368 , Batch Accuracy = 81.75
# 	Batch  40, Loss = 0.0939 , Rolling Mean Loss = 0.128 , Batch Accuracy = 84.0
# 	Batch  60, Loss = 0.1091 , Rolling Mean Loss = 0.1202 , Batch Accuracy = 81.0
# 	Batch  80, Loss = 0.0975 , Rolling Mean Loss = 0.1118 , Batch Accuracy = 84.5
# 	Batch 100, Loss = 0.1158 , Rolling Mean Loss = 0.1038 , Batch Accuracy = 83.75
# 	Batch 120, Loss = 0.1241 , Rolling Mean Loss = 0.1079 , Batch Accuracy = 83.5
# 	Batch 140, Loss = 0.1233 , Rolling Mean Loss = 0.1131 , Batch Accuracy = 82.0
# 	Batch 160, Loss = 0.1003 , Rolling Mean Loss = 0.1164 , Batch Accuracy = 85.25
# 	Batch 180, Loss = 0.1676 , Rolling Mean Loss = 0.1214 , Batch Accuracy = 80.5
# 	Batch 200, Loss = 0.1129 , Rolling Mean Loss = 0.1271 , Batch Accuracy = 82.25
# 	Batch 220, Loss = 0.1041 , Rolling Mean Loss = 0.13 , Batch Accuracy = 81.5
# 	Train Accuracy (mean) =  82.85
# 	Test Accuracy         =  40.0
# Epoch 26
# 	Batch   0, Loss = 0.1032 , Rolling Mean Loss = 0.1307 , Batch Accuracy = 81.5
# 	Batch  20, Loss = 0.0876 , Rolling Mean Loss = 0.1262 , Batch Accuracy = 79.0
# 	Batch  40, Loss = 0.0268 , Rolling Mean Loss = 0.1191 , Batch Accuracy = 81.75
# 	Batch  60, Loss = 0.0816 , Rolling Mean Loss = 0.1101 , Batch Accuracy = 82.25
# 	Batch  80, Loss = 0.0992 , Rolling Mean Loss = 0.1021 , Batch Accuracy = 80.0
# 	Batch 100, Loss = 0.1134 , Rolling Mean Loss = 0.0941 , Batch Accuracy = 86.25
# 	Batch 120, Loss = 0.1022 , Rolling Mean Loss = 0.0982 , Batch Accuracy = 82.0
# 	Batch 140, Loss = 0.1264 , Rolling Mean Loss = 0.1044 , Batch Accuracy = 84.5
# 	Batch 160, Loss = 0.1017 , Rolling Mean Loss = 0.1081 , Batch Accuracy = 82.75
# 	Batch 180, Loss = 0.1062 , Rolling Mean Loss = 0.1098 , Batch Accuracy = 84.5
# 	Batch 200, Loss = 0.1631 , Rolling Mean Loss = 0.1124 , Batch Accuracy = 82.25
# 	Batch 220, Loss = 0.1185 , Rolling Mean Loss = 0.1151 , Batch Accuracy = 83.25
# 	Train Accuracy (mean) =  83.29
# 	Test Accuracy         =  40.2
# Epoch 27
# 	Batch   0, Loss = 0.1138 , Rolling Mean Loss = 0.1161 , Batch Accuracy = 81.5
# 	Batch  20, Loss = 0.0618 , Rolling Mean Loss = 0.1114 , Batch Accuracy = 85.75
# 	Batch  40, Loss = 0.0547 , Rolling Mean Loss = 0.1071 , Batch Accuracy = 83.75
# 	Batch  60, Loss = 0.0789 , Rolling Mean Loss = 0.1028 , Batch Accuracy = 85.0
# 	Batch  80, Loss = 0.0768 , Rolling Mean Loss = 0.0954 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0568 , Rolling Mean Loss = 0.086 , Batch Accuracy = 86.75
# 	Batch 120, Loss = 0.0837 , Rolling Mean Loss = 0.0868 , Batch Accuracy = 84.25
# 	Batch 140, Loss = 0.149 , Rolling Mean Loss = 0.09 , Batch Accuracy = 85.0
# 	Batch 160, Loss = 0.1756 , Rolling Mean Loss = 0.0962 , Batch Accuracy = 80.75
# 	Batch 180, Loss = 0.1643 , Rolling Mean Loss = 0.106 , Batch Accuracy = 83.0
# 	Batch 200, Loss = 0.1441 , Rolling Mean Loss = 0.1139 , Batch Accuracy = 80.75
# 	Batch 220, Loss = 0.1493 , Rolling Mean Loss = 0.122 , Batch Accuracy = 81.5
# 	Train Accuracy (mean) =  83.31
# 	Test Accuracy         =  41.5
# Epoch 28
# 	Batch   0, Loss = 0.1119 , Rolling Mean Loss = 0.1237 , Batch Accuracy = 81.75
# 	Batch  20, Loss = 0.0631 , Rolling Mean Loss = 0.1185 , Batch Accuracy = 83.75
# 	Batch  40, Loss = 0.0869 , Rolling Mean Loss = 0.1068 , Batch Accuracy = 85.25
# 	Batch  60, Loss = 0.076 , Rolling Mean Loss = 0.0994 , Batch Accuracy = 84.5
# 	Batch  80, Loss = 0.0509 , Rolling Mean Loss = 0.0927 , Batch Accuracy = 83.75
# 	Batch 100, Loss = 0.1051 , Rolling Mean Loss = 0.0832 , Batch Accuracy = 79.0
# 	Batch 120, Loss = 0.1042 , Rolling Mean Loss = 0.0839 , Batch Accuracy = 86.25
# 	Batch 140, Loss = 0.0646 , Rolling Mean Loss = 0.0893 , Batch Accuracy = 87.5
# 	Batch 160, Loss = 0.1154 , Rolling Mean Loss = 0.0934 , Batch Accuracy = 80.0
# 	Batch 180, Loss = 0.1101 , Rolling Mean Loss = 0.0963 , Batch Accuracy = 84.75
# 	Batch 200, Loss = 0.093 , Rolling Mean Loss = 0.1004 , Batch Accuracy = 81.25
# 	Batch 220, Loss = 0.0754 , Rolling Mean Loss = 0.105 , Batch Accuracy = 83.5
# 	Train Accuracy (mean) =  83.67
# 	Test Accuracy         =  40.4
# Epoch 29
# 	Batch   0, Loss = 0.0833 , Rolling Mean Loss = 0.1057 , Batch Accuracy = 83.75
# 	Batch  20, Loss = 0.0742 , Rolling Mean Loss = 0.0995 , Batch Accuracy = 82.25
# 	Batch  40, Loss = 0.0783 , Rolling Mean Loss = 0.0923 , Batch Accuracy = 83.0
# 	Batch  60, Loss = 0.0651 , Rolling Mean Loss = 0.083 , Batch Accuracy = 84.75
# 	Batch  80, Loss = 0.0685 , Rolling Mean Loss = 0.0786 , Batch Accuracy = 81.25
# 	Batch 100, Loss = 0.0822 , Rolling Mean Loss = 0.0715 , Batch Accuracy = 83.25
# 	Batch 120, Loss = 0.09 , Rolling Mean Loss = 0.0712 , Batch Accuracy = 82.75
# 	Batch 140, Loss = 0.094 , Rolling Mean Loss = 0.0734 , Batch Accuracy = 86.0
# 	Batch 160, Loss = 0.083 , Rolling Mean Loss = 0.0783 , Batch Accuracy = 84.5
# 	Batch 180, Loss = 0.0812 , Rolling Mean Loss = 0.0821 , Batch Accuracy = 84.0
# 	Batch 200, Loss = 0.118 , Rolling Mean Loss = 0.0866 , Batch Accuracy = 83.75
# 	Batch 220, Loss = 0.1154 , Rolling Mean Loss = 0.0915 , Batch Accuracy = 79.25
# 	Train Accuracy (mean) =  83.97
# 	Test Accuracy         =  41.8
# Epoch 30
# 	Batch   0, Loss = 0.0737 , Rolling Mean Loss = 0.0945 , Batch Accuracy = 84.75
# 	Batch  20, Loss = 0.0506 , Rolling Mean Loss = 0.0912 , Batch Accuracy = 83.0
# 	Batch  40, Loss = 0.0636 , Rolling Mean Loss = 0.0874 , Batch Accuracy = 85.5
# 	Batch  60, Loss = 0.0676 , Rolling Mean Loss = 0.0815 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.1099 , Rolling Mean Loss = 0.0785 , Batch Accuracy = 82.75
# 	Batch 100, Loss = 0.1088 , Rolling Mean Loss = 0.0752 , Batch Accuracy = 81.75
# 	Batch 120, Loss = 0.0415 , Rolling Mean Loss = 0.0761 , Batch Accuracy = 85.0
# 	Batch 140, Loss = 0.0694 , Rolling Mean Loss = 0.0795 , Batch Accuracy = 83.75
# 	Batch 160, Loss = 0.0821 , Rolling Mean Loss = 0.0833 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0693 , Rolling Mean Loss = 0.0862 , Batch Accuracy = 85.75
# 	Batch 200, Loss = 0.1417 , Rolling Mean Loss = 0.0877 , Batch Accuracy = 81.0
# 	Batch 220, Loss = 0.0826 , Rolling Mean Loss = 0.0904 , Batch Accuracy = 84.75
# 	Train Accuracy (mean) =  83.94
# 	Test Accuracy         =  40.7
# Epoch 31
# 	Batch   0, Loss = 0.054 , Rolling Mean Loss = 0.0918 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0707 , Rolling Mean Loss = 0.087 , Batch Accuracy = 84.75
# 	Batch  40, Loss = 0.0621 , Rolling Mean Loss = 0.081 , Batch Accuracy = 86.0
# 	Batch  60, Loss = 0.1167 , Rolling Mean Loss = 0.0774 , Batch Accuracy = 80.0
# 	Batch  80, Loss = 0.0474 , Rolling Mean Loss = 0.0721 , Batch Accuracy = 86.25
# 	Batch 100, Loss = 0.0515 , Rolling Mean Loss = 0.0688 , Batch Accuracy = 85.75
# 	Batch 120, Loss = 0.0761 , Rolling Mean Loss = 0.0714 , Batch Accuracy = 81.0
# 	Batch 140, Loss = 0.0523 , Rolling Mean Loss = 0.0744 , Batch Accuracy = 85.25
# 	Batch 160, Loss = 0.0884 , Rolling Mean Loss = 0.0767 , Batch Accuracy = 81.75
# 	Batch 180, Loss = 0.0536 , Rolling Mean Loss = 0.0809 , Batch Accuracy = 84.25
# 	Batch 200, Loss = 0.0829 , Rolling Mean Loss = 0.0839 , Batch Accuracy = 81.25
# 	Batch 220, Loss = 0.0818 , Rolling Mean Loss = 0.0872 , Batch Accuracy = 85.5
# 	Train Accuracy (mean) =  84.04
# 	Test Accuracy         =  40.6
# Epoch 32
# 	Batch   0, Loss = 0.0526 , Rolling Mean Loss = 0.0895 , Batch Accuracy = 86.5
# 	Batch  20, Loss = 0.101 , Rolling Mean Loss = 0.088 , Batch Accuracy = 86.25
# 	Batch  40, Loss = 0.0759 , Rolling Mean Loss = 0.085 , Batch Accuracy = 84.0
# 	Batch  60, Loss = 0.0522 , Rolling Mean Loss = 0.0801 , Batch Accuracy = 87.0
# 	Batch  80, Loss = 0.0696 , Rolling Mean Loss = 0.0764 , Batch Accuracy = 84.5
# 	Batch 100, Loss = 0.0699 , Rolling Mean Loss = 0.0722 , Batch Accuracy = 85.25
# 	Batch 120, Loss = 0.0887 , Rolling Mean Loss = 0.0716 , Batch Accuracy = 83.25
# 	Batch 140, Loss = 0.0926 , Rolling Mean Loss = 0.0721 , Batch Accuracy = 84.0
# 	Batch 160, Loss = 0.0939 , Rolling Mean Loss = 0.0736 , Batch Accuracy = 85.75
# 	Batch 180, Loss = 0.1025 , Rolling Mean Loss = 0.0783 , Batch Accuracy = 84.75
# 	Batch 200, Loss = 0.109 , Rolling Mean Loss = 0.0825 , Batch Accuracy = 83.25
# 	Batch 220, Loss = 0.0897 , Rolling Mean Loss = 0.0896 , Batch Accuracy = 82.5
# 	Train Accuracy (mean) =  83.98
# 	Test Accuracy         =  40.7
# Epoch 33
# 	Batch   0, Loss = 0.0584 , Rolling Mean Loss = 0.0928 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.0564 , Rolling Mean Loss = 0.0916 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.0473 , Rolling Mean Loss = 0.0884 , Batch Accuracy = 86.5
# 	Batch  60, Loss = 0.0797 , Rolling Mean Loss = 0.0831 , Batch Accuracy = 81.75
# 	Batch  80, Loss = 0.0996 , Rolling Mean Loss = 0.0774 , Batch Accuracy = 84.5
# 	Batch 100, Loss = 0.0676 , Rolling Mean Loss = 0.0727 , Batch Accuracy = 84.75
# 	Batch 120, Loss = 0.0625 , Rolling Mean Loss = 0.0723 , Batch Accuracy = 82.0
# 	Batch 140, Loss = 0.0529 , Rolling Mean Loss = 0.0727 , Batch Accuracy = 87.0
# 	Batch 160, Loss = 0.0677 , Rolling Mean Loss = 0.0767 , Batch Accuracy = 83.25
# 	Batch 180, Loss = 0.0825 , Rolling Mean Loss = 0.0803 , Batch Accuracy = 87.75
# 	Batch 200, Loss = 0.072 , Rolling Mean Loss = 0.0832 , Batch Accuracy = 84.25
# 	Batch 220, Loss = 0.1045 , Rolling Mean Loss = 0.0878 , Batch Accuracy = 82.0
# 	Train Accuracy (mean) =  84.1
# 	Test Accuracy         =  40.5
# Epoch 34
# 	Batch   0, Loss = 0.0577 , Rolling Mean Loss = 0.0878 , Batch Accuracy = 83.5
# 	Batch  20, Loss = 0.0604 , Rolling Mean Loss = 0.0845 , Batch Accuracy = 82.5
# 	Batch  40, Loss = 0.0819 , Rolling Mean Loss = 0.0803 , Batch Accuracy = 84.5
# 	Batch  60, Loss = 0.0974 , Rolling Mean Loss = 0.0773 , Batch Accuracy = 83.0
# 	Batch  80, Loss = 0.0511 , Rolling Mean Loss = 0.073 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.075 , Rolling Mean Loss = 0.0696 , Batch Accuracy = 83.75
# 	Batch 120, Loss = 0.0367 , Rolling Mean Loss = 0.0731 , Batch Accuracy = 87.75
# 	Batch 140, Loss = 0.0647 , Rolling Mean Loss = 0.0738 , Batch Accuracy = 83.25
# 	Batch 160, Loss = 0.0459 , Rolling Mean Loss = 0.0746 , Batch Accuracy = 83.75
# 	Batch 180, Loss = 0.092 , Rolling Mean Loss = 0.0782 , Batch Accuracy = 85.25
# 	Batch 200, Loss = 0.1057 , Rolling Mean Loss = 0.082 , Batch Accuracy = 82.75
# 	Batch 220, Loss = 0.0625 , Rolling Mean Loss = 0.084 , Batch Accuracy = 83.75
# 	Train Accuracy (mean) =  84.12
# 	Test Accuracy         =  40.1
# Epoch 35
# 	Batch   0, Loss = 0.0605 , Rolling Mean Loss = 0.086 , Batch Accuracy = 86.25
# 	Batch  20, Loss = 0.0322 , Rolling Mean Loss = 0.0858 , Batch Accuracy = 85.0
# 	Batch  40, Loss = 0.0463 , Rolling Mean Loss = 0.0819 , Batch Accuracy = 85.0
# 	Batch  60, Loss = 0.0573 , Rolling Mean Loss = 0.0737 , Batch Accuracy = 84.5
# 	Batch  80, Loss = 0.0681 , Rolling Mean Loss = 0.0691 , Batch Accuracy = 83.5
# 	Batch 100, Loss = 0.0477 , Rolling Mean Loss = 0.0634 , Batch Accuracy = 83.0
# 	Batch 120, Loss = 0.0543 , Rolling Mean Loss = 0.0619 , Batch Accuracy = 82.5
# 	Batch 140, Loss = 0.0737 , Rolling Mean Loss = 0.0633 , Batch Accuracy = 83.5
# 	Batch 160, Loss = 0.0978 , Rolling Mean Loss = 0.0674 , Batch Accuracy = 83.0
# 	Batch 180, Loss = 0.0818 , Rolling Mean Loss = 0.0697 , Batch Accuracy = 83.5
# 	Batch 200, Loss = 0.0898 , Rolling Mean Loss = 0.0742 , Batch Accuracy = 84.25
# 	Batch 220, Loss = 0.1173 , Rolling Mean Loss = 0.077 , Batch Accuracy = 83.75
# 	Train Accuracy (mean) =  84.25
# 	Test Accuracy         =  42.0
# Epoch 36
# 	Batch   0, Loss = 0.0838 , Rolling Mean Loss = 0.0782 , Batch Accuracy = 86.25
# 	Batch  20, Loss = 0.0499 , Rolling Mean Loss = 0.0742 , Batch Accuracy = 86.25
# 	Batch  40, Loss = 0.0531 , Rolling Mean Loss = 0.0732 , Batch Accuracy = 86.0
# 	Batch  60, Loss = 0.0454 , Rolling Mean Loss = 0.0689 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.0417 , Rolling Mean Loss = 0.0633 , Batch Accuracy = 89.0
# 	Batch 100, Loss = 0.073 , Rolling Mean Loss = 0.0585 , Batch Accuracy = 84.0
# 	Batch 120, Loss = 0.0452 , Rolling Mean Loss = 0.058 , Batch Accuracy = 82.5
# 	Batch 140, Loss = 0.0458 , Rolling Mean Loss = 0.058 , Batch Accuracy = 82.75
# 	Batch 160, Loss = 0.106 , Rolling Mean Loss = 0.0583 , Batch Accuracy = 82.25
# 	Batch 180, Loss = 0.0391 , Rolling Mean Loss = 0.0602 , Batch Accuracy = 85.5
# 	Batch 200, Loss = 0.0864 , Rolling Mean Loss = 0.0643 , Batch Accuracy = 83.0
# 	Batch 220, Loss = 0.0633 , Rolling Mean Loss = 0.0687 , Batch Accuracy = 83.25
# 	Train Accuracy (mean) =  84.55
# 	Test Accuracy         =  40.8
# Epoch 37
# 	Batch   0, Loss = 0.0397 , Rolling Mean Loss = 0.0694 , Batch Accuracy = 84.75
# 	Batch  20, Loss = 0.0325 , Rolling Mean Loss = 0.0676 , Batch Accuracy = 83.75
# 	Batch  40, Loss = 0.0872 , Rolling Mean Loss = 0.0656 , Batch Accuracy = 83.75
# 	Batch  60, Loss = 0.0382 , Rolling Mean Loss = 0.0624 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.0224 , Rolling Mean Loss = 0.0578 , Batch Accuracy = 86.25
# 	Batch 100, Loss = 0.0413 , Rolling Mean Loss = 0.055 , Batch Accuracy = 85.25
# 	Batch 120, Loss = 0.1038 , Rolling Mean Loss = 0.0588 , Batch Accuracy = 82.25
# 	Batch 140, Loss = 0.0481 , Rolling Mean Loss = 0.0599 , Batch Accuracy = 84.75
# 	Batch 160, Loss = 0.0712 , Rolling Mean Loss = 0.0592 , Batch Accuracy = 85.25
# 	Batch 180, Loss = 0.0724 , Rolling Mean Loss = 0.0616 , Batch Accuracy = 84.75
# 	Batch 200, Loss = 0.0469 , Rolling Mean Loss = 0.0642 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.0647 , Rolling Mean Loss = 0.0654 , Batch Accuracy = 83.25
# 	Train Accuracy (mean) =  84.55
# 	Test Accuracy         =  40.6
# Epoch 38
# 	Batch   0, Loss = 0.0503 , Rolling Mean Loss = 0.0674 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.0771 , Rolling Mean Loss = 0.0688 , Batch Accuracy = 85.75
# 	Batch  40, Loss = 0.0538 , Rolling Mean Loss = 0.0666 , Batch Accuracy = 80.5
# 	Batch  60, Loss = 0.0627 , Rolling Mean Loss = 0.0635 , Batch Accuracy = 84.75
# 	Batch  80, Loss = 0.0619 , Rolling Mean Loss = 0.0598 , Batch Accuracy = 85.75
# 	Batch 100, Loss = 0.0987 , Rolling Mean Loss = 0.0548 , Batch Accuracy = 83.5
# 	Batch 120, Loss = 0.0736 , Rolling Mean Loss = 0.0543 , Batch Accuracy = 82.75
# 	Batch 140, Loss = 0.0947 , Rolling Mean Loss = 0.056 , Batch Accuracy = 83.0
# 	Batch 160, Loss = 0.0687 , Rolling Mean Loss = 0.059 , Batch Accuracy = 83.75
# 	Batch 180, Loss = 0.0447 , Rolling Mean Loss = 0.0627 , Batch Accuracy = 88.5
# 	Batch 200, Loss = 0.0519 , Rolling Mean Loss = 0.0675 , Batch Accuracy = 82.25
# 	Batch 220, Loss = 0.0703 , Rolling Mean Loss = 0.0704 , Batch Accuracy = 84.0
# 	Train Accuracy (mean) =  84.57
# 	Test Accuracy         =  39.2
# Epoch 39
# 	Batch   0, Loss = 0.0686 , Rolling Mean Loss = 0.0718 , Batch Accuracy = 85.5
# 	Batch  20, Loss = 0.0684 , Rolling Mean Loss = 0.0712 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.0354 , Rolling Mean Loss = 0.069 , Batch Accuracy = 84.5
# 	Batch  60, Loss = 0.0276 , Rolling Mean Loss = 0.0653 , Batch Accuracy = 87.0
# 	Batch  80, Loss = 0.0534 , Rolling Mean Loss = 0.0618 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.051 , Rolling Mean Loss = 0.0584 , Batch Accuracy = 83.25
# 	Batch 120, Loss = 0.0751 , Rolling Mean Loss = 0.0589 , Batch Accuracy = 83.25
# 	Batch 140, Loss = 0.1163 , Rolling Mean Loss = 0.0604 , Batch Accuracy = 83.0
# 	Batch 160, Loss = 0.0589 , Rolling Mean Loss = 0.0619 , Batch Accuracy = 85.75
# 	Batch 180, Loss = 0.0768 , Rolling Mean Loss = 0.0671 , Batch Accuracy = 82.5
# 	Batch 200, Loss = 0.0714 , Rolling Mean Loss = 0.0711 , Batch Accuracy = 84.25
# 	Batch 220, Loss = 0.0678 , Rolling Mean Loss = 0.0745 , Batch Accuracy = 84.0
# 	Train Accuracy (mean) =  84.42
# 	Test Accuracy         =  40.7
# Epoch 40
# 	Batch   0, Loss = 0.0538 , Rolling Mean Loss = 0.0758 , Batch Accuracy = 84.25
# 	Batch  20, Loss = 0.021 , Rolling Mean Loss = 0.0725 , Batch Accuracy = 84.75
# 	Batch  40, Loss = 0.0449 , Rolling Mean Loss = 0.0705 , Batch Accuracy = 83.75
# 	Batch  60, Loss = 0.0561 , Rolling Mean Loss = 0.0636 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.0395 , Rolling Mean Loss = 0.0578 , Batch Accuracy = 85.5
# 	Batch 100, Loss = 0.0603 , Rolling Mean Loss = 0.0541 , Batch Accuracy = 83.5
# 	Batch 120, Loss = 0.0506 , Rolling Mean Loss = 0.0561 , Batch Accuracy = 84.0
# 	Batch 140, Loss = 0.0173 , Rolling Mean Loss = 0.0561 , Batch Accuracy = 86.25
# 	Batch 160, Loss = 0.0469 , Rolling Mean Loss = 0.0594 , Batch Accuracy = 83.25
# 	Batch 180, Loss = 0.0909 , Rolling Mean Loss = 0.0618 , Batch Accuracy = 81.0
# 	Batch 200, Loss = 0.1418 , Rolling Mean Loss = 0.0645 , Batch Accuracy = 80.5
# 	Batch 220, Loss = 0.0398 , Rolling Mean Loss = 0.0675 , Batch Accuracy = 84.0
# 	Train Accuracy (mean) =  84.59
# 	Test Accuracy         =  40.9
# Epoch 41
# 	Batch   0, Loss = 0.0937 , Rolling Mean Loss = 0.0697 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0413 , Rolling Mean Loss = 0.0698 , Batch Accuracy = 84.25
# 	Batch  40, Loss = 0.0506 , Rolling Mean Loss = 0.0688 , Batch Accuracy = 83.75
# 	Batch  60, Loss = 0.0374 , Rolling Mean Loss = 0.0654 , Batch Accuracy = 82.0
# 	Batch  80, Loss = 0.0437 , Rolling Mean Loss = 0.0601 , Batch Accuracy = 85.5
# 	Batch 100, Loss = 0.0318 , Rolling Mean Loss = 0.0507 , Batch Accuracy = 87.75
# 	Batch 120, Loss = 0.0416 , Rolling Mean Loss = 0.0497 , Batch Accuracy = 87.75
# 	Batch 140, Loss = 0.027 , Rolling Mean Loss = 0.0493 , Batch Accuracy = 85.0
# 	Batch 160, Loss = 0.0959 , Rolling Mean Loss = 0.0527 , Batch Accuracy = 80.0
# 	Batch 180, Loss = 0.0915 , Rolling Mean Loss = 0.0554 , Batch Accuracy = 83.75
# 	Batch 200, Loss = 0.0751 , Rolling Mean Loss = 0.0596 , Batch Accuracy = 84.0
# 	Batch 220, Loss = 0.0465 , Rolling Mean Loss = 0.0616 , Batch Accuracy = 86.75
# 	Train Accuracy (mean) =  84.72
# 	Test Accuracy         =  39.9
# Epoch 42
# 	Batch   0, Loss = 0.13 , Rolling Mean Loss = 0.0634 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.0603 , Rolling Mean Loss = 0.0648 , Batch Accuracy = 83.0
# 	Batch  40, Loss = 0.1025 , Rolling Mean Loss = 0.0613 , Batch Accuracy = 82.75
# 	Batch  60, Loss = 0.0279 , Rolling Mean Loss = 0.0576 , Batch Accuracy = 86.25
# 	Batch  80, Loss = 0.0366 , Rolling Mean Loss = 0.0538 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0249 , Rolling Mean Loss = 0.0486 , Batch Accuracy = 87.5
# 	Batch 120, Loss = 0.0728 , Rolling Mean Loss = 0.0467 , Batch Accuracy = 83.5
# 	Batch 140, Loss = 0.0324 , Rolling Mean Loss = 0.0486 , Batch Accuracy = 88.0
# 	Batch 160, Loss = 0.0691 , Rolling Mean Loss = 0.0518 , Batch Accuracy = 83.5
# 	Batch 180, Loss = 0.0563 , Rolling Mean Loss = 0.0552 , Batch Accuracy = 84.25
# 	Batch 200, Loss = 0.0555 , Rolling Mean Loss = 0.0593 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0912 , Rolling Mean Loss = 0.0646 , Batch Accuracy = 82.75
# 	Train Accuracy (mean) =  84.71
# 	Test Accuracy         =  38.7
# Epoch 43
# 	Batch   0, Loss = 0.0913 , Rolling Mean Loss = 0.0668 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.0355 , Rolling Mean Loss = 0.0693 , Batch Accuracy = 85.5
# 	Batch  40, Loss = 0.0376 , Rolling Mean Loss = 0.0698 , Batch Accuracy = 82.25
# 	Batch  60, Loss = 0.0348 , Rolling Mean Loss = 0.0658 , Batch Accuracy = 84.75
# 	Batch  80, Loss = 0.046 , Rolling Mean Loss = 0.0636 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0563 , Rolling Mean Loss = 0.0568 , Batch Accuracy = 80.5
# 	Batch 120, Loss = 0.067 , Rolling Mean Loss = 0.0536 , Batch Accuracy = 85.0
# 	Batch 140, Loss = 0.0756 , Rolling Mean Loss = 0.0513 , Batch Accuracy = 83.5
# 	Batch 160, Loss = 0.0668 , Rolling Mean Loss = 0.0537 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0513 , Rolling Mean Loss = 0.0543 , Batch Accuracy = 84.0
# 	Batch 200, Loss = 0.0535 , Rolling Mean Loss = 0.0578 , Batch Accuracy = 85.75
# 	Batch 220, Loss = 0.0963 , Rolling Mean Loss = 0.0604 , Batch Accuracy = 81.75
# 	Train Accuracy (mean) =  84.68
# 	Test Accuracy         =  40.2
# Epoch 44
# 	Batch   0, Loss = 0.0572 , Rolling Mean Loss = 0.0614 , Batch Accuracy = 85.5
# 	Batch  20, Loss = 0.0127 , Rolling Mean Loss = 0.06 , Batch Accuracy = 86.75
# 	Batch  40, Loss = 0.0297 , Rolling Mean Loss = 0.0549 , Batch Accuracy = 87.25
# 	Batch  60, Loss = 0.047 , Rolling Mean Loss = 0.0531 , Batch Accuracy = 84.5
# 	Batch  80, Loss = 0.0405 , Rolling Mean Loss = 0.0499 , Batch Accuracy = 85.5
# 	Batch 100, Loss = 0.0364 , Rolling Mean Loss = 0.0464 , Batch Accuracy = 87.75
# 	Batch 120, Loss = 0.04 , Rolling Mean Loss = 0.047 , Batch Accuracy = 85.25
# 	Batch 140, Loss = 0.099 , Rolling Mean Loss = 0.052 , Batch Accuracy = 82.5
# 	Batch 160, Loss = 0.0624 , Rolling Mean Loss = 0.0546 , Batch Accuracy = 83.75
# 	Batch 180, Loss = 0.0423 , Rolling Mean Loss = 0.0558 , Batch Accuracy = 87.0
# 	Batch 200, Loss = 0.0636 , Rolling Mean Loss = 0.0582 , Batch Accuracy = 83.75
# 	Batch 220, Loss = 0.113 , Rolling Mean Loss = 0.0638 , Batch Accuracy = 82.0
# 	Train Accuracy (mean) =  84.75
# 	Test Accuracy         =  40.2
# Epoch 45
# 	Batch   0, Loss = 0.0285 , Rolling Mean Loss = 0.0645 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.0476 , Rolling Mean Loss = 0.0618 , Batch Accuracy = 82.75
# 	Batch  40, Loss = 0.0852 , Rolling Mean Loss = 0.0603 , Batch Accuracy = 84.25
# 	Batch  60, Loss = 0.0331 , Rolling Mean Loss = 0.0586 , Batch Accuracy = 85.25
# 	Batch  80, Loss = 0.0475 , Rolling Mean Loss = 0.0573 , Batch Accuracy = 85.25
# 	Batch 100, Loss = 0.0597 , Rolling Mean Loss = 0.0531 , Batch Accuracy = 85.75
# 	Batch 120, Loss = 0.0452 , Rolling Mean Loss = 0.0549 , Batch Accuracy = 85.0
# 	Batch 140, Loss = 0.0585 , Rolling Mean Loss = 0.0567 , Batch Accuracy = 86.5
# 	Batch 160, Loss = 0.0326 , Rolling Mean Loss = 0.0598 , Batch Accuracy = 84.5
# 	Batch 180, Loss = 0.0817 , Rolling Mean Loss = 0.0613 , Batch Accuracy = 81.75
# 	Batch 200, Loss = 0.0539 , Rolling Mean Loss = 0.0614 , Batch Accuracy = 87.75
# 	Batch 220, Loss = 0.0544 , Rolling Mean Loss = 0.0638 , Batch Accuracy = 85.0
# 	Train Accuracy (mean) =  84.64
# 	Test Accuracy         =  40.6
# Epoch 46
# 	Batch   0, Loss = 0.0395 , Rolling Mean Loss = 0.0642 , Batch Accuracy = 89.75
# 	Batch  20, Loss = 0.0221 , Rolling Mean Loss = 0.0599 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.0431 , Rolling Mean Loss = 0.0565 , Batch Accuracy = 85.25
# 	Batch  60, Loss = 0.0639 , Rolling Mean Loss = 0.054 , Batch Accuracy = 84.25
# 	Batch  80, Loss = 0.0871 , Rolling Mean Loss = 0.0489 , Batch Accuracy = 82.75
# 	Batch 100, Loss = 0.0507 , Rolling Mean Loss = 0.0481 , Batch Accuracy = 83.25
# 	Batch 120, Loss = 0.0576 , Rolling Mean Loss = 0.0502 , Batch Accuracy = 84.5
# 	Batch 140, Loss = 0.0516 , Rolling Mean Loss = 0.0505 , Batch Accuracy = 86.5
# 	Batch 160, Loss = 0.0469 , Rolling Mean Loss = 0.0525 , Batch Accuracy = 82.75
# 	Batch 180, Loss = 0.0559 , Rolling Mean Loss = 0.0537 , Batch Accuracy = 87.25
# 	Batch 200, Loss = 0.0608 , Rolling Mean Loss = 0.0537 , Batch Accuracy = 82.5
# ...
# 	Batch 140, Loss = 0.0216 , Rolling Mean Loss = 0.0212 , Batch Accuracy = 83.75
# 	Batch 160, Loss = 0.0092 , Rolling Mean Loss = 0.0214 , Batch Accuracy = 85.0
# 	Batch 180, Loss = 0.0288 , Rolling Mean Loss = 0.0229 , Batch Accuracy = 84.5
# 	Batch 200, Loss = 0.0164 , Rolling Mean Loss = 0.0271 , Batch Accuracy = 83.0
# 	Batch 220, Loss = 0.0428 , Rolling Mean Loss = 0.0297 , Batch Accuracy = 82.25
# 	Train Accuracy (mean) =  85.62
# 	Test Accuracy         =  40.1
# Epoch 85
# 	Batch   0, Loss = 0.009 , Rolling Mean Loss = 0.0299 , Batch Accuracy = 84.75
# 	Batch  20, Loss = 0.0151 , Rolling Mean Loss = 0.0295 , Batch Accuracy = 86.5
# 	Batch  40, Loss = 0.0584 , Rolling Mean Loss = 0.0315 , Batch Accuracy = 84.75
# 	Batch  60, Loss = 0.0323 , Rolling Mean Loss = 0.0293 , Batch Accuracy = 84.0
# 	Batch  80, Loss = 0.0079 , Rolling Mean Loss = 0.0271 , Batch Accuracy = 83.75
# 	Batch 100, Loss = 0.0247 , Rolling Mean Loss = 0.027 , Batch Accuracy = 83.75
# 	Batch 120, Loss = 0.0401 , Rolling Mean Loss = 0.0268 , Batch Accuracy = 88.25
# 	Batch 140, Loss = 0.0094 , Rolling Mean Loss = 0.0249 , Batch Accuracy = 84.75
# 	Batch 160, Loss = 0.0254 , Rolling Mean Loss = 0.0252 , Batch Accuracy = 84.25
# 	Batch 180, Loss = 0.0537 , Rolling Mean Loss = 0.0273 , Batch Accuracy = 83.75
# 	Batch 200, Loss = 0.0123 , Rolling Mean Loss = 0.029 , Batch Accuracy = 87.25
# 	Batch 220, Loss = 0.0249 , Rolling Mean Loss = 0.0301 , Batch Accuracy = 86.5
# 	Train Accuracy (mean) =  85.52
# 	Test Accuracy         =  40.7
# Epoch 86
# 	Batch   0, Loss = 0.0101 , Rolling Mean Loss = 0.0302 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0061 , Rolling Mean Loss = 0.0295 , Batch Accuracy = 83.25
# 	Batch  40, Loss = 0.0233 , Rolling Mean Loss = 0.0286 , Batch Accuracy = 88.25
# 	Batch  60, Loss = 0.0189 , Rolling Mean Loss = 0.0252 , Batch Accuracy = 86.5
# 	Batch  80, Loss = 0.006 , Rolling Mean Loss = 0.0222 , Batch Accuracy = 88.0
# 	Batch 100, Loss = 0.036 , Rolling Mean Loss = 0.0222 , Batch Accuracy = 87.5
# 	Batch 120, Loss = 0.0179 , Rolling Mean Loss = 0.0234 , Batch Accuracy = 83.25
# 	Batch 140, Loss = 0.049 , Rolling Mean Loss = 0.0237 , Batch Accuracy = 81.25
# 	Batch 160, Loss = 0.012 , Rolling Mean Loss = 0.0242 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0128 , Rolling Mean Loss = 0.0273 , Batch Accuracy = 85.5
# 	Batch 200, Loss = 0.0784 , Rolling Mean Loss = 0.0282 , Batch Accuracy = 85.5
# 	Batch 220, Loss = 0.0629 , Rolling Mean Loss = 0.0319 , Batch Accuracy = 84.25
# 	Train Accuracy (mean) =  85.57
# 	Test Accuracy         =  40.0
# Epoch 87
# 	Batch   0, Loss = 0.029 , Rolling Mean Loss = 0.0345 , Batch Accuracy = 82.25
# 	Batch  20, Loss = 0.0264 , Rolling Mean Loss = 0.0346 , Batch Accuracy = 85.0
# 	Batch  40, Loss = 0.033 , Rolling Mean Loss = 0.0337 , Batch Accuracy = 84.75
# 	Batch  60, Loss = 0.0351 , Rolling Mean Loss = 0.0322 , Batch Accuracy = 83.75
# 	Batch  80, Loss = 0.033 , Rolling Mean Loss = 0.0318 , Batch Accuracy = 82.25
# 	Batch 100, Loss = 0.0113 , Rolling Mean Loss = 0.0286 , Batch Accuracy = 85.0
# 	Batch 120, Loss = 0.0596 , Rolling Mean Loss = 0.0311 , Batch Accuracy = 84.5
# 	Batch 140, Loss = 0.0423 , Rolling Mean Loss = 0.0323 , Batch Accuracy = 87.0
# 	Batch 160, Loss = 0.0341 , Rolling Mean Loss = 0.0362 , Batch Accuracy = 85.25
# 	Batch 180, Loss = 0.0196 , Rolling Mean Loss = 0.0387 , Batch Accuracy = 88.25
# 	Batch 200, Loss = 0.039 , Rolling Mean Loss = 0.0411 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.054 , Rolling Mean Loss = 0.0417 , Batch Accuracy = 85.75
# 	Train Accuracy (mean) =  85.31
# 	Test Accuracy         =  38.8
# Epoch 88
# 	Batch   0, Loss = 0.0408 , Rolling Mean Loss = 0.0425 , Batch Accuracy = 85.0
# 	Batch  20, Loss = 0.0439 , Rolling Mean Loss = 0.0402 , Batch Accuracy = 83.25
# 	Batch  40, Loss = 0.052 , Rolling Mean Loss = 0.0393 , Batch Accuracy = 85.25
# 	Batch  60, Loss = 0.0328 , Rolling Mean Loss = 0.0377 , Batch Accuracy = 86.5
# 	Batch  80, Loss = 0.0556 , Rolling Mean Loss = 0.0349 , Batch Accuracy = 87.25
# 	Batch 100, Loss = 0.0307 , Rolling Mean Loss = 0.0326 , Batch Accuracy = 86.25
# 	Batch 120, Loss = 0.0364 , Rolling Mean Loss = 0.0342 , Batch Accuracy = 85.75
# 	Batch 140, Loss = 0.0336 , Rolling Mean Loss = 0.0351 , Batch Accuracy = 84.5
# 	Batch 160, Loss = 0.041 , Rolling Mean Loss = 0.0355 , Batch Accuracy = 86.75
# 	Batch 180, Loss = 0.0282 , Rolling Mean Loss = 0.0385 , Batch Accuracy = 84.0
# 	Batch 200, Loss = 0.0278 , Rolling Mean Loss = 0.0409 , Batch Accuracy = 85.5
# 	Batch 220, Loss = 0.035 , Rolling Mean Loss = 0.0423 , Batch Accuracy = 82.5
# 	Train Accuracy (mean) =  85.32
# 	Test Accuracy         =  39.9
# Epoch 89
# 	Batch   0, Loss = 0.0209 , Rolling Mean Loss = 0.0419 , Batch Accuracy = 88.25
# 	Batch  20, Loss = 0.0276 , Rolling Mean Loss = 0.0427 , Batch Accuracy = 85.75
# 	Batch  40, Loss = 0.0313 , Rolling Mean Loss = 0.0398 , Batch Accuracy = 85.75
# 	Batch  60, Loss = 0.0842 , Rolling Mean Loss = 0.0377 , Batch Accuracy = 84.5
# 	Batch  80, Loss = 0.0137 , Rolling Mean Loss = 0.0345 , Batch Accuracy = 85.25
# 	Batch 100, Loss = 0.0158 , Rolling Mean Loss = 0.0323 , Batch Accuracy = 85.0
# 	Batch 120, Loss = 0.0744 , Rolling Mean Loss = 0.03 , Batch Accuracy = 85.0
# 	Batch 140, Loss = 0.0793 , Rolling Mean Loss = 0.0318 , Batch Accuracy = 85.75
# 	Batch 160, Loss = 0.0407 , Rolling Mean Loss = 0.033 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.023 , Rolling Mean Loss = 0.0346 , Batch Accuracy = 87.0
# 	Batch 200, Loss = 0.04 , Rolling Mean Loss = 0.0356 , Batch Accuracy = 89.75
# 	Batch 220, Loss = 0.0254 , Rolling Mean Loss = 0.0386 , Batch Accuracy = 86.25
# 	Train Accuracy (mean) =  85.4
# 	Test Accuracy         =  40.3
# Epoch 90
# 	Batch   0, Loss = 0.0445 , Rolling Mean Loss = 0.0397 , Batch Accuracy = 83.5
# 	Batch  20, Loss = 0.0495 , Rolling Mean Loss = 0.0379 , Batch Accuracy = 88.25
# 	Batch  40, Loss = 0.0523 , Rolling Mean Loss = 0.0373 , Batch Accuracy = 85.5
# 	Batch  60, Loss = 0.0082 , Rolling Mean Loss = 0.0341 , Batch Accuracy = 86.25
# 	Batch  80, Loss = 0.0339 , Rolling Mean Loss = 0.0314 , Batch Accuracy = 81.75
# 	Batch 100, Loss = 0.006 , Rolling Mean Loss = 0.0263 , Batch Accuracy = 84.25
# 	Batch 120, Loss = 0.0295 , Rolling Mean Loss = 0.0249 , Batch Accuracy = 85.5
# 	Batch 140, Loss = 0.0084 , Rolling Mean Loss = 0.0241 , Batch Accuracy = 87.25
# 	Batch 160, Loss = 0.029 , Rolling Mean Loss = 0.0249 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0585 , Rolling Mean Loss = 0.0252 , Batch Accuracy = 86.5
# 	Batch 200, Loss = 0.0087 , Rolling Mean Loss = 0.0253 , Batch Accuracy = 86.0
# 	Batch 220, Loss = 0.0311 , Rolling Mean Loss = 0.0266 , Batch Accuracy = 81.75
# 	Train Accuracy (mean) =  85.55
# 	Test Accuracy         =  39.2
# Epoch 91
# 	Batch   0, Loss = 0.0192 , Rolling Mean Loss = 0.0275 , Batch Accuracy = 85.25
# 	Batch  20, Loss = 0.0339 , Rolling Mean Loss = 0.026 , Batch Accuracy = 86.25
# 	Batch  40, Loss = 0.0206 , Rolling Mean Loss = 0.0248 , Batch Accuracy = 82.75
# 	Batch  60, Loss = 0.0111 , Rolling Mean Loss = 0.0228 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.0093 , Rolling Mean Loss = 0.0213 , Batch Accuracy = 86.25
# 	Batch 100, Loss = 0.0222 , Rolling Mean Loss = 0.0174 , Batch Accuracy = 87.0
# 	Batch 120, Loss = 0.0217 , Rolling Mean Loss = 0.0175 , Batch Accuracy = 86.5
# 	Batch 140, Loss = 0.0115 , Rolling Mean Loss = 0.0172 , Batch Accuracy = 86.75
# 	Batch 160, Loss = 0.0153 , Rolling Mean Loss = 0.0184 , Batch Accuracy = 88.0
# 	Batch 180, Loss = 0.0145 , Rolling Mean Loss = 0.0192 , Batch Accuracy = 87.5
# 	Batch 200, Loss = 0.0101 , Rolling Mean Loss = 0.0212 , Batch Accuracy = 81.75
# 	Batch 220, Loss = 0.0092 , Rolling Mean Loss = 0.0216 , Batch Accuracy = 90.25
# 	Train Accuracy (mean) =  85.76
# 	Test Accuracy         =  39.5
# Epoch 92
# 	Batch   0, Loss = 0.0194 , Rolling Mean Loss = 0.0226 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.027 , Rolling Mean Loss = 0.0222 , Batch Accuracy = 81.5
# 	Batch  40, Loss = 0.007 , Rolling Mean Loss = 0.0215 , Batch Accuracy = 83.5
# 	Batch  60, Loss = 0.0041 , Rolling Mean Loss = 0.0202 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.0381 , Rolling Mean Loss = 0.0201 , Batch Accuracy = 88.25
# 	Batch 100, Loss = 0.0145 , Rolling Mean Loss = 0.0185 , Batch Accuracy = 87.75
# 	Batch 120, Loss = 0.0458 , Rolling Mean Loss = 0.0192 , Batch Accuracy = 84.0
# 	Batch 140, Loss = 0.0732 , Rolling Mean Loss = 0.0196 , Batch Accuracy = 83.25
# 	Batch 160, Loss = 0.0334 , Rolling Mean Loss = 0.0212 , Batch Accuracy = 83.25
# 	Batch 180, Loss = 0.0566 , Rolling Mean Loss = 0.0219 , Batch Accuracy = 84.25
# 	Batch 200, Loss = 0.0439 , Rolling Mean Loss = 0.0248 , Batch Accuracy = 82.75
# 	Batch 220, Loss = 0.0096 , Rolling Mean Loss = 0.0258 , Batch Accuracy = 83.0
# 	Train Accuracy (mean) =  85.69
# 	Test Accuracy         =  39.1
# Epoch 93
# 	Batch   0, Loss = 0.0211 , Rolling Mean Loss = 0.0262 , Batch Accuracy = 88.0
# 	Batch  20, Loss = 0.0058 , Rolling Mean Loss = 0.0244 , Batch Accuracy = 85.25
# 	Batch  40, Loss = 0.0184 , Rolling Mean Loss = 0.022 , Batch Accuracy = 84.5
# 	Batch  60, Loss = 0.0129 , Rolling Mean Loss = 0.0184 , Batch Accuracy = 83.0
# 	Batch  80, Loss = 0.0061 , Rolling Mean Loss = 0.0155 , Batch Accuracy = 88.5
# 	Batch 100, Loss = 0.0051 , Rolling Mean Loss = 0.015 , Batch Accuracy = 87.5
# 	Batch 120, Loss = 0.004 , Rolling Mean Loss = 0.0147 , Batch Accuracy = 86.5
# 	Batch 140, Loss = 0.0203 , Rolling Mean Loss = 0.0156 , Batch Accuracy = 85.25
# 	Batch 160, Loss = 0.0108 , Rolling Mean Loss = 0.0154 , Batch Accuracy = 85.0
# 	Batch 180, Loss = 0.0204 , Rolling Mean Loss = 0.0164 , Batch Accuracy = 87.75
# 	Batch 200, Loss = 0.017 , Rolling Mean Loss = 0.0169 , Batch Accuracy = 86.0
# 	Batch 220, Loss = 0.0465 , Rolling Mean Loss = 0.0182 , Batch Accuracy = 85.0
# 	Train Accuracy (mean) =  85.83
# 	Test Accuracy         =  39.6
# Epoch 94
# 	Batch   0, Loss = 0.0035 , Rolling Mean Loss = 0.0191 , Batch Accuracy = 89.5
# 	Batch  20, Loss = 0.0121 , Rolling Mean Loss = 0.0189 , Batch Accuracy = 84.75
# 	Batch  40, Loss = 0.0499 , Rolling Mean Loss = 0.0194 , Batch Accuracy = 85.0
# 	Batch  60, Loss = 0.0497 , Rolling Mean Loss = 0.0196 , Batch Accuracy = 86.5
# 	Batch  80, Loss = 0.006 , Rolling Mean Loss = 0.0191 , Batch Accuracy = 86.0
# 	Batch 100, Loss = 0.0143 , Rolling Mean Loss = 0.018 , Batch Accuracy = 87.25
# 	Batch 120, Loss = 0.01 , Rolling Mean Loss = 0.0184 , Batch Accuracy = 86.25
# 	Batch 140, Loss = 0.0223 , Rolling Mean Loss = 0.02 , Batch Accuracy = 86.0
# 	Batch 160, Loss = 0.0333 , Rolling Mean Loss = 0.0205 , Batch Accuracy = 82.75
# 	Batch 180, Loss = 0.0284 , Rolling Mean Loss = 0.0223 , Batch Accuracy = 87.5
# 	Batch 200, Loss = 0.0261 , Rolling Mean Loss = 0.0244 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0755 , Rolling Mean Loss = 0.0277 , Batch Accuracy = 83.5
# 	Train Accuracy (mean) =  85.68
# 	Test Accuracy         =  38.1
# Epoch 95
# 	Batch   0, Loss = 0.0177 , Rolling Mean Loss = 0.0284 , Batch Accuracy = 87.25
# 	Batch  20, Loss = 0.0483 , Rolling Mean Loss = 0.0286 , Batch Accuracy = 85.25
# 	Batch  40, Loss = 0.0043 , Rolling Mean Loss = 0.0306 , Batch Accuracy = 86.0
# 	Batch  60, Loss = 0.0187 , Rolling Mean Loss = 0.0292 , Batch Accuracy = 84.75
# 	Batch  80, Loss = 0.007 , Rolling Mean Loss = 0.0294 , Batch Accuracy = 86.5
# 	Batch 100, Loss = 0.0291 , Rolling Mean Loss = 0.028 , Batch Accuracy = 87.0
# 	Batch 120, Loss = 0.0207 , Rolling Mean Loss = 0.0294 , Batch Accuracy = 84.5
# 	Batch 140, Loss = 0.019 , Rolling Mean Loss = 0.0289 , Batch Accuracy = 83.75
# 	Batch 160, Loss = 0.0493 , Rolling Mean Loss = 0.0295 , Batch Accuracy = 86.75
# 	Batch 180, Loss = 0.0326 , Rolling Mean Loss = 0.0305 , Batch Accuracy = 83.25
# 	Batch 200, Loss = 0.0506 , Rolling Mean Loss = 0.0306 , Batch Accuracy = 84.5
# 	Batch 220, Loss = 0.0533 , Rolling Mean Loss = 0.0318 , Batch Accuracy = 82.75
# 	Train Accuracy (mean) =  85.49
# 	Test Accuracy         =  40.3
# Epoch 96
# 	Batch   0, Loss = 0.034 , Rolling Mean Loss = 0.0321 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0499 , Rolling Mean Loss = 0.0312 , Batch Accuracy = 85.0
# 	Batch  40, Loss = 0.0389 , Rolling Mean Loss = 0.0318 , Batch Accuracy = 88.25
# 	Batch  60, Loss = 0.0128 , Rolling Mean Loss = 0.0304 , Batch Accuracy = 86.75
# 	Batch  80, Loss = 0.0584 , Rolling Mean Loss = 0.0289 , Batch Accuracy = 85.25
# 	Batch 100, Loss = 0.0219 , Rolling Mean Loss = 0.0278 , Batch Accuracy = 86.75
# 	Batch 120, Loss = 0.015 , Rolling Mean Loss = 0.0298 , Batch Accuracy = 87.75
# 	Batch 140, Loss = 0.0244 , Rolling Mean Loss = 0.0306 , Batch Accuracy = 86.75
# 	Batch 160, Loss = 0.0415 , Rolling Mean Loss = 0.0316 , Batch Accuracy = 86.0
# 	Batch 180, Loss = 0.0186 , Rolling Mean Loss = 0.0324 , Batch Accuracy = 88.25
# 	Batch 200, Loss = 0.0203 , Rolling Mean Loss = 0.0328 , Batch Accuracy = 84.75
# 	Batch 220, Loss = 0.0268 , Rolling Mean Loss = 0.0329 , Batch Accuracy = 85.0
# 	Train Accuracy (mean) =  85.4
# 	Test Accuracy         =  40.0
# Epoch 97
# 	Batch   0, Loss = 0.0403 , Rolling Mean Loss = 0.0348 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.028 , Rolling Mean Loss = 0.0338 , Batch Accuracy = 84.5
# 	Batch  40, Loss = 0.0268 , Rolling Mean Loss = 0.0348 , Batch Accuracy = 86.75
# 	Batch  60, Loss = 0.03 , Rolling Mean Loss = 0.0365 , Batch Accuracy = 85.5
# 	Batch  80, Loss = 0.0415 , Rolling Mean Loss = 0.036 , Batch Accuracy = 84.25
# 	Batch 100, Loss = 0.0663 , Rolling Mean Loss = 0.0346 , Batch Accuracy = 82.5
# 	Batch 120, Loss = 0.0143 , Rolling Mean Loss = 0.0352 , Batch Accuracy = 88.25
# 	Batch 140, Loss = 0.0198 , Rolling Mean Loss = 0.035 , Batch Accuracy = 85.75
# 	Batch 160, Loss = 0.0271 , Rolling Mean Loss = 0.0354 , Batch Accuracy = 87.75
# 	Batch 180, Loss = 0.0577 , Rolling Mean Loss = 0.0364 , Batch Accuracy = 84.75
# 	Batch 200, Loss = 0.0854 , Rolling Mean Loss = 0.0377 , Batch Accuracy = 82.5
# 	Batch 220, Loss = 0.0367 , Rolling Mean Loss = 0.0396 , Batch Accuracy = 84.75
# 	Train Accuracy (mean) =  85.28
# 	Test Accuracy         =  40.1
# Epoch 98
# 	Batch   0, Loss = 0.0117 , Rolling Mean Loss = 0.0406 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0207 , Rolling Mean Loss = 0.0395 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.0112 , Rolling Mean Loss = 0.038 , Batch Accuracy = 86.75
# 	Batch  60, Loss = 0.0068 , Rolling Mean Loss = 0.0353 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.003 , Rolling Mean Loss = 0.0335 , Batch Accuracy = 85.25
# 	Batch 100, Loss = 0.0565 , Rolling Mean Loss = 0.0306 , Batch Accuracy = 83.25
# 	Batch 120, Loss = 0.0306 , Rolling Mean Loss = 0.0297 , Batch Accuracy = 85.0
# 	Batch 140, Loss = 0.0276 , Rolling Mean Loss = 0.0301 , Batch Accuracy = 87.75
# 	Batch 160, Loss = 0.0432 , Rolling Mean Loss = 0.0305 , Batch Accuracy = 85.5
# 	Batch 180, Loss = 0.0142 , Rolling Mean Loss = 0.0308 , Batch Accuracy = 84.0
# 	Batch 200, Loss = 0.0853 , Rolling Mean Loss = 0.0317 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0329 , Rolling Mean Loss = 0.0317 , Batch Accuracy = 84.5
# 	Train Accuracy (mean) =  85.44
# 	Test Accuracy         =  38.0
# Epoch 99
# 	Batch   0, Loss = 0.0174 , Rolling Mean Loss = 0.0318 , Batch Accuracy = 83.0
# 	Batch  20, Loss = 0.0082 , Rolling Mean Loss = 0.031 , Batch Accuracy = 83.5
# 	Batch  40, Loss = 0.0329 , Rolling Mean Loss = 0.0281 , Batch Accuracy = 87.5
# 	Batch  60, Loss = 0.0177 , Rolling Mean Loss = 0.0256 , Batch Accuracy = 82.25
# 	Batch  80, Loss = 0.0226 , Rolling Mean Loss = 0.0243 , Batch Accuracy = 85.75
# 	Batch 100, Loss = 0.0156 , Rolling Mean Loss = 0.0217 , Batch Accuracy = 86.5
# 	Batch 120, Loss = 0.0103 , Rolling Mean Loss = 0.0213 , Batch Accuracy = 86.0
# 	Batch 140, Loss = 0.0271 , Rolling Mean Loss = 0.0217 , Batch Accuracy = 87.5
# 	Batch 160, Loss = 0.005 , Rolling Mean Loss = 0.0209 , Batch Accuracy = 86.5
# 	Batch 180, Loss = 0.0128 , Rolling Mean Loss = 0.0204 , Batch Accuracy = 84.0
# 	Batch 200, Loss = 0.009 , Rolling Mean Loss = 0.0213 , Batch Accuracy = 86.75
# 	Batch 220, Loss = 0.0266 , Rolling Mean Loss = 0.022 , Batch Accuracy = 86.25
# 	Train Accuracy (mean) =  85.71
# 	Test Accuracy         =  39.3
#
# Final Loss = 0.0156
# Final Rolling Loss = 0.0225
#
# Final Test Accuracy  = 39.30%
# Final Train Accuracy = 85.96%
#
# Running Time = 34 min, 25 sec.

# %%
import pandas as pd

df = pd.DataFrame(L)
Lmean = df.rolling(100).mean().values

plt.figure(figsize=(15,7.5))
plt.title('Model Loss During Training')
plt.scatter(range(len(L)),L,5,alpha=.5,color='C1',label='Loss')
plt.scatter(range(len(Lmean)),Lmean,1,color='C0',label='Loss (100 Iteration Rolling Mean)')
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.ylim([-0.1,5])
plt.legend()
#plt.show()

plt.savefig('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/ResNet_ReLU_hidden0_noActivationEmbeddig_Loss.png')

# %%
plt.figure(figsize=(15,7.5))
plt.title('Model Loss During Training')
plt.plot(range(len(L[::228])),L[::228],color='C0',label='Traing Loss')
plt.plot(range(len(test_epoch_loss)),test_epoch_loss,color='C1',label='Test Loss')
plt.ylabel('Loss')
plt.xlabel('Iteration')
#plt.ylim([0,5])
plt.legend()
#plt.show()

print(final_train_loss)
print(final_test_loss)

plt.savefig('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/ResNet_ReLU_hidden0_noActivationEmbeddig_Losses.png')
# Out:
# 0.013423340434408664
# 6.573654651641846

# %%
plt.figure(figsize=(15,7.5))
plt.title('Model Accuracy During Training')
plt.plot([tmea*100 for tmea in train_mean_epoch_accuracy],label='Train Mean Epoch Accuracy')
plt.plot([tea*100 for tea in test_epoch_accuracy],label='Test Epoch Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.savefig('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/ResNet_ReLU_hidden0_noActivationEmbeddig_Accuracy.png')

# %%
max([tea*100 for tea in test_epoch_accuracy])
# Out:
# 42.0

# %%
import pickle

LA = test_epoch_loss

file_name = 'ResNet_ReLU_hidden0_noActivationEmbeddig'
variables_list = [L,LA,
                  train_mean_epoch_accuracy,test_epoch_accuracy,
                  final_train_accuracy,final_test_accuracy,
                  word2idx]

with open('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/' + file_name + '.pkl','wb') as file:
  pickle.dump(variables_list,file)
