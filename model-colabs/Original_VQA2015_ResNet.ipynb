# %%
import os
import time
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms
from torchsummary import summary

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
from torch.utils.data import Dataset, TensorDataset, ChainDataset, DataLoader
from sklearn.feature_extraction.text import CountVectorizer

# %%
device = torch.device('cuda')
print(device)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
if not os.path.exists('annotation_map.save'):
    # !unzip '/content/gdrive/My Drive/aidl/r50_embeddings.zip'
# Out:
# Archive:  /content/gdrive/My Drive/aidl/r50_embeddings.zip
#   inflating: annotation_map.save
#   inflating: image_embeddings_train.save
#   inflating: question_embeddings_train.save
#   inflating: annotations_train.save
#   inflating: metadatas_train.save
#   inflating: image_embeddings_test.save
#   inflating: question_embeddings_test.save
#   inflating: annotations_test.save
#   inflating: metadatas_test.save

# %%
dataset_root = "/content"
answer2idx = torch.load(os.path.join(dataset_root,'annotation_map.save'))
idx2answer = { idx: answer for answer, idx in answer2idx.items() }

# %%
image_embeddings_train = torch.load(os.path.join(dataset_root,'image_embeddings_train.save'))
#question_embeddings_train = torch.load(os.path.join(dataset_root,'question_embeddings_train.save'))
annotations_train = torch.load(os.path.join(dataset_root,'annotations_train.save'))

# %%
image_embeddings_test = torch.load(os.path.join(dataset_root,'image_embeddings_test.save'))
#question_embeddings_test = torch.load(os.path.join(dataset_root,'question_embeddings_test.save'))
annotations_test = torch.load(os.path.join(dataset_root,'annotations_test.save'))

# %%
metadatas_train = torch.load(os.path.join(dataset_root,'metadatas_train.save'))
df_train = pd.DataFrame(metadatas_train)
questions_train = df_train['question_text'].to_list()

metadatas_test = torch.load(os.path.join(dataset_root,'metadatas_test.save'))
df_test = pd.DataFrame(metadatas_test)
questions_test = df_test['question_text'].to_list()

# %%
countVec = CountVectorizer(stop_words=['?'])
countVec.fit_transform(df_train['question_text'])

word2idx = countVec.vocabulary_
idx2word = { idx: word for word, idx in word2idx.items() }

# %%
#   Create list a2mfa to reindex annotations for a fixed size classifier output (1000)

most_freq_answers = torch.load('/content/gdrive/My Drive/aidl/stats/1000w.save')
most_freq_answers_dict = { ans: answer2idx[ans] for ans in most_freq_answers }

new_idx = 0
answer2mfa = [999] * len(answer2idx)
for ans,idx in answer2idx.items():
  if ans in most_freq_answers:
    answer2mfa[idx] = new_idx
    new_idx += 1

# %%
'''
count = 0
for ans in annotations_train:
    if ans in most_freq_answers_idx:
        count +=1
print(count)
print(round(count/len(annotations_train)*100,2),'%')

OUT:
78619
86.27 %
'''
# Out:
# "\ncount = 0\nfor ans in annotations_train:\n    if ans in most_freq_answers_idx:\n        count +=1\nprint(count)\nprint(round(count/len(annotations_train)*100,2),'%')\n\nOUT:\n78619\n86.27 %\n"

# %%
'''
count = 0
for ans in annotations_test:
    if ans in most_freq_answers_idx:
        count +=1
print(count)
print(round(count/len(annotations_test)*100,2),'%')

OUT:
878
87.8 %
'''
# Out:
# "\ncount = 0\nfor ans in annotations_test:\n    if ans in most_freq_answers_idx:\n        count +=1\nprint(count)\nprint(round(count/len(annotations_test)*100,2),'%')\n\nOUT:\n878\n87.8 %\n"

# %%
class CustomDataset(Dataset):
    def __init__(self, questions, images, answers):

        assert len(questions) == len(images) & len(images) == len(answers), 'Different Lenghts!'

        self.questions = questions
        self.images = images
        self.answers = answers

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        return self.questions[idx], self.images[idx], self.answers[idx]

train_dataset = CustomDataset(image_embeddings_train,questions_train,annotations_train)
test_dataset = CustomDataset(image_embeddings_test,questions_test,annotations_test)

batch_size = 400
train_dataloader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
test_dataloader = DataLoader(test_dataset,batch_size=batch_size,shuffle=True)

# %%
class VQA2015(nn.Module):
    
    def __init__(self, embedding_dim, hidden_dim, vocab_size, image_dim, tagset_size):
        
        super(VQA2015, self).__init__()
        
        # Branca Llenguatge

        self.hidden_dim = hidden_dim
        
        self.word_embeddings = nn.Embedding(vocab_size + 1, embedding_dim, padding_idx = vocab_size)

        self.tanh = nn.Tanh() # https://discuss.pytorch.org/t/torch-tanh-vs-torch-nn-functional-tanh/15897/7

        self.lstm = nn.LSTM(embedding_dim, hidden_dim,batch_first=True)

        self.txt_fcl = nn.Sequential(
            nn.Linear(2*hidden_dim, 2*hidden_dim),
            nn.Tanh()
            )
        
        # Branca Imatge (VGG16)

        self.img_fcl = nn.Sequential(
            nn.Linear(image_dim, 2*hidden_dim), 
            nn.Tanh()
            )

        # Classificador
                
        self.classificador = nn.Sequential(
            nn.Linear(2*hidden_dim, 1000),
            nn.Dropout(),
            nn.Tanh(),
            nn.Linear(1000, 1000),
            nn.Dropout(),
            nn.Tanh(),
            nn.Linear(1000, 1000),
            nn.Dropout(),
            nn.Tanh(),
            nn.Linear(1000, tagset_size),
          )
                
    def forward(self,sentence,image,questionLengths,hidden):

        # Question
        embeds = self.word_embeddings(sentence) # batch_size x seq_len x embedding_dim

        embeds = self.tanh(embeds) # batch_size x seq_len x embedding_dim

        embeds = pack_padded_sequence(embeds, questionLengths, batch_first=True, enforce_sorted = False)

        _, hidden = self.lstm(embeds,hidden) # ht i ct:  num_layer*num_directions x batch_size x hidden_dim

        lstm_out = torch.cat(hidden,2) # num_layer*num_directions x batch_size x 2*hidden_dim
        lstm_out = lstm_out.reshape((-1,2*self.hidden_dim)) # batch_size x 2*hidden_dim

        txt_embed = self.txt_fcl(lstm_out) # batch_size x tagset_size = vocab_size
        
        # Image
        
        img_embed = self.img_fcl(image)
        
        # Join
        
        txt_img_embed = txt_embed*img_embed
        tag_scores = self.classificador(txt_img_embed)
        
        return tag_scores, hidden

# %%
# Instancia Model

embedding_dim = 300
hidden_dim = 512
image_dim = 2048 # ResNet50
vocab_size = len(word2idx)
tagset_size = 1000
    
modelVQA2015 = VQA2015(embedding_dim, hidden_dim, vocab_size, image_dim,tagset_size)
modelVQA2015 = modelVQA2015.to(device)

loss_function = nn.CrossEntropyLoss(ignore_index=999)
optimizer = optim.Adam(modelVQA2015.parameters(), lr=0.001)

# %%
for i, (imageBatch, questionBatch, answerBatch) in enumerate(train_dataloader):
     break

# %%
start = time.time()

wordIndices = [ torch.tensor(countVec.transform([question]).nonzero()[-1]) for question in questionBatch ]
paddedWordIndices = pad_sequence(wordIndices,batch_first=True,padding_value=vocab_size).long()

questionLengths = torch.tensor([ len(seq) for seq in wordIndices ])
paddedWordIndices = paddedWordIndices.to(device)
imageBatch = imageBatch.to(device)

hidden = (torch.zeros(1, batch_size, hidden_dim).to(device),
          torch.zeros(1, batch_size, hidden_dim).to(device))

tag_scores, hidden_out = modelVQA2015(paddedWordIndices,imageBatch,questionLengths,hidden)

targets = torch.tensor([ answer2mfa[answer] for answer in answerBatch ]).to(device)

tag_scores = torch.nn.functional.log_softmax(tag_scores,dim=1)
tag_scores = torch.argmax(tag_scores,dim=1)

hits = (tag_scores == targets) & (tag_scores != 999)

end = time.time()
print(end - start)
# Out:
# 0.20917177200317383

# %%
#torch.argmax(tag_scores,dim=1)
#tag_scores
#[idx2answer[int(ans)] for ans in answerBatch]
#[idx2answer[int(ans)] for ans in targets]
#[idx2answer[int(ans)] for ans in most_freq_answers]
#most_freq_answers
#answerBatch
#[ answer2mfa.index(idx) for idx in targets ]
#targets

# %%
# Funció per evaluar l'accuracy d'un dataset

def VQA2015_model_accuracy(eval_model,eval_dataset,eval_batch_size,eval_countVec,eval_answer2mfa, ignore=999,eval=False):

    eval_dataloader = DataLoader(eval_dataset,batch_size=eval_batch_size)

    count = 0
    total = 0

    eval_L = []

    eval_model.eval()
    
    eval_hidden = ( torch.zeros(1, batch_size, hidden_dim).to(device),
                    torch.zeros(1, batch_size, hidden_dim).to(device) )

    with torch.no_grad():

        for i, (eval_imageBatch, eval_questionBatch, eval_answerBatch) in enumerate(eval_dataloader):

            if eval:
                if i % 10 == 0: print('Batch',i)

            # Transofrma
          
            eval_wordIndices = [ torch.tensor(eval_countVec.transform([question]).nonzero()[-1]) for question in eval_questionBatch ]
            eval_paddedWordIndices = pad_sequence(eval_wordIndices,batch_first=True,padding_value=vocab_size).long()
            eval_questionLengths = torch.tensor([ len(seq) for seq in eval_wordIndices ])
          
            eval_paddedWordIndices = eval_paddedWordIndices.to(device)
            eval_imageBatch = eval_imageBatch.to(device)
          
            eval_targets = torch.tensor([ eval_answer2mfa[answer] for answer in eval_answerBatch ]).to(device)
            
            # Run our forward pass.

            eval_tag_scores, eval_hidden = eval_model(eval_paddedWordIndices,eval_imageBatch,eval_questionLengths,eval_hidden)

            # Compute Loss
        
            eval_loss = loss_function(eval_tag_scores, eval_targets)
            eval_L.append(float(eval_loss))

            # Compute Accuracy

            eval_tag_scores = torch.nn.functional.log_softmax(eval_tag_scores,dim=1)
            eval_tag_scores = torch.argmax(eval_tag_scores,dim=1)

            eval_hits = (eval_tag_scores == eval_targets) & (eval_tag_scores != ignore)
          
            #count += float(sum(eval_targets == eval_tag_scores))
            count += eval_hits.sum().item()
            total += len(eval_answerBatch)

    return count/total, sum(eval_L)/len(eval_L)

# %%
start = time.time()

pretrain_test_accuracy, pretrain_test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
print('\nAccuracy = %5.2f%%' % (pretrain_test_accuracy*100))
print('Loss  = %5.2f' % pretrain_test_loss )

end = time.time()
print(end - start,'seconds')
# Out:
# Accuracy =  0.10%
# Loss  =  6.92
# 0.26328325271606445 seconds

# %%
def compute_batch_accuracy(tag_scores,targets,ignore=999):

  pred = torch.nn.functional.log_softmax(tag_scores,dim=1) 
  pred = torch.argmax(pred,dim=1)
  hits = (pred == targets) & (pred != ignore)
   
  return hits.sum().item()/len(pred)

# %%
# %% Train: basat en el link més algunes modificacions per adaptar-ho al cas

start = time.time()

ignore = 999

L = [] # loss

train_mean_epoch_accuracy = []
test_epoch_accuracy = []
test_epoch_loss = []

num_epochs = 100

for epoch in range(num_epochs):  # again, normally you would NOT do 300 epochs, it is toy data
    
    print('Epoch', epoch)

    modelVQA2015.train()

    hidden = ( torch.zeros(1, batch_size, hidden_dim).to(device),
               torch.zeros(1, batch_size, hidden_dim).to(device) )

    train_batch_accuracy = []

    for i, (imageBatch, questionBatch, answerBatch) in enumerate(train_dataloader):
        
        if i % 20 == 0: print('\tBatch', '%3d' % i, end = ', ')
                    
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        
        optimizer.zero_grad()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.

        wordIndices = [ torch.tensor(countVec.transform([question]).nonzero()[-1]) for question in questionBatch ]
        paddedWordIndices = pad_sequence(wordIndices,batch_first=True,padding_value=vocab_size).long()
        questionLengths = torch.tensor([ len(seq) for seq in wordIndices ])
        
        paddedWordIndices = paddedWordIndices.to(device)
        imageBatch = imageBatch.to(device)

        hidden = tuple( h.detach() for h in hidden )
        
        # Step 3. Run our forward pass.

        tag_scores, hidden = modelVQA2015(paddedWordIndices,imageBatch,questionLengths,hidden)

        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()        
        
        targets = torch.tensor([ answer2mfa[answer] for answer in answerBatch ]).to(device)
        
        loss = loss_function(tag_scores, targets)
        
        loss.backward()
        optimizer.step()

        # Monitoritza el procés

        batch_accuracy = compute_batch_accuracy(tag_scores,targets)

        train_batch_accuracy.append(batch_accuracy)

        L.append(float(loss))

        if len(L) >= 100:
          rolling_loss = sum(L[-100:])/100
        else:
          rolling_loss = sum(L)/len(L)

        if i % 20 == 0: print('Loss =',round(float(loss),4),', Rolling Mean Loss =',round(rolling_loss,4),', Batch Accuracy =',round(100*batch_accuracy,2))

    train_mean_epoch_accuracy.append( sum(train_batch_accuracy)/len(train_batch_accuracy) )
    print('\tTrain Accuracy (mean) = ',round(100*train_mean_epoch_accuracy[-1],2))

    test_accuracy, test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
    test_epoch_accuracy.append(test_accuracy)
    test_epoch_loss.append(test_loss)
    print('\tTest Accuracy         = ',round(100*test_epoch_accuracy[-1],2))

print('')

print('Final Loss =',round(float(loss),4))
print('Final Rolling Loss =',round(float(rolling_loss),4))

print('')
final_test_accuracy, final_test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
print('Final Test Accuracy  = %5.2f%%' % (100*final_test_accuracy))

final_train_accuracy, final_train_loss = VQA2015_model_accuracy(modelVQA2015,train_dataset,batch_size,countVec,answer2mfa)
print('Final Train Accuracy = %5.2f%%' % (100*final_train_accuracy))

print('')
end = time.time()
total_time = round(end -start)
print('Running Time =', total_time//60,'min,',total_time % 60, 'sec.')
# Out:
# Epoch 0
# 	Batch   0, Loss = 6.9159 , Rolling Mean Loss = 6.9159 , Batch Accuracy = 0.0
# 	Batch  20, Loss = 4.3722 , Rolling Mean Loss = 4.6762 , Batch Accuracy = 19.75
# 	Batch  40, Loss = 4.3861 , Rolling Mean Loss = 4.4752 , Batch Accuracy = 21.25
# 	Batch  60, Loss = 4.2099 , Rolling Mean Loss = 4.4025 , Batch Accuracy = 20.25
# 	Batch  80, Loss = 4.1691 , Rolling Mean Loss = 4.3714 , Batch Accuracy = 21.0
# 	Batch 100, Loss = 4.5243 , Rolling Mean Loss = 4.3272 , Batch Accuracy = 24.5
# 	Batch 120, Loss = 4.1988 , Rolling Mean Loss = 4.2506 , Batch Accuracy = 22.0
# 	Batch 140, Loss = 3.7578 , Rolling Mean Loss = 4.1987 , Batch Accuracy = 23.0
# 	Batch 160, Loss = 3.2151 , Rolling Mean Loss = 4.1171 , Batch Accuracy = 23.5
# 	Batch 180, Loss = 3.784 , Rolling Mean Loss = 3.9975 , Batch Accuracy = 23.0
# 	Batch 200, Loss = 3.2559 , Rolling Mean Loss = 3.8457 , Batch Accuracy = 23.75
# 	Batch 220, Loss = 3.4334 , Rolling Mean Loss = 3.6979 , Batch Accuracy = 24.75
# 	Train Accuracy (mean) =  22.92
# 	Test Accuracy         =  25.8
# Epoch 1
# 	Batch   0, Loss = 3.115 , Rolling Mean Loss = 3.6366 , Batch Accuracy = 27.75
# 	Batch  20, Loss = 3.5684 , Rolling Mean Loss = 3.5198 , Batch Accuracy = 24.75
# 	Batch  40, Loss = 3.4218 , Rolling Mean Loss = 3.435 , Batch Accuracy = 25.75
# 	Batch  60, Loss = 3.1321 , Rolling Mean Loss = 3.3592 , Batch Accuracy = 30.75
# 	Batch  80, Loss = 3.1966 , Rolling Mean Loss = 3.3228 , Batch Accuracy = 26.5
# 	Batch 100, Loss = 3.0601 , Rolling Mean Loss = 3.2949 , Batch Accuracy = 28.5
# 	Batch 120, Loss = 3.2607 , Rolling Mean Loss = 3.2778 , Batch Accuracy = 26.0
# 	Batch 140, Loss = 3.1315 , Rolling Mean Loss = 3.2583 , Batch Accuracy = 28.5
# 	Batch 160, Loss = 3.1125 , Rolling Mean Loss = 3.2511 , Batch Accuracy = 24.5
# 	Batch 180, Loss = 3.0311 , Rolling Mean Loss = 3.2208 , Batch Accuracy = 29.0
# 	Batch 200, Loss = 3.1205 , Rolling Mean Loss = 3.1833 , Batch Accuracy = 25.75
# 	Batch 220, Loss = 3.1871 , Rolling Mean Loss = 3.1404 , Batch Accuracy = 23.75
# 	Train Accuracy (mean) =  26.82
# 	Test Accuracy         =  26.5
# Epoch 2
# 	Batch   0, Loss = 3.139 , Rolling Mean Loss = 3.1251 , Batch Accuracy = 25.25
# 	Batch  20, Loss = 2.9545 , Rolling Mean Loss = 3.0851 , Batch Accuracy = 26.5
# 	Batch  40, Loss = 2.7411 , Rolling Mean Loss = 3.0471 , Batch Accuracy = 29.5
# 	Batch  60, Loss = 3.3131 , Rolling Mean Loss = 3.0358 , Batch Accuracy = 27.0
# 	Batch  80, Loss = 3.0998 , Rolling Mean Loss = 3.0354 , Batch Accuracy = 26.0
# 	Batch 100, Loss = 3.0151 , Rolling Mean Loss = 3.0445 , Batch Accuracy = 29.5
# 	Batch 120, Loss = 2.9927 , Rolling Mean Loss = 3.0424 , Batch Accuracy = 29.0
# 	Batch 140, Loss = 2.8682 , Rolling Mean Loss = 3.0523 , Batch Accuracy = 31.5
# 	Batch 160, Loss = 3.3139 , Rolling Mean Loss = 3.0671 , Batch Accuracy = 25.5
# 	Batch 180, Loss = 3.1182 , Rolling Mean Loss = 3.0556 , Batch Accuracy = 27.5
# 	Batch 200, Loss = 3.0269 , Rolling Mean Loss = 3.0506 , Batch Accuracy = 29.75
# 	Batch 220, Loss = 3.0718 , Rolling Mean Loss = 3.0445 , Batch Accuracy = 25.25
# 	Train Accuracy (mean) =  27.13
# 	Test Accuracy         =  25.9
# Epoch 3
# 	Batch   0, Loss = 2.8949 , Rolling Mean Loss = 3.0378 , Batch Accuracy = 25.75
# 	Batch  20, Loss = 3.1215 , Rolling Mean Loss = 3.0221 , Batch Accuracy = 29.5
# 	Batch  40, Loss = 3.2102 , Rolling Mean Loss = 3.0244 , Batch Accuracy = 20.75
# 	Batch  60, Loss = 2.8575 , Rolling Mean Loss = 3.0196 , Batch Accuracy = 27.0
# 	Batch  80, Loss = 2.7823 , Rolling Mean Loss = 3.0205 , Batch Accuracy = 32.25
# 	Batch 100, Loss = 3.0113 , Rolling Mean Loss = 3.0281 , Batch Accuracy = 26.25
# 	Batch 120, Loss = 3.0804 , Rolling Mean Loss = 3.0363 , Batch Accuracy = 27.75
# 	Batch 140, Loss = 3.0195 , Rolling Mean Loss = 3.0301 , Batch Accuracy = 24.75
# 	Batch 160, Loss = 2.9056 , Rolling Mean Loss = 3.0125 , Batch Accuracy = 29.5
# 	Batch 180, Loss = 3.3414 , Rolling Mean Loss = 3.0066 , Batch Accuracy = 25.25
# 	Batch 200, Loss = 3.0244 , Rolling Mean Loss = 3.0067 , Batch Accuracy = 26.25
# 	Batch 220, Loss = 3.1021 , Rolling Mean Loss = 2.9892 , Batch Accuracy = 30.0
# 	Train Accuracy (mean) =  27.33
# 	Test Accuracy         =  26.3
# Epoch 4
# 	Batch   0, Loss = 3.0581 , Rolling Mean Loss = 2.9929 , Batch Accuracy = 26.0
# 	Batch  20, Loss = 2.986 , Rolling Mean Loss = 2.9802 , Batch Accuracy = 27.75
# 	Batch  40, Loss = 2.8108 , Rolling Mean Loss = 2.9685 , Batch Accuracy = 28.75
# 	Batch  60, Loss = 3.0644 , Rolling Mean Loss = 2.9466 , Batch Accuracy = 24.0
# 	Batch  80, Loss = 3.156 , Rolling Mean Loss = 2.9559 , Batch Accuracy = 28.25
# 	Batch 100, Loss = 3.0383 , Rolling Mean Loss = 2.9516 , Batch Accuracy = 29.25
# 	Batch 120, Loss = 3.0699 , Rolling Mean Loss = 2.9603 , Batch Accuracy = 28.25
# 	Batch 140, Loss = 2.8451 , Rolling Mean Loss = 2.9762 , Batch Accuracy = 31.25
# 	Batch 160, Loss = 2.8112 , Rolling Mean Loss = 2.9719 , Batch Accuracy = 32.25
# 	Batch 180, Loss = 2.8852 , Rolling Mean Loss = 2.9614 , Batch Accuracy = 32.75
# 	Batch 200, Loss = 2.9918 , Rolling Mean Loss = 2.9454 , Batch Accuracy = 27.75
# 	Batch 220, Loss = 2.9923 , Rolling Mean Loss = 2.9172 , Batch Accuracy = 24.0
# 	Train Accuracy (mean) =  28.35
# 	Test Accuracy         =  28.1
# Epoch 5
# 	Batch   0, Loss = 2.9594 , Rolling Mean Loss = 2.9072 , Batch Accuracy = 30.0
# 	Batch  20, Loss = 2.8364 , Rolling Mean Loss = 2.9023 , Batch Accuracy = 29.5
# 	Batch  40, Loss = 2.6644 , Rolling Mean Loss = 2.9008 , Batch Accuracy = 32.5
# 	Batch  60, Loss = 2.7581 , Rolling Mean Loss = 2.8969 , Batch Accuracy = 30.5
# 	Batch  80, Loss = 2.7814 , Rolling Mean Loss = 2.9026 , Batch Accuracy = 29.75
# 	Batch 100, Loss = 2.9777 , Rolling Mean Loss = 2.8964 , Batch Accuracy = 31.0
# 	Batch 120, Loss = 2.6935 , Rolling Mean Loss = 2.8749 , Batch Accuracy = 30.5
# 	Batch 140, Loss = 2.5614 , Rolling Mean Loss = 2.864 , Batch Accuracy = 31.5
# 	Batch 160, Loss = 2.8872 , Rolling Mean Loss = 2.8584 , Batch Accuracy = 28.0
# 	Batch 180, Loss = 2.7311 , Rolling Mean Loss = 2.8384 , Batch Accuracy = 34.25
# 	Batch 200, Loss = 2.7605 , Rolling Mean Loss = 2.8343 , Batch Accuracy = 33.0
# 	Batch 220, Loss = 2.7854 , Rolling Mean Loss = 2.8233 , Batch Accuracy = 33.5
# 	Train Accuracy (mean) =  29.97
# 	Test Accuracy         =  29.3
# Epoch 6
# 	Batch   0, Loss = 2.7798 , Rolling Mean Loss = 2.8147 , Batch Accuracy = 28.25
# 	Batch  20, Loss = 2.7323 , Rolling Mean Loss = 2.8086 , Batch Accuracy = 33.75
# 	Batch  40, Loss = 3.0587 , Rolling Mean Loss = 2.7998 , Batch Accuracy = 28.5
# 	Batch  60, Loss = 2.6287 , Rolling Mean Loss = 2.7972 , Batch Accuracy = 34.5
# 	Batch  80, Loss = 2.7009 , Rolling Mean Loss = 2.7797 , Batch Accuracy = 29.5
# 	Batch 100, Loss = 2.7061 , Rolling Mean Loss = 2.7728 , Batch Accuracy = 27.0
# 	Batch 120, Loss = 2.716 , Rolling Mean Loss = 2.7662 , Batch Accuracy = 31.0
# 	Batch 140, Loss = 2.62 , Rolling Mean Loss = 2.7524 , Batch Accuracy = 34.75
# 	Batch 160, Loss = 2.7076 , Rolling Mean Loss = 2.7598 , Batch Accuracy = 30.5
# 	Batch 180, Loss = 2.8152 , Rolling Mean Loss = 2.7589 , Batch Accuracy = 29.0
# 	Batch 200, Loss = 2.6005 , Rolling Mean Loss = 2.7636 , Batch Accuracy = 34.0
# 	Batch 220, Loss = 2.9433 , Rolling Mean Loss = 2.7573 , Batch Accuracy = 29.5
# 	Train Accuracy (mean) =  31.16
# 	Test Accuracy         =  29.6
# Epoch 7
# 	Batch   0, Loss = 2.5521 , Rolling Mean Loss = 2.7569 , Batch Accuracy = 32.5
# 	Batch  20, Loss = 2.7331 , Rolling Mean Loss = 2.7603 , Batch Accuracy = 32.75
# 	Batch  40, Loss = 2.7938 , Rolling Mean Loss = 2.7465 , Batch Accuracy = 35.25
# 	Batch  60, Loss = 2.5593 , Rolling Mean Loss = 2.7407 , Batch Accuracy = 34.0
# 	Batch  80, Loss = 2.7727 , Rolling Mean Loss = 2.737 , Batch Accuracy = 29.25
# 	Batch 100, Loss = 2.7555 , Rolling Mean Loss = 2.7113 , Batch Accuracy = 33.25
# 	Batch 120, Loss = 2.7101 , Rolling Mean Loss = 2.7003 , Batch Accuracy = 28.75
# 	Batch 140, Loss = 2.5508 , Rolling Mean Loss = 2.7034 , Batch Accuracy = 30.0
# 	Batch 160, Loss = 2.4347 , Rolling Mean Loss = 2.7008 , Batch Accuracy = 36.25
# 	Batch 180, Loss = 2.7787 , Rolling Mean Loss = 2.7057 , Batch Accuracy = 33.75
# 	Batch 200, Loss = 2.3938 , Rolling Mean Loss = 2.7145 , Batch Accuracy = 34.75
# 	Batch 220, Loss = 2.4598 , Rolling Mean Loss = 2.7144 , Batch Accuracy = 31.5
# 	Train Accuracy (mean) =  31.95
# 	Test Accuracy         =  30.2
# Epoch 8
# 	Batch   0, Loss = 2.9171 , Rolling Mean Loss = 2.7147 , Batch Accuracy = 28.25
# 	Batch  20, Loss = 2.5467 , Rolling Mean Loss = 2.7032 , Batch Accuracy = 32.5
# 	Batch  40, Loss = 2.5035 , Rolling Mean Loss = 2.6987 , Batch Accuracy = 37.0
# 	Batch  60, Loss = 2.6194 , Rolling Mean Loss = 2.6899 , Batch Accuracy = 31.5
# 	Batch  80, Loss = 2.5046 , Rolling Mean Loss = 2.6806 , Batch Accuracy = 34.75
# 	Batch 100, Loss = 2.4367 , Rolling Mean Loss = 2.6579 , Batch Accuracy = 38.0
# 	Batch 120, Loss = 2.6822 , Rolling Mean Loss = 2.6658 , Batch Accuracy = 33.0
# 	Batch 140, Loss = 2.4761 , Rolling Mean Loss = 2.6528 , Batch Accuracy = 32.25
# 	Batch 160, Loss = 2.5834 , Rolling Mean Loss = 2.6528 , Batch Accuracy = 33.25
# 	Batch 180, Loss = 2.7668 , Rolling Mean Loss = 2.6584 , Batch Accuracy = 29.5
# 	Batch 200, Loss = 2.6884 , Rolling Mean Loss = 2.6685 , Batch Accuracy = 33.75
# 	Batch 220, Loss = 2.6644 , Rolling Mean Loss = 2.6636 , Batch Accuracy = 29.75
# 	Train Accuracy (mean) =  32.56
# 	Test Accuracy         =  29.7
# Epoch 9
# 	Batch   0, Loss = 2.6974 , Rolling Mean Loss = 2.664 , Batch Accuracy = 32.5
# 	Batch  20, Loss = 2.744 , Rolling Mean Loss = 2.6627 , Batch Accuracy = 31.75
# 	Batch  40, Loss = 2.6573 , Rolling Mean Loss = 2.6618 , Batch Accuracy = 34.0
# 	Batch  60, Loss = 2.541 , Rolling Mean Loss = 2.6409 , Batch Accuracy = 34.25
# 	Batch  80, Loss = 2.7373 , Rolling Mean Loss = 2.6332 , Batch Accuracy = 27.5
# 	Batch 100, Loss = 2.4563 , Rolling Mean Loss = 2.6291 , Batch Accuracy = 35.5
# 	Batch 120, Loss = 2.5871 , Rolling Mean Loss = 2.6285 , Batch Accuracy = 34.25
# 	Batch 140, Loss = 2.4693 , Rolling Mean Loss = 2.6264 , Batch Accuracy = 36.0
# 	Batch 160, Loss = 2.5765 , Rolling Mean Loss = 2.6469 , Batch Accuracy = 33.0
# 	Batch 180, Loss = 2.5758 , Rolling Mean Loss = 2.6373 , Batch Accuracy = 32.75
# 	Batch 200, Loss = 2.5138 , Rolling Mean Loss = 2.6302 , Batch Accuracy = 35.25
# 	Batch 220, Loss = 2.5362 , Rolling Mean Loss = 2.6169 , Batch Accuracy = 36.75
# 	Train Accuracy (mean) =  33.25
# 	Test Accuracy         =  30.4
# Epoch 10
# 	Batch   0, Loss = 2.5323 , Rolling Mean Loss = 2.6079 , Batch Accuracy = 37.25
# 	Batch  20, Loss = 2.5121 , Rolling Mean Loss = 2.6052 , Batch Accuracy = 34.5
# 	Batch  40, Loss = 2.4532 , Rolling Mean Loss = 2.5927 , Batch Accuracy = 37.75
# 	Batch  60, Loss = 2.4896 , Rolling Mean Loss = 2.5899 , Batch Accuracy = 34.75
# 	Batch  80, Loss = 2.5661 , Rolling Mean Loss = 2.5828 , Batch Accuracy = 34.5
# 	Batch 100, Loss = 2.7414 , Rolling Mean Loss = 2.574 , Batch Accuracy = 34.0
# 	Batch 120, Loss = 2.6673 , Rolling Mean Loss = 2.5542 , Batch Accuracy = 33.75
# 	Batch 140, Loss = 2.5706 , Rolling Mean Loss = 2.5561 , Batch Accuracy = 36.75
# 	Batch 160, Loss = 2.4276 , Rolling Mean Loss = 2.564 , Batch Accuracy = 34.5
# 	Batch 180, Loss = 2.4891 , Rolling Mean Loss = 2.558 , Batch Accuracy = 36.0
# 	Batch 200, Loss = 2.6096 , Rolling Mean Loss = 2.5696 , Batch Accuracy = 33.0
# 	Batch 220, Loss = 2.4481 , Rolling Mean Loss = 2.5872 , Batch Accuracy = 35.0
# 	Train Accuracy (mean) =  34.13
# 	Test Accuracy         =  30.6
# Epoch 11
# 	Batch   0, Loss = 2.493 , Rolling Mean Loss = 2.5805 , Batch Accuracy = 37.5
# 	Batch  20, Loss = 2.3655 , Rolling Mean Loss = 2.5588 , Batch Accuracy = 35.0
# 	Batch  40, Loss = 2.4979 , Rolling Mean Loss = 2.5534 , Batch Accuracy = 31.75
# 	Batch  60, Loss = 2.3251 , Rolling Mean Loss = 2.5416 , Batch Accuracy = 37.25
# 	Batch  80, Loss = 2.545 , Rolling Mean Loss = 2.5377 , Batch Accuracy = 32.75
# 	Batch 100, Loss = 2.5499 , Rolling Mean Loss = 2.5185 , Batch Accuracy = 32.25
# 	Batch 120, Loss = 2.5343 , Rolling Mean Loss = 2.5309 , Batch Accuracy = 38.0
# 	Batch 140, Loss = 2.9676 , Rolling Mean Loss = 2.5317 , Batch Accuracy = 28.75
# 	Batch 160, Loss = 2.7077 , Rolling Mean Loss = 2.5429 , Batch Accuracy = 31.5
# 	Batch 180, Loss = 2.4778 , Rolling Mean Loss = 2.5314 , Batch Accuracy = 37.0
# 	Batch 200, Loss = 2.5297 , Rolling Mean Loss = 2.5228 , Batch Accuracy = 39.0
# 	Batch 220, Loss = 2.5686 , Rolling Mean Loss = 2.5298 , Batch Accuracy = 35.5
# 	Train Accuracy (mean) =  35.03
# 	Test Accuracy         =  31.7
# Epoch 12
# 	Batch   0, Loss = 2.4564 , Rolling Mean Loss = 2.5315 , Batch Accuracy = 35.25
# 	Batch  20, Loss = 2.3415 , Rolling Mean Loss = 2.5038 , Batch Accuracy = 36.75
# 	Batch  40, Loss = 2.4226 , Rolling Mean Loss = 2.4989 , Batch Accuracy = 34.5
# 	Batch  60, Loss = 2.6077 , Rolling Mean Loss = 2.4956 , Batch Accuracy = 36.5
# 	Batch  80, Loss = 2.5028 , Rolling Mean Loss = 2.4801 , Batch Accuracy = 38.0
# 	Batch 100, Loss = 2.4072 , Rolling Mean Loss = 2.4715 , Batch Accuracy = 39.25
# 	Batch 120, Loss = 2.6577 , Rolling Mean Loss = 2.4816 , Batch Accuracy = 32.5
# 	Batch 140, Loss = 2.5447 , Rolling Mean Loss = 2.4829 , Batch Accuracy = 35.25
# 	Batch 160, Loss = 2.3447 , Rolling Mean Loss = 2.4782 , Batch Accuracy = 35.0
# 	Batch 180, Loss = 2.5533 , Rolling Mean Loss = 2.4959 , Batch Accuracy = 35.75
# 	Batch 200, Loss = 2.5966 , Rolling Mean Loss = 2.4929 , Batch Accuracy = 31.5
# 	Batch 220, Loss = 2.6481 , Rolling Mean Loss = 2.4898 , Batch Accuracy = 37.75
# 	Train Accuracy (mean) =  35.53
# 	Test Accuracy         =  32.8
# Epoch 13
# 	Batch   0, Loss = 2.2314 , Rolling Mean Loss = 2.4893 , Batch Accuracy = 40.75
# 	Batch  20, Loss = 2.2926 , Rolling Mean Loss = 2.4696 , Batch Accuracy = 35.75
# 	Batch  40, Loss = 2.7113 , Rolling Mean Loss = 2.4601 , Batch Accuracy = 34.25
# 	Batch  60, Loss = 2.5212 , Rolling Mean Loss = 2.4553 , Batch Accuracy = 35.25
# 	Batch  80, Loss = 2.6257 , Rolling Mean Loss = 2.4538 , Batch Accuracy = 36.25
# 	Batch 100, Loss = 2.3724 , Rolling Mean Loss = 2.4465 , Batch Accuracy = 36.25
# 	Batch 120, Loss = 2.375 , Rolling Mean Loss = 2.4648 , Batch Accuracy = 38.25
# 	Batch 140, Loss = 2.2508 , Rolling Mean Loss = 2.4674 , Batch Accuracy = 38.25
# 	Batch 160, Loss = 2.5085 , Rolling Mean Loss = 2.4459 , Batch Accuracy = 35.25
# 	Batch 180, Loss = 2.3107 , Rolling Mean Loss = 2.4283 , Batch Accuracy = 40.0
# 	Batch 200, Loss = 2.4874 , Rolling Mean Loss = 2.424 , Batch Accuracy = 35.75
# 	Batch 220, Loss = 2.1906 , Rolling Mean Loss = 2.4197 , Batch Accuracy = 35.75
# 	Train Accuracy (mean) =  36.47
# 	Test Accuracy         =  31.7
# Epoch 14
# 	Batch   0, Loss = 2.6163 , Rolling Mean Loss = 2.4133 , Batch Accuracy = 32.25
# 	Batch  20, Loss = 2.549 , Rolling Mean Loss = 2.4122 , Batch Accuracy = 34.75
# 	Batch  40, Loss = 2.3506 , Rolling Mean Loss = 2.4116 , Batch Accuracy = 35.25
# 	Batch  60, Loss = 2.2481 , Rolling Mean Loss = 2.4136 , Batch Accuracy = 38.5
# 	Batch  80, Loss = 2.2389 , Rolling Mean Loss = 2.411 , Batch Accuracy = 37.25
# 	Batch 100, Loss = 2.6461 , Rolling Mean Loss = 2.4079 , Batch Accuracy = 35.0
# 	Batch 120, Loss = 2.3753 , Rolling Mean Loss = 2.4104 , Batch Accuracy = 36.75
# 	Batch 140, Loss = 2.1561 , Rolling Mean Loss = 2.4058 , Batch Accuracy = 44.0
# 	Batch 160, Loss = 2.2096 , Rolling Mean Loss = 2.4005 , Batch Accuracy = 40.75
# 	Batch 180, Loss = 2.4437 , Rolling Mean Loss = 2.3972 , Batch Accuracy = 36.0
# 	Batch 200, Loss = 2.3555 , Rolling Mean Loss = 2.3915 , Batch Accuracy = 34.25
# 	Batch 220, Loss = 2.4181 , Rolling Mean Loss = 2.3877 , Batch Accuracy = 36.25
# 	Train Accuracy (mean) =  37.09
# 	Test Accuracy         =  33.3
# Epoch 15
# 	Batch   0, Loss = 2.31 , Rolling Mean Loss = 2.3763 , Batch Accuracy = 38.5
# 	Batch  20, Loss = 2.2009 , Rolling Mean Loss = 2.3707 , Batch Accuracy = 36.75
# 	Batch  40, Loss = 2.5434 , Rolling Mean Loss = 2.3625 , Batch Accuracy = 36.5
# 	Batch  60, Loss = 2.6158 , Rolling Mean Loss = 2.3495 , Batch Accuracy = 35.25
# 	Batch  80, Loss = 2.3463 , Rolling Mean Loss = 2.3342 , Batch Accuracy = 36.25
# 	Batch 100, Loss = 2.3789 , Rolling Mean Loss = 2.3387 , Batch Accuracy = 36.5
# 	Batch 120, Loss = 2.3398 , Rolling Mean Loss = 2.3536 , Batch Accuracy = 37.5
# 	Batch 140, Loss = 2.2033 , Rolling Mean Loss = 2.3465 , Batch Accuracy = 37.5
# 	Batch 160, Loss = 2.2369 , Rolling Mean Loss = 2.3539 , Batch Accuracy = 38.75
# 	Batch 180, Loss = 2.2423 , Rolling Mean Loss = 2.3584 , Batch Accuracy = 43.0
# 	Batch 200, Loss = 2.415 , Rolling Mean Loss = 2.3557 , Batch Accuracy = 36.5
# 	Batch 220, Loss = 2.5194 , Rolling Mean Loss = 2.351 , Batch Accuracy = 33.75
# 	Train Accuracy (mean) =  37.74
# 	Test Accuracy         =  31.7
# Epoch 16
# 	Batch   0, Loss = 2.2622 , Rolling Mean Loss = 2.3531 , Batch Accuracy = 42.25
# 	Batch  20, Loss = 2.4888 , Rolling Mean Loss = 2.339 , Batch Accuracy = 36.0
# 	Batch  40, Loss = 2.1195 , Rolling Mean Loss = 2.3226 , Batch Accuracy = 38.5
# 	Batch  60, Loss = 2.3618 , Rolling Mean Loss = 2.3201 , Batch Accuracy = 39.5
# 	Batch  80, Loss = 2.1967 , Rolling Mean Loss = 2.306 , Batch Accuracy = 38.75
# 	Batch 100, Loss = 2.3485 , Rolling Mean Loss = 2.2946 , Batch Accuracy = 36.25
# 	Batch 120, Loss = 2.2372 , Rolling Mean Loss = 2.3028 , Batch Accuracy = 39.0
# 	Batch 140, Loss = 2.3748 , Rolling Mean Loss = 2.3035 , Batch Accuracy = 37.25
# 	Batch 160, Loss = 2.3885 , Rolling Mean Loss = 2.304 , Batch Accuracy = 35.25
# 	Batch 180, Loss = 2.4392 , Rolling Mean Loss = 2.3058 , Batch Accuracy = 36.5
# 	Batch 200, Loss = 2.3039 , Rolling Mean Loss = 2.3068 , Batch Accuracy = 36.0
# 	Batch 220, Loss = 2.1961 , Rolling Mean Loss = 2.2994 , Batch Accuracy = 37.25
# 	Train Accuracy (mean) =  38.57
# 	Test Accuracy         =  34.1
# Epoch 17
# 	Batch   0, Loss = 2.3439 , Rolling Mean Loss = 2.3106 , Batch Accuracy = 40.25
# 	Batch  20, Loss = 2.1792 , Rolling Mean Loss = 2.3057 , Batch Accuracy = 43.25
# 	Batch  40, Loss = 2.0005 , Rolling Mean Loss = 2.2939 , Batch Accuracy = 42.25
# 	Batch  60, Loss = 2.3944 , Rolling Mean Loss = 2.2886 , Batch Accuracy = 37.75
# 	Batch  80, Loss = 2.2037 , Rolling Mean Loss = 2.2714 , Batch Accuracy = 36.75
# 	Batch 100, Loss = 2.3083 , Rolling Mean Loss = 2.2614 , Batch Accuracy = 38.0
# 	Batch 120, Loss = 2.2358 , Rolling Mean Loss = 2.2487 , Batch Accuracy = 41.5
# 	Batch 140, Loss = 2.29 , Rolling Mean Loss = 2.2588 , Batch Accuracy = 42.5
# 	Batch 160, Loss = 2.2595 , Rolling Mean Loss = 2.2631 , Batch Accuracy = 41.0
# 	Batch 180, Loss = 2.2631 , Rolling Mean Loss = 2.2641 , Batch Accuracy = 40.0
# 	Batch 200, Loss = 2.2861 , Rolling Mean Loss = 2.256 , Batch Accuracy = 41.0
# 	Batch 220, Loss = 2.4958 , Rolling Mean Loss = 2.2652 , Batch Accuracy = 34.5
# 	Train Accuracy (mean) =  39.56
# 	Test Accuracy         =  34.5
# Epoch 18
# 	Batch   0, Loss = 2.2129 , Rolling Mean Loss = 2.262 , Batch Accuracy = 41.5
# 	Batch  20, Loss = 2.1407 , Rolling Mean Loss = 2.2554 , Batch Accuracy = 43.0
# 	Batch  40, Loss = 1.9766 , Rolling Mean Loss = 2.24 , Batch Accuracy = 44.25
# 	Batch  60, Loss = 2.3076 , Rolling Mean Loss = 2.23 , Batch Accuracy = 38.5
# 	Batch  80, Loss = 2.2246 , Rolling Mean Loss = 2.2134 , Batch Accuracy = 37.5
# 	Batch 100, Loss = 2.1912 , Rolling Mean Loss = 2.2032 , Batch Accuracy = 42.5
# 	Batch 120, Loss = 2.0726 , Rolling Mean Loss = 2.1881 , Batch Accuracy = 45.25
# 	Batch 140, Loss = 2.4631 , Rolling Mean Loss = 2.1974 , Batch Accuracy = 37.75
# 	Batch 160, Loss = 2.1088 , Rolling Mean Loss = 2.2042 , Batch Accuracy = 41.5
# 	Batch 180, Loss = 2.2601 , Rolling Mean Loss = 2.2163 , Batch Accuracy = 37.0
# 	Batch 200, Loss = 2.3645 , Rolling Mean Loss = 2.2328 , Batch Accuracy = 37.75
# 	Batch 220, Loss = 2.0799 , Rolling Mean Loss = 2.2431 , Batch Accuracy = 41.5
# 	Train Accuracy (mean) =  40.3
# 	Test Accuracy         =  34.6
# Epoch 19
# 	Batch   0, Loss = 2.3281 , Rolling Mean Loss = 2.2428 , Batch Accuracy = 36.25
# 	Batch  20, Loss = 2.1494 , Rolling Mean Loss = 2.2202 , Batch Accuracy = 37.0
# 	Batch  40, Loss = 2.0996 , Rolling Mean Loss = 2.2089 , Batch Accuracy = 43.25
# 	Batch  60, Loss = 2.1899 , Rolling Mean Loss = 2.2057 , Batch Accuracy = 38.75
# 	Batch  80, Loss = 2.3831 , Rolling Mean Loss = 2.1844 , Batch Accuracy = 40.75
# 	Batch 100, Loss = 2.2384 , Rolling Mean Loss = 2.171 , Batch Accuracy = 38.25
# 	Batch 120, Loss = 2.0852 , Rolling Mean Loss = 2.1829 , Batch Accuracy = 40.25
# 	Batch 140, Loss = 2.1227 , Rolling Mean Loss = 2.1785 , Batch Accuracy = 39.25
# 	Batch 160, Loss = 2.4614 , Rolling Mean Loss = 2.1774 , Batch Accuracy = 35.25
# 	Batch 180, Loss = 2.1558 , Rolling Mean Loss = 2.1792 , Batch Accuracy = 40.75
# 	Batch 200, Loss = 2.1663 , Rolling Mean Loss = 2.1946 , Batch Accuracy = 41.5
# 	Batch 220, Loss = 2.478 , Rolling Mean Loss = 2.1966 , Batch Accuracy = 32.25
# 	Train Accuracy (mean) =  40.7
# 	Test Accuracy         =  32.6
# Epoch 20
# 	Batch   0, Loss = 1.896 , Rolling Mean Loss = 2.1879 , Batch Accuracy = 46.75
# 	Batch  20, Loss = 2.2261 , Rolling Mean Loss = 2.1812 , Batch Accuracy = 37.25
# 	Batch  40, Loss = 1.9011 , Rolling Mean Loss = 2.1683 , Batch Accuracy = 44.5
# 	Batch  60, Loss = 2.26 , Rolling Mean Loss = 2.1586 , Batch Accuracy = 36.75
# 	Batch  80, Loss = 2.416 , Rolling Mean Loss = 2.1499 , Batch Accuracy = 33.0
# 	Batch 100, Loss = 2.1867 , Rolling Mean Loss = 2.1423 , Batch Accuracy = 42.5
# 	Batch 120, Loss = 2.1467 , Rolling Mean Loss = 2.1427 , Batch Accuracy = 41.25
# 	Batch 140, Loss = 2.2203 , Rolling Mean Loss = 2.1514 , Batch Accuracy = 41.0
# 	Batch 160, Loss = 2.2033 , Rolling Mean Loss = 2.1564 , Batch Accuracy = 41.75
# 	Batch 180, Loss = 2.467 , Rolling Mean Loss = 2.1589 , Batch Accuracy = 37.5
# 	Batch 200, Loss = 2.3166 , Rolling Mean Loss = 2.143 , Batch Accuracy = 40.5
# 	Batch 220, Loss = 2.0434 , Rolling Mean Loss = 2.1555 , Batch Accuracy = 42.0
# 	Train Accuracy (mean) =  41.26
# 	Test Accuracy         =  34.6
# Epoch 21
# 	Batch   0, Loss = 2.3655 , Rolling Mean Loss = 2.1606 , Batch Accuracy = 36.25
# 	Batch  20, Loss = 1.8592 , Rolling Mean Loss = 2.1332 , Batch Accuracy = 48.25
# 	Batch  40, Loss = 2.0414 , Rolling Mean Loss = 2.126 , Batch Accuracy = 43.75
# 	Batch  60, Loss = 2.4593 , Rolling Mean Loss = 2.1304 , Batch Accuracy = 38.25
# 	Batch  80, Loss = 1.9978 , Rolling Mean Loss = 2.1386 , Batch Accuracy = 47.5
# 	Batch 100, Loss = 2.1228 , Rolling Mean Loss = 2.1192 , Batch Accuracy = 42.25
# 	Batch 120, Loss = 2.0935 , Rolling Mean Loss = 2.1131 , Batch Accuracy = 43.5
# 	Batch 140, Loss = 2.1732 , Rolling Mean Loss = 2.1039 , Batch Accuracy = 43.75
# 	Batch 160, Loss = 1.8954 , Rolling Mean Loss = 2.0999 , Batch Accuracy = 43.0
# 	Batch 180, Loss = 2.0466 , Rolling Mean Loss = 2.0905 , Batch Accuracy = 42.0
# 	Batch 200, Loss = 2.1875 , Rolling Mean Loss = 2.0828 , Batch Accuracy = 41.0
# 	Batch 220, Loss = 2.2333 , Rolling Mean Loss = 2.1084 , Batch Accuracy = 39.25
# 	Train Accuracy (mean) =  41.85
# 	Test Accuracy         =  35.2
# Epoch 22
# 	Batch   0, Loss = 2.1418 , Rolling Mean Loss = 2.1169 , Batch Accuracy = 44.75
# 	Batch  20, Loss = 2.0308 , Rolling Mean Loss = 2.1034 , Batch Accuracy = 44.25
# 	Batch  40, Loss = 2.1259 , Rolling Mean Loss = 2.0937 , Batch Accuracy = 41.0
# 	Batch  60, Loss = 2.2239 , Rolling Mean Loss = 2.0973 , Batch Accuracy = 43.0
# 	Batch  80, Loss = 2.3824 , Rolling Mean Loss = 2.0982 , Batch Accuracy = 38.25
# 	Batch 100, Loss = 2.1299 , Rolling Mean Loss = 2.0824 , Batch Accuracy = 36.75
# 	Batch 120, Loss = 2.0656 , Rolling Mean Loss = 2.0793 , Batch Accuracy = 42.75
# 	Batch 140, Loss = 2.1947 , Rolling Mean Loss = 2.0732 , Batch Accuracy = 41.25
# 	Batch 160, Loss = 2.1179 , Rolling Mean Loss = 2.0765 , Batch Accuracy = 41.75
# 	Batch 180, Loss = 2.0988 , Rolling Mean Loss = 2.074 , Batch Accuracy = 38.75
# 	Batch 200, Loss = 2.0311 , Rolling Mean Loss = 2.0704 , Batch Accuracy = 44.25
# 	Batch 220, Loss = 2.0161 , Rolling Mean Loss = 2.082 , Batch Accuracy = 44.0
# 	Train Accuracy (mean) =  42.28
# 	Test Accuracy         =  34.2
# Epoch 23
# 	Batch   0, Loss = 2.1713 , Rolling Mean Loss = 2.0795 , Batch Accuracy = 44.75
# 	Batch  20, Loss = 2.1816 , Rolling Mean Loss = 2.0694 , Batch Accuracy = 38.25
# 	Batch  40, Loss = 2.1559 , Rolling Mean Loss = 2.0601 , Batch Accuracy = 43.25
# 	Batch  60, Loss = 2.0853 , Rolling Mean Loss = 2.0549 , Batch Accuracy = 45.75
# 	Batch  80, Loss = 1.962 , Rolling Mean Loss = 2.0428 , Batch Accuracy = 41.25
# 	Batch 100, Loss = 1.9646 , Rolling Mean Loss = 2.0286 , Batch Accuracy = 39.5
# 	Batch 120, Loss = 1.8709 , Rolling Mean Loss = 2.0278 , Batch Accuracy = 45.75
# 	Batch 140, Loss = 2.1025 , Rolling Mean Loss = 2.0295 , Batch Accuracy = 44.0
# 	Batch 160, Loss = 2.1958 , Rolling Mean Loss = 2.0393 , Batch Accuracy = 42.5
# 	Batch 180, Loss = 2.1122 , Rolling Mean Loss = 2.0492 , Batch Accuracy = 41.5
# 	Batch 200, Loss = 1.8926 , Rolling Mean Loss = 2.0624 , Batch Accuracy = 41.25
# 	Batch 220, Loss = 2.1143 , Rolling Mean Loss = 2.0729 , Batch Accuracy = 43.0
# 	Train Accuracy (mean) =  42.96
# 	Test Accuracy         =  34.0
# Epoch 24
# 	Batch   0, Loss = 1.9898 , Rolling Mean Loss = 2.0782 , Batch Accuracy = 43.75
# 	Batch  20, Loss = 1.8914 , Rolling Mean Loss = 2.0616 , Batch Accuracy = 45.5
# 	Batch  40, Loss = 2.2321 , Rolling Mean Loss = 2.0531 , Batch Accuracy = 36.25
# 	Batch  60, Loss = 2.1488 , Rolling Mean Loss = 2.0253 , Batch Accuracy = 44.75
# 	Batch  80, Loss = 2.0253 , Rolling Mean Loss = 2.0073 , Batch Accuracy = 40.25
# 	Batch 100, Loss = 2.1065 , Rolling Mean Loss = 2.0015 , Batch Accuracy = 41.5
# 	Batch 120, Loss = 2.1289 , Rolling Mean Loss = 2.0186 , Batch Accuracy = 39.25
# 	Batch 140, Loss = 2.1188 , Rolling Mean Loss = 2.0172 , Batch Accuracy = 42.75
# 	Batch 160, Loss = 2.069 , Rolling Mean Loss = 2.0357 , Batch Accuracy = 43.25
# 	Batch 180, Loss = 2.0712 , Rolling Mean Loss = 2.051 , Batch Accuracy = 41.5
# 	Batch 200, Loss = 2.121 , Rolling Mean Loss = 2.0512 , Batch Accuracy = 39.25
# 	Batch 220, Loss = 2.0006 , Rolling Mean Loss = 2.0387 , Batch Accuracy = 42.75
# 	Train Accuracy (mean) =  43.07
# 	Test Accuracy         =  34.3
# Epoch 25
# 	Batch   0, Loss = 1.9891 , Rolling Mean Loss = 2.0305 , Batch Accuracy = 43.75
# 	Batch  20, Loss = 2.0175 , Rolling Mean Loss = 2.0272 , Batch Accuracy = 45.25
# 	Batch  40, Loss = 2.2316 , Rolling Mean Loss = 2.0176 , Batch Accuracy = 39.75
# 	Batch  60, Loss = 2.1928 , Rolling Mean Loss = 2.0216 , Batch Accuracy = 43.5
# 	Batch  80, Loss = 1.9364 , Rolling Mean Loss = 2.0133 , Batch Accuracy = 40.5
# 	Batch 100, Loss = 2.2093 , Rolling Mean Loss = 2.0101 , Batch Accuracy = 38.0
# 	Batch 120, Loss = 1.847 , Rolling Mean Loss = 2.0003 , Batch Accuracy = 45.25
# 	Batch 140, Loss = 1.8232 , Rolling Mean Loss = 1.9943 , Batch Accuracy = 45.75
# 	Batch 160, Loss = 2.1082 , Rolling Mean Loss = 1.9883 , Batch Accuracy = 41.25
# 	Batch 180, Loss = 1.9985 , Rolling Mean Loss = 1.9854 , Batch Accuracy = 43.25
# 	Batch 200, Loss = 1.8226 , Rolling Mean Loss = 1.9849 , Batch Accuracy = 47.0
# 	Batch 220, Loss = 2.108 , Rolling Mean Loss = 1.9865 , Batch Accuracy = 43.5
# 	Train Accuracy (mean) =  43.47
# 	Test Accuracy         =  35.0
# Epoch 26
# 	Batch   0, Loss = 1.9168 , Rolling Mean Loss = 1.9836 , Batch Accuracy = 46.25
# 	Batch  20, Loss = 1.8225 , Rolling Mean Loss = 1.9728 , Batch Accuracy = 43.25
# 	Batch  40, Loss = 1.8955 , Rolling Mean Loss = 1.9683 , Batch Accuracy = 45.5
# 	Batch  60, Loss = 1.9667 , Rolling Mean Loss = 1.9696 , Batch Accuracy = 45.0
# 	Batch  80, Loss = 1.842 , Rolling Mean Loss = 1.9673 , Batch Accuracy = 46.5
# 	Batch 100, Loss = 1.9677 , Rolling Mean Loss = 1.9596 , Batch Accuracy = 45.25
# 	Batch 120, Loss = 2.012 , Rolling Mean Loss = 1.9773 , Batch Accuracy = 42.0
# 	Batch 140, Loss = 2.0051 , Rolling Mean Loss = 1.9731 , Batch Accuracy = 45.0
# 	Batch 160, Loss = 2.12 , Rolling Mean Loss = 1.9643 , Batch Accuracy = 41.0
# 	Batch 180, Loss = 2.1345 , Rolling Mean Loss = 1.9654 , Batch Accuracy = 38.75
# 	Batch 200, Loss = 2.1097 , Rolling Mean Loss = 1.9786 , Batch Accuracy = 43.5
# 	Batch 220, Loss = 1.8592 , Rolling Mean Loss = 1.9727 , Batch Accuracy = 47.25
# 	Train Accuracy (mean) =  43.93
# 	Test Accuracy         =  35.1
# Epoch 27
# 	Batch   0, Loss = 2.093 , Rolling Mean Loss = 1.9896 , Batch Accuracy = 39.75
# 	Batch  20, Loss = 1.9497 , Rolling Mean Loss = 1.9802 , Batch Accuracy = 47.5
# 	Batch  40, Loss = 1.7575 , Rolling Mean Loss = 1.9661 , Batch Accuracy = 49.25
# 	Batch  60, Loss = 1.8392 , Rolling Mean Loss = 1.9612 , Batch Accuracy = 46.75
# 	Batch  80, Loss = 1.8416 , Rolling Mean Loss = 1.944 , Batch Accuracy = 45.25
# 	Batch 100, Loss = 1.9391 , Rolling Mean Loss = 1.9246 , Batch Accuracy = 42.0
# 	Batch 120, Loss = 2.0478 , Rolling Mean Loss = 1.9386 , Batch Accuracy = 47.0
# 	Batch 140, Loss = 1.9329 , Rolling Mean Loss = 1.9407 , Batch Accuracy = 48.75
# 	Batch 160, Loss = 1.9337 , Rolling Mean Loss = 1.9421 , Batch Accuracy = 44.0
# 	Batch 180, Loss = 1.7814 , Rolling Mean Loss = 1.9483 , Batch Accuracy = 46.5
# 	Batch 200, Loss = 1.827 , Rolling Mean Loss = 1.9493 , Batch Accuracy = 45.0
# 	Batch 220, Loss = 2.0953 , Rolling Mean Loss = 1.9605 , Batch Accuracy = 44.75
# 	Train Accuracy (mean) =  44.18
# 	Test Accuracy         =  35.6
# Epoch 28
# 	Batch   0, Loss = 2.0473 , Rolling Mean Loss = 1.9643 , Batch Accuracy = 43.75
# 	Batch  20, Loss = 1.8006 , Rolling Mean Loss = 1.9497 , Batch Accuracy = 44.0
# 	Batch  40, Loss = 2.0444 , Rolling Mean Loss = 1.9291 , Batch Accuracy = 43.25
# 	Batch  60, Loss = 2.0528 , Rolling Mean Loss = 1.9153 , Batch Accuracy = 42.25
# 	Batch  80, Loss = 2.0059 , Rolling Mean Loss = 1.904 , Batch Accuracy = 43.75
# 	Batch 100, Loss = 2.0183 , Rolling Mean Loss = 1.8897 , Batch Accuracy = 44.25
# 	Batch 120, Loss = 1.8371 , Rolling Mean Loss = 1.897 , Batch Accuracy = 46.5
# 	Batch 140, Loss = 2.2115 , Rolling Mean Loss = 1.9077 , Batch Accuracy = 41.5
# 	Batch 160, Loss = 2.0182 , Rolling Mean Loss = 1.9206 , Batch Accuracy = 42.25
# 	Batch 180, Loss = 2.0515 , Rolling Mean Loss = 1.9284 , Batch Accuracy = 41.5
# 	Batch 200, Loss = 2.0028 , Rolling Mean Loss = 1.9312 , Batch Accuracy = 42.25
# 	Batch 220, Loss = 1.9537 , Rolling Mean Loss = 1.9366 , Batch Accuracy = 43.0
# 	Train Accuracy (mean) =  44.63
# 	Test Accuracy         =  34.4
# Epoch 29
# 	Batch   0, Loss = 1.9297 , Rolling Mean Loss = 1.9475 , Batch Accuracy = 42.75
# 	Batch  20, Loss = 1.7724 , Rolling Mean Loss = 1.9286 , Batch Accuracy = 48.0
# 	Batch  40, Loss = 2.0644 , Rolling Mean Loss = 1.9219 , Batch Accuracy = 41.0
# 	Batch  60, Loss = 2.0119 , Rolling Mean Loss = 1.9074 , Batch Accuracy = 43.5
# 	Batch  80, Loss = 1.9515 , Rolling Mean Loss = 1.9032 , Batch Accuracy = 42.0
# 	Batch 100, Loss = 1.8157 , Rolling Mean Loss = 1.8871 , Batch Accuracy = 43.75
# 	Batch 120, Loss = 1.8848 , Rolling Mean Loss = 1.8971 , Batch Accuracy = 43.5
# 	Batch 140, Loss = 1.8613 , Rolling Mean Loss = 1.9035 , Batch Accuracy = 45.5
# 	Batch 160, Loss = 1.7713 , Rolling Mean Loss = 1.9095 , Batch Accuracy = 46.25
# 	Batch 180, Loss = 1.8158 , Rolling Mean Loss = 1.9113 , Batch Accuracy = 47.0
# 	Batch 200, Loss = 1.9915 , Rolling Mean Loss = 1.91 , Batch Accuracy = 40.25
# 	Batch 220, Loss = 1.9774 , Rolling Mean Loss = 1.9151 , Batch Accuracy = 43.0
# 	Train Accuracy (mean) =  44.88
# 	Test Accuracy         =  36.7
# Epoch 30
# 	Batch   0, Loss = 1.6792 , Rolling Mean Loss = 1.9065 , Batch Accuracy = 45.5
# 	Batch  20, Loss = 1.8089 , Rolling Mean Loss = 1.8881 , Batch Accuracy = 46.75
# 	Batch  40, Loss = 1.8946 , Rolling Mean Loss = 1.8733 , Batch Accuracy = 43.5
# 	Batch  60, Loss = 1.9728 , Rolling Mean Loss = 1.8719 , Batch Accuracy = 43.25
# 	Batch  80, Loss = 2.1318 , Rolling Mean Loss = 1.8539 , Batch Accuracy = 38.5
# 	Batch 100, Loss = 1.7236 , Rolling Mean Loss = 1.8587 , Batch Accuracy = 47.5
# 	Batch 120, Loss = 1.8273 , Rolling Mean Loss = 1.8606 , Batch Accuracy = 45.25
# 	Batch 140, Loss = 1.8348 , Rolling Mean Loss = 1.8699 , Batch Accuracy = 41.5
# 	Batch 160, Loss = 2.1134 , Rolling Mean Loss = 1.8816 , Batch Accuracy = 40.0
# 	Batch 180, Loss = 1.9664 , Rolling Mean Loss = 1.9003 , Batch Accuracy = 44.5
# 	Batch 200, Loss = 1.8347 , Rolling Mean Loss = 1.8993 , Batch Accuracy = 47.0
# 	Batch 220, Loss = 1.9886 , Rolling Mean Loss = 1.9079 , Batch Accuracy = 44.5
# 	Train Accuracy (mean) =  45.04
# 	Test Accuracy         =  35.4
# Epoch 31
# 	Batch   0, Loss = 1.91 , Rolling Mean Loss = 1.9128 , Batch Accuracy = 43.25
# 	Batch  20, Loss = 1.7845 , Rolling Mean Loss = 1.8936 , Batch Accuracy = 46.0
# 	Batch  40, Loss = 1.8226 , Rolling Mean Loss = 1.8813 , Batch Accuracy = 46.75
# 	Batch  60, Loss = 1.9508 , Rolling Mean Loss = 1.8745 , Batch Accuracy = 44.5
# 	Batch  80, Loss = 1.7343 , Rolling Mean Loss = 1.8669 , Batch Accuracy = 44.75
# 	Batch 100, Loss = 1.9238 , Rolling Mean Loss = 1.8516 , Batch Accuracy = 43.5
# 	Batch 120, Loss = 1.8466 , Rolling Mean Loss = 1.8693 , Batch Accuracy = 47.75
# 	Batch 140, Loss = 2.0769 , Rolling Mean Loss = 1.8669 , Batch Accuracy = 40.75
# 	Batch 160, Loss = 1.758 , Rolling Mean Loss = 1.8608 , Batch Accuracy = 47.0
# 	Batch 180, Loss = 1.9239 , Rolling Mean Loss = 1.8671 , Batch Accuracy = 43.25
# 	Batch 200, Loss = 1.8146 , Rolling Mean Loss = 1.8735 , Batch Accuracy = 44.5
# 	Batch 220, Loss = 1.725 , Rolling Mean Loss = 1.8723 , Batch Accuracy = 47.75
# 	Train Accuracy (mean) =  45.37
# 	Test Accuracy         =  34.4
# Epoch 32
# 	Batch   0, Loss = 1.7988 , Rolling Mean Loss = 1.8689 , Batch Accuracy = 48.75
# 	Batch  20, Loss = 1.7032 , Rolling Mean Loss = 1.8622 , Batch Accuracy = 46.25
# 	Batch  40, Loss = 2.0829 , Rolling Mean Loss = 1.8547 , Batch Accuracy = 43.25
# 	Batch  60, Loss = 1.8212 , Rolling Mean Loss = 1.8465 , Batch Accuracy = 46.75
# 	Batch  80, Loss = 1.7642 , Rolling Mean Loss = 1.838 , Batch Accuracy = 46.25
# 	Batch 100, Loss = 2.0514 , Rolling Mean Loss = 1.8452 , Batch Accuracy = 42.75
# 	Batch 120, Loss = 2.055 , Rolling Mean Loss = 1.8509 , Batch Accuracy = 41.5
# 	Batch 140, Loss = 1.8223 , Rolling Mean Loss = 1.8591 , Batch Accuracy = 44.5
# 	Batch 160, Loss = 1.8471 , Rolling Mean Loss = 1.8518 , Batch Accuracy = 48.25
# 	Batch 180, Loss = 2.0036 , Rolling Mean Loss = 1.8429 , Batch Accuracy = 40.75
# 	Batch 200, Loss = 1.7243 , Rolling Mean Loss = 1.8344 , Batch Accuracy = 49.75
# 	Batch 220, Loss = 1.6897 , Rolling Mean Loss = 1.8429 , Batch Accuracy = 48.5
# 	Train Accuracy (mean) =  45.69
# 	Test Accuracy         =  35.5
# Epoch 33
# 	Batch   0, Loss = 1.7314 , Rolling Mean Loss = 1.8404 , Batch Accuracy = 46.75
# 	Batch  20, Loss = 1.8415 , Rolling Mean Loss = 1.826 , Batch Accuracy = 48.25
# 	Batch  40, Loss = 1.9613 , Rolling Mean Loss = 1.8292 , Batch Accuracy = 41.0
# 	Batch  60, Loss = 1.841 , Rolling Mean Loss = 1.8303 , Batch Accuracy = 47.5
# 	Batch  80, Loss = 1.8537 , Rolling Mean Loss = 1.8256 , Batch Accuracy = 48.75
# 	Batch 100, Loss = 1.7031 , Rolling Mean Loss = 1.8111 , Batch Accuracy = 49.5
# 	Batch 120, Loss = 1.8686 , Rolling Mean Loss = 1.8158 , Batch Accuracy = 45.75
# 	Batch 140, Loss = 1.8872 , Rolling Mean Loss = 1.8165 , Batch Accuracy = 45.5
# 	Batch 160, Loss = 1.8477 , Rolling Mean Loss = 1.8282 , Batch Accuracy = 43.0
# 	Batch 180, Loss = 1.6819 , Rolling Mean Loss = 1.8283 , Batch Accuracy = 48.25
# 	Batch 200, Loss = 1.7972 , Rolling Mean Loss = 1.8299 , Batch Accuracy = 44.5
# 	Batch 220, Loss = 1.8007 , Rolling Mean Loss = 1.8477 , Batch Accuracy = 45.75
# 	Train Accuracy (mean) =  45.78
# 	Test Accuracy         =  35.1
# Epoch 34
# 	Batch   0, Loss = 1.8344 , Rolling Mean Loss = 1.8488 , Batch Accuracy = 46.25
# 	Batch  20, Loss = 1.786 , Rolling Mean Loss = 1.8288 , Batch Accuracy = 46.5
# 	Batch  40, Loss = 1.5133 , Rolling Mean Loss = 1.8109 , Batch Accuracy = 49.0
# 	Batch  60, Loss = 1.7251 , Rolling Mean Loss = 1.8054 , Batch Accuracy = 50.5
# 	Batch  80, Loss = 1.8585 , Rolling Mean Loss = 1.8047 , Batch Accuracy = 44.25
# 	Batch 100, Loss = 1.8294 , Rolling Mean Loss = 1.806 , Batch Accuracy = 44.5
# 	Batch 120, Loss = 1.734 , Rolling Mean Loss = 1.8063 , Batch Accuracy = 50.5
# 	Batch 140, Loss = 1.7421 , Rolling Mean Loss = 1.8129 , Batch Accuracy = 48.25
# 	Batch 160, Loss = 1.9769 , Rolling Mean Loss = 1.8206 , Batch Accuracy = 44.75
# 	Batch 180, Loss = 1.7014 , Rolling Mean Loss = 1.8161 , Batch Accuracy = 45.25
# 	Batch 200, Loss = 1.7064 , Rolling Mean Loss = 1.8087 , Batch Accuracy = 47.0
# 	Batch 220, Loss = 1.9288 , Rolling Mean Loss = 1.8116 , Batch Accuracy = 43.5
# 	Train Accuracy (mean) =  46.19
# 	Test Accuracy         =  34.4
# Epoch 35
# 	Batch   0, Loss = 1.6905 , Rolling Mean Loss = 1.8128 , Batch Accuracy = 48.25
# 	Batch  20, Loss = 1.9363 , Rolling Mean Loss = 1.817 , Batch Accuracy = 44.25
# 	Batch  40, Loss = 1.8386 , Rolling Mean Loss = 1.7963 , Batch Accuracy = 47.25
# 	Batch  60, Loss = 1.8037 , Rolling Mean Loss = 1.7946 , Batch Accuracy = 49.0
# 	Batch  80, Loss = 1.7624 , Rolling Mean Loss = 1.7932 , Batch Accuracy = 48.25
# 	Batch 100, Loss = 1.7795 , Rolling Mean Loss = 1.7805 , Batch Accuracy = 43.0
# 	Batch 120, Loss = 1.8272 , Rolling Mean Loss = 1.7745 , Batch Accuracy = 45.0
# 	Batch 140, Loss = 1.7702 , Rolling Mean Loss = 1.7772 , Batch Accuracy = 47.0
# 	Batch 160, Loss = 1.5512 , Rolling Mean Loss = 1.775 , Batch Accuracy = 50.25
# 	Batch 180, Loss = 1.699 , Rolling Mean Loss = 1.7799 , Batch Accuracy = 47.5
# 	Batch 200, Loss = 1.8324 , Rolling Mean Loss = 1.7915 , Batch Accuracy = 44.25
# 	Batch 220, Loss = 1.7057 , Rolling Mean Loss = 1.7985 , Batch Accuracy = 46.0
# 	Train Accuracy (mean) =  46.35
# 	Test Accuracy         =  36.3
# Epoch 36
# 	Batch   0, Loss = 1.6395 , Rolling Mean Loss = 1.8026 , Batch Accuracy = 43.25
# 	Batch  20, Loss = 1.7213 , Rolling Mean Loss = 1.7901 , Batch Accuracy = 50.0
# 	Batch  40, Loss = 1.8316 , Rolling Mean Loss = 1.7785 , Batch Accuracy = 40.75
# 	Batch  60, Loss = 1.8988 , Rolling Mean Loss = 1.7666 , Batch Accuracy = 44.0
# 	Batch  80, Loss = 1.7101 , Rolling Mean Loss = 1.7624 , Batch Accuracy = 47.25
# 	Batch 100, Loss = 1.712 , Rolling Mean Loss = 1.7606 , Batch Accuracy = 47.0
# 	Batch 120, Loss = 1.7482 , Rolling Mean Loss = 1.7664 , Batch Accuracy = 43.75
# 	Batch 140, Loss = 1.784 , Rolling Mean Loss = 1.7697 , Batch Accuracy = 44.25
# 	Batch 160, Loss = 1.8393 , Rolling Mean Loss = 1.7734 , Batch Accuracy = 44.0
# 	Batch 180, Loss = 2.066 , Rolling Mean Loss = 1.7765 , Batch Accuracy = 42.25
# 	Batch 200, Loss = 1.9264 , Rolling Mean Loss = 1.7778 , Batch Accuracy = 44.5
# 	Batch 220, Loss = 1.7118 , Rolling Mean Loss = 1.7853 , Batch Accuracy = 48.75
# 	Train Accuracy (mean) =  46.74
# 	Test Accuracy         =  34.5
# Epoch 37
# 	Batch   0, Loss = 1.6047 , Rolling Mean Loss = 1.7941 , Batch Accuracy = 49.25
# 	Batch  20, Loss = 1.5649 , Rolling Mean Loss = 1.7808 , Batch Accuracy = 48.75
# 	Batch  40, Loss = 1.7113 , Rolling Mean Loss = 1.7679 , Batch Accuracy = 44.25
# 	Batch  60, Loss = 1.8633 , Rolling Mean Loss = 1.7527 , Batch Accuracy = 46.75
# 	Batch  80, Loss = 1.7016 , Rolling Mean Loss = 1.7426 , Batch Accuracy = 48.0
# 	Batch 100, Loss = 1.9302 , Rolling Mean Loss = 1.7278 , Batch Accuracy = 42.25
# 	Batch 120, Loss = 1.8544 , Rolling Mean Loss = 1.7379 , Batch Accuracy = 48.25
# 	Batch 140, Loss = 1.9911 , Rolling Mean Loss = 1.7413 , Batch Accuracy = 46.25
# 	Batch 160, Loss = 1.5617 , Rolling Mean Loss = 1.7491 , Batch Accuracy = 47.75
# 	Batch 180, Loss = 1.6847 , Rolling Mean Loss = 1.7502 , Batch Accuracy = 47.0
# 	Batch 200, Loss = 1.9579 , Rolling Mean Loss = 1.7542 , Batch Accuracy = 44.75
# 	Batch 220, Loss = 1.6579 , Rolling Mean Loss = 1.7626 , Batch Accuracy = 54.0
# 	Train Accuracy (mean) =  46.9
# 	Test Accuracy         =  35.0
# Epoch 38
# 	Batch   0, Loss = 1.8068 , Rolling Mean Loss = 1.7667 , Batch Accuracy = 48.0
# 	Batch  20, Loss = 1.7462 , Rolling Mean Loss = 1.7528 , Batch Accuracy = 50.25
# 	Batch  40, Loss = 1.7696 , Rolling Mean Loss = 1.7422 , Batch Accuracy = 46.0
# 	Batch  60, Loss = 1.5446 , Rolling Mean Loss = 1.7369 , Batch Accuracy = 48.75
# 	Batch  80, Loss = 1.9503 , Rolling Mean Loss = 1.7298 , Batch Accuracy = 42.25
# 	Batch 100, Loss = 1.5757 , Rolling Mean Loss = 1.7215 , Batch Accuracy = 52.5
# 	Batch 120, Loss = 1.617 , Rolling Mean Loss = 1.7211 , Batch Accuracy = 46.75
# 	Batch 140, Loss = 1.7804 , Rolling Mean Loss = 1.7195 , Batch Accuracy = 44.25
# 	Batch 160, Loss = 1.7975 , Rolling Mean Loss = 1.7338 , Batch Accuracy = 47.25
# 	Batch 180, Loss = 1.6992 , Rolling Mean Loss = 1.7419 , Batch Accuracy = 47.0
# 	Batch 200, Loss = 1.7958 , Rolling Mean Loss = 1.748 , Batch Accuracy = 46.5
# 	Batch 220, Loss = 1.8934 , Rolling Mean Loss = 1.7516 , Batch Accuracy = 44.75
# 	Train Accuracy (mean) =  46.98
# 	Test Accuracy         =  35.6
# Epoch 39
# 	Batch   0, Loss = 1.6602 , Rolling Mean Loss = 1.7582 , Batch Accuracy = 49.5
# 	Batch  20, Loss = 1.8119 , Rolling Mean Loss = 1.7509 , Batch Accuracy = 47.25
# 	Batch  40, Loss = 1.6798 , Rolling Mean Loss = 1.7253 , Batch Accuracy = 47.25
# 	Batch  60, Loss = 1.5736 , Rolling Mean Loss = 1.7055 , Batch Accuracy = 50.0
# 	Batch  80, Loss = 1.7738 , Rolling Mean Loss = 1.7072 , Batch Accuracy = 49.25
# 	Batch 100, Loss = 1.7294 , Rolling Mean Loss = 1.6981 , Batch Accuracy = 48.5
# 	Batch 120, Loss = 1.8305 , Rolling Mean Loss = 1.6977 , Batch Accuracy = 45.25
# 	Batch 140, Loss = 1.7592 , Rolling Mean Loss = 1.71 , Batch Accuracy = 46.75
# 	Batch 160, Loss = 1.8737 , Rolling Mean Loss = 1.7213 , Batch Accuracy = 49.5
# 	Batch 180, Loss = 1.8232 , Rolling Mean Loss = 1.7266 , Batch Accuracy = 47.0
# 	Batch 200, Loss = 1.693 , Rolling Mean Loss = 1.7241 , Batch Accuracy = 46.5
# 	Batch 220, Loss = 1.6632 , Rolling Mean Loss = 1.7322 , Batch Accuracy = 48.0
# 	Train Accuracy (mean) =  47.57
# 	Test Accuracy         =  35.6
# Epoch 40
# 	Batch   0, Loss = 1.6604 , Rolling Mean Loss = 1.728 , Batch Accuracy = 46.5
# 	Batch  20, Loss = 1.863 , Rolling Mean Loss = 1.7198 , Batch Accuracy = 44.0
# 	Batch  40, Loss = 1.6568 , Rolling Mean Loss = 1.7124 , Batch Accuracy = 47.25
# 	Batch  60, Loss = 1.496 , Rolling Mean Loss = 1.7066 , Batch Accuracy = 52.25
# 	Batch  80, Loss = 1.7212 , Rolling Mean Loss = 1.7029 , Batch Accuracy = 47.75
# 	Batch 100, Loss = 1.8009 , Rolling Mean Loss = 1.696 , Batch Accuracy = 46.75
# 	Batch 120, Loss = 1.5674 , Rolling Mean Loss = 1.7048 , Batch Accuracy = 49.5
# 	Batch 140, Loss = 1.7387 , Rolling Mean Loss = 1.7155 , Batch Accuracy = 48.75
# 	Batch 160, Loss = 1.5228 , Rolling Mean Loss = 1.7158 , Batch Accuracy = 49.0
# 	Batch 180, Loss = 1.5772 , Rolling Mean Loss = 1.7134 , Batch Accuracy = 48.25
# 	Batch 200, Loss = 1.5699 , Rolling Mean Loss = 1.7104 , Batch Accuracy = 51.0
# 	Batch 220, Loss = 1.8236 , Rolling Mean Loss = 1.7182 , Batch Accuracy = 46.0
# 	Train Accuracy (mean) =  47.56
# 	Test Accuracy         =  34.8
# Epoch 41
# 	Batch   0, Loss = 1.5392 , Rolling Mean Loss = 1.7073 , Batch Accuracy = 52.25
# 	Batch  20, Loss = 1.8578 , Rolling Mean Loss = 1.7011 , Batch Accuracy = 47.5
# 	Batch  40, Loss = 1.5081 , Rolling Mean Loss = 1.6969 , Batch Accuracy = 50.5
# 	Batch  60, Loss = 1.9322 , Rolling Mean Loss = 1.6966 , Batch Accuracy = 41.75
# 	Batch  80, Loss = 1.6756 , Rolling Mean Loss = 1.6839 , Batch Accuracy = 48.5
# 	Batch 100, Loss = 1.806 , Rolling Mean Loss = 1.6734 , Batch Accuracy = 46.75
# 	Batch 120, Loss = 1.8768 , Rolling Mean Loss = 1.6851 , Batch Accuracy = 44.0
# 	Batch 140, Loss = 1.8148 , Rolling Mean Loss = 1.6943 , Batch Accuracy = 47.5
# 	Batch 160, Loss = 1.5837 , Rolling Mean Loss = 1.7014 , Batch Accuracy = 45.75
# 	Batch 180, Loss = 1.6847 , Rolling Mean Loss = 1.7022 , Batch Accuracy = 46.25
# 	Batch 200, Loss = 1.7745 , Rolling Mean Loss = 1.7052 , Batch Accuracy = 47.5
# 	Batch 220, Loss = 1.777 , Rolling Mean Loss = 1.6957 , Batch Accuracy = 45.25
# 	Train Accuracy (mean) =  47.94
# 	Test Accuracy         =  35.3
# Epoch 42
# 	Batch   0, Loss = 1.7296 , Rolling Mean Loss = 1.6997 , Batch Accuracy = 45.75
# 	Batch  20, Loss = 1.9202 , Rolling Mean Loss = 1.6812 , Batch Accuracy = 42.0
# 	Batch  40, Loss = 1.6442 , Rolling Mean Loss = 1.6751 , Batch Accuracy = 50.0
# 	Batch  60, Loss = 1.6624 , Rolling Mean Loss = 1.6745 , Batch Accuracy = 47.75
# 	Batch  80, Loss = 1.7164 , Rolling Mean Loss = 1.6787 , Batch Accuracy = 47.5
# 	Batch 100, Loss = 1.75 , Rolling Mean Loss = 1.6685 , Batch Accuracy = 46.0
# 	Batch 120, Loss = 1.7251 , Rolling Mean Loss = 1.6771 , Batch Accuracy = 46.5
# 	Batch 140, Loss = 1.6528 , Rolling Mean Loss = 1.6847 , Batch Accuracy = 48.75
# 	Batch 160, Loss = 1.7201 , Rolling Mean Loss = 1.6886 , Batch Accuracy = 49.25
# 	Batch 180, Loss = 1.5968 , Rolling Mean Loss = 1.6842 , Batch Accuracy = 49.0
# 	Batch 200, Loss = 1.5664 , Rolling Mean Loss = 1.6852 , Batch Accuracy = 49.25
# 	Batch 220, Loss = 1.6862 , Rolling Mean Loss = 1.6823 , Batch Accuracy = 47.5
# 	Train Accuracy (mean) =  48.13
# 	Test Accuracy         =  34.8
# Epoch 43
# 	Batch   0, Loss = 1.7031 , Rolling Mean Loss = 1.6808 , Batch Accuracy = 51.5
# 	Batch  20, Loss = 1.6587 , Rolling Mean Loss = 1.6597 , Batch Accuracy = 49.0
# 	Batch  40, Loss = 1.6436 , Rolling Mean Loss = 1.6547 , Batch Accuracy = 45.5
# 	Batch  60, Loss = 1.6425 , Rolling Mean Loss = 1.6451 , Batch Accuracy = 50.25
# 	Batch  80, Loss = 1.7434 , Rolling Mean Loss = 1.6459 , Batch Accuracy = 45.75
# 	Batch 100, Loss = 1.7096 , Rolling Mean Loss = 1.6372 , Batch Accuracy = 48.75
# 	Batch 120, Loss = 1.5007 , Rolling Mean Loss = 1.658 , Batch Accuracy = 53.5
# 	Batch 140, Loss = 1.5408 , Rolling Mean Loss = 1.6532 , Batch Accuracy = 48.25
# 	Batch 160, Loss = 1.6647 , Rolling Mean Loss = 1.6659 , Batch Accuracy = 49.75
# 	Batch 180, Loss = 1.584 , Rolling Mean Loss = 1.6731 , Batch Accuracy = 51.5
# 	Batch 200, Loss = 1.5099 , Rolling Mean Loss = 1.6775 , Batch Accuracy = 49.0
# 	Batch 220, Loss = 1.8689 , Rolling Mean Loss = 1.6797 , Batch Accuracy = 43.25
# 	Train Accuracy (mean) =  48.33
# 	Test Accuracy         =  33.6
# Epoch 44
# 	Batch   0, Loss = 1.3864 , Rolling Mean Loss = 1.6743 , Batch Accuracy = 51.5
# 	Batch  20, Loss = 1.4104 , Rolling Mean Loss = 1.6624 , Batch Accuracy = 50.5
# 	Batch  40, Loss = 1.8275 , Rolling Mean Loss = 1.6586 , Batch Accuracy = 43.5
# 	Batch  60, Loss = 1.6287 , Rolling Mean Loss = 1.6575 , Batch Accuracy = 50.0
# 	Batch  80, Loss = 1.546 , Rolling Mean Loss = 1.6446 , Batch Accuracy = 51.25
# 	Batch 100, Loss = 1.6754 , Rolling Mean Loss = 1.639 , Batch Accuracy = 45.0
# 	Batch 120, Loss = 1.716 , Rolling Mean Loss = 1.6522 , Batch Accuracy = 47.5
# 	Batch 140, Loss = 1.5998 , Rolling Mean Loss = 1.644 , Batch Accuracy = 52.5
# 	Batch 160, Loss = 1.6318 , Rolling Mean Loss = 1.646 , Batch Accuracy = 51.0
# 	Batch 180, Loss = 1.6069 , Rolling Mean Loss = 1.6565 , Batch Accuracy = 48.5
# 	Batch 200, Loss = 1.7168 , Rolling Mean Loss = 1.6606 , Batch Accuracy = 44.5
# 	Batch 220, Loss = 1.8267 , Rolling Mean Loss = 1.6723 , Batch Accuracy = 46.0
# 	Train Accuracy (mean) =  48.47
# 	Test Accuracy         =  35.5
# Epoch 45
# 	Batch   0, Loss = 1.5798 , Rolling Mean Loss = 1.6781 , Batch Accuracy = 51.25
# 	Batch  20, Loss = 1.6089 , Rolling Mean Loss = 1.6656 , Batch Accuracy = 51.5
# 	Batch  40, Loss = 1.5648 , Rolling Mean Loss = 1.6556 , Batch Accuracy = 51.0
# 	Batch  60, Loss = 1.6469 , Rolling Mean Loss = 1.6456 , Batch Accuracy = 52.5
# 	Batch  80, Loss = 1.5603 , Rolling Mean Loss = 1.6387 , Batch Accuracy = 47.75
# 	Batch 100, Loss = 1.6759 , Rolling Mean Loss = 1.6171 , Batch Accuracy = 47.0
# 	Batch 120, Loss = 1.6977 , Rolling Mean Loss = 1.6252 , Batch Accuracy = 48.75
# 	Batch 140, Loss = 1.5839 , Rolling Mean Loss = 1.6295 , Batch Accuracy = 53.5
# 	Batch 160, Loss = 1.7228 , Rolling Mean Loss = 1.6338 , Batch Accuracy = 43.5
# 	Batch 180, Loss = 1.6145 , Rolling Mean Loss = 1.6274 , Batch Accuracy = 50.0
# 	Batch 200, Loss = 1.7579 , Rolling Mean Loss = 1.647 , Batch Accuracy = 47.5
# 	Batch 220, Loss = 1.5885 , Rolling Mean Loss = 1.6408 , Batch Accuracy = 49.75
# 	Train Accuracy (mean) =  49.02
# 	Test Accuracy         =  35.2
# Epoch 46
# 	Batch   0, Loss = 1.5172 , Rolling Mean Loss = 1.6435 , Batch Accuracy = 51.5
# 	Batch  20, Loss = 1.5666 , Rolling Mean Loss = 1.6392 , Batch Accuracy = 51.5
# 	Batch  40, Loss = 1.6789 , Rolling Mean Loss = 1.6231 , Batch Accuracy = 48.25
# 	Batch  60, Loss = 1.5581 , Rolling Mean Loss = 1.6182 , Batch Accuracy = 50.0
# 	Batch  80, Loss = 1.7442 , Rolling Mean Loss = 1.6124 , Batch Accuracy = 49.0
# 	Batch 100, Loss = 1.7214 , Rolling Mean Loss = 1.6097 , Batch Accuracy = 45.75
# 	Batch 120, Loss = 1.7108 , Rolling Mean Loss = 1.6171 , Batch Accuracy = 48.75
# 	Batch 140, Loss = 1.6276 , Rolling Mean Loss = 1.6244 , Batch Accuracy = 43.25
# 	Batch 160, Loss = 1.5398 , Rolling Mean Loss = 1.6269 , Batch Accuracy = 51.5
# 	Batch 180, Loss = 1.7552 , Rolling Mean Loss = 1.635 , Batch Accuracy = 48.0
# 	Batch 200, Loss = 1.6055 , Rolling Mean Loss = 1.6305 , Batch Accuracy = 51.75
# ...
# 	Batch 140, Loss = 1.1395 , Rolling Mean Loss = 1.2728 , Batch Accuracy = 56.75
# 	Batch 160, Loss = 1.3601 , Rolling Mean Loss = 1.2676 , Batch Accuracy = 55.5
# 	Batch 180, Loss = 1.3739 , Rolling Mean Loss = 1.2666 , Batch Accuracy = 48.5
# 	Batch 200, Loss = 1.2118 , Rolling Mean Loss = 1.2681 , Batch Accuracy = 56.25
# 	Batch 220, Loss = 1.2197 , Rolling Mean Loss = 1.2757 , Batch Accuracy = 58.5
# 	Train Accuracy (mean) =  55.93
# 	Test Accuracy         =  36.1
# Epoch 85
# 	Batch   0, Loss = 1.1818 , Rolling Mean Loss = 1.284 , Batch Accuracy = 55.5
# 	Batch  20, Loss = 1.2259 , Rolling Mean Loss = 1.2791 , Batch Accuracy = 53.25
# 	Batch  40, Loss = 1.3358 , Rolling Mean Loss = 1.2791 , Batch Accuracy = 56.0
# 	Batch  60, Loss = 1.283 , Rolling Mean Loss = 1.278 , Batch Accuracy = 57.25
# 	Batch  80, Loss = 1.2353 , Rolling Mean Loss = 1.2715 , Batch Accuracy = 56.5
# 	Batch 100, Loss = 1.2624 , Rolling Mean Loss = 1.2617 , Batch Accuracy = 56.75
# 	Batch 120, Loss = 1.3158 , Rolling Mean Loss = 1.2682 , Batch Accuracy = 59.75
# 	Batch 140, Loss = 1.1872 , Rolling Mean Loss = 1.2698 , Batch Accuracy = 58.5
# 	Batch 160, Loss = 1.191 , Rolling Mean Loss = 1.2732 , Batch Accuracy = 56.75
# 	Batch 180, Loss = 1.2085 , Rolling Mean Loss = 1.2751 , Batch Accuracy = 58.25
# 	Batch 200, Loss = 1.2664 , Rolling Mean Loss = 1.2851 , Batch Accuracy = 55.0
# 	Batch 220, Loss = 1.3311 , Rolling Mean Loss = 1.2892 , Batch Accuracy = 55.5
# 	Train Accuracy (mean) =  56.05
# 	Test Accuracy         =  34.2
# Epoch 86
# 	Batch   0, Loss = 1.1814 , Rolling Mean Loss = 1.2891 , Batch Accuracy = 57.75
# 	Batch  20, Loss = 1.1557 , Rolling Mean Loss = 1.2806 , Batch Accuracy = 56.5
# 	Batch  40, Loss = 1.1724 , Rolling Mean Loss = 1.2741 , Batch Accuracy = 61.75
# 	Batch  60, Loss = 1.3261 , Rolling Mean Loss = 1.2695 , Batch Accuracy = 53.0
# 	Batch  80, Loss = 1.338 , Rolling Mean Loss = 1.2588 , Batch Accuracy = 53.75
# 	Batch 100, Loss = 1.3172 , Rolling Mean Loss = 1.2622 , Batch Accuracy = 59.25
# 	Batch 120, Loss = 1.1988 , Rolling Mean Loss = 1.2696 , Batch Accuracy = 59.25
# 	Batch 140, Loss = 1.2879 , Rolling Mean Loss = 1.2797 , Batch Accuracy = 55.25
# 	Batch 160, Loss = 1.4978 , Rolling Mean Loss = 1.2834 , Batch Accuracy = 52.25
# 	Batch 180, Loss = 1.2766 , Rolling Mean Loss = 1.2895 , Batch Accuracy = 52.0
# 	Batch 200, Loss = 1.4053 , Rolling Mean Loss = 1.2978 , Batch Accuracy = 52.5
# 	Batch 220, Loss = 1.2645 , Rolling Mean Loss = 1.3024 , Batch Accuracy = 55.75
# 	Train Accuracy (mean) =  55.93
# 	Test Accuracy         =  35.3
# Epoch 87
# 	Batch   0, Loss = 1.1431 , Rolling Mean Loss = 1.2981 , Batch Accuracy = 60.0
# 	Batch  20, Loss = 1.368 , Rolling Mean Loss = 1.2871 , Batch Accuracy = 55.75
# 	Batch  40, Loss = 1.1319 , Rolling Mean Loss = 1.2798 , Batch Accuracy = 61.25
# 	Batch  60, Loss = 1.2704 , Rolling Mean Loss = 1.2689 , Batch Accuracy = 55.75
# 	Batch  80, Loss = 1.1319 , Rolling Mean Loss = 1.2598 , Batch Accuracy = 56.0
# 	Batch 100, Loss = 1.33 , Rolling Mean Loss = 1.2544 , Batch Accuracy = 55.25
# 	Batch 120, Loss = 1.177 , Rolling Mean Loss = 1.2588 , Batch Accuracy = 57.75
# 	Batch 140, Loss = 1.3147 , Rolling Mean Loss = 1.2666 , Batch Accuracy = 53.5
# 	Batch 160, Loss = 1.3254 , Rolling Mean Loss = 1.272 , Batch Accuracy = 56.5
# 	Batch 180, Loss = 1.4424 , Rolling Mean Loss = 1.2708 , Batch Accuracy = 54.5
# 	Batch 200, Loss = 1.3624 , Rolling Mean Loss = 1.2732 , Batch Accuracy = 55.25
# 	Batch 220, Loss = 1.2608 , Rolling Mean Loss = 1.2807 , Batch Accuracy = 56.75
# 	Train Accuracy (mean) =  56.24
# 	Test Accuracy         =  36.5
# Epoch 88
# 	Batch   0, Loss = 1.1493 , Rolling Mean Loss = 1.2785 , Batch Accuracy = 55.5
# 	Batch  20, Loss = 1.4341 , Rolling Mean Loss = 1.2736 , Batch Accuracy = 54.25
# 	Batch  40, Loss = 1.1436 , Rolling Mean Loss = 1.2611 , Batch Accuracy = 56.0
# 	Batch  60, Loss = 1.1743 , Rolling Mean Loss = 1.2516 , Batch Accuracy = 58.75
# 	Batch  80, Loss = 1.3233 , Rolling Mean Loss = 1.2516 , Batch Accuracy = 57.5
# 	Batch 100, Loss = 1.2286 , Rolling Mean Loss = 1.2511 , Batch Accuracy = 55.5
# 	Batch 120, Loss = 1.3617 , Rolling Mean Loss = 1.254 , Batch Accuracy = 52.0
# 	Batch 140, Loss = 1.3246 , Rolling Mean Loss = 1.2728 , Batch Accuracy = 52.75
# 	Batch 160, Loss = 1.1687 , Rolling Mean Loss = 1.2827 , Batch Accuracy = 59.5
# 	Batch 180, Loss = 1.268 , Rolling Mean Loss = 1.2761 , Batch Accuracy = 57.5
# 	Batch 200, Loss = 1.2359 , Rolling Mean Loss = 1.2803 , Batch Accuracy = 55.25
# 	Batch 220, Loss = 1.3419 , Rolling Mean Loss = 1.2829 , Batch Accuracy = 56.75
# 	Train Accuracy (mean) =  56.4
# 	Test Accuracy         =  35.0
# Epoch 89
# 	Batch   0, Loss = 1.2436 , Rolling Mean Loss = 1.2834 , Batch Accuracy = 57.0
# 	Batch  20, Loss = 1.1302 , Rolling Mean Loss = 1.2724 , Batch Accuracy = 58.25
# 	Batch  40, Loss = 1.1631 , Rolling Mean Loss = 1.2608 , Batch Accuracy = 60.5
# 	Batch  60, Loss = 1.2623 , Rolling Mean Loss = 1.2464 , Batch Accuracy = 59.0
# 	Batch  80, Loss = 1.4011 , Rolling Mean Loss = 1.2419 , Batch Accuracy = 54.0
# 	Batch 100, Loss = 1.3573 , Rolling Mean Loss = 1.2309 , Batch Accuracy = 56.5
# 	Batch 120, Loss = 1.4691 , Rolling Mean Loss = 1.2371 , Batch Accuracy = 54.75
# 	Batch 140, Loss = 1.4175 , Rolling Mean Loss = 1.2461 , Batch Accuracy = 51.25
# 	Batch 160, Loss = 1.3359 , Rolling Mean Loss = 1.2572 , Batch Accuracy = 55.0
# 	Batch 180, Loss = 1.3267 , Rolling Mean Loss = 1.266 , Batch Accuracy = 54.5
# 	Batch 200, Loss = 1.3144 , Rolling Mean Loss = 1.2748 , Batch Accuracy = 54.25
# 	Batch 220, Loss = 1.1375 , Rolling Mean Loss = 1.2826 , Batch Accuracy = 56.5
# 	Train Accuracy (mean) =  56.54
# 	Test Accuracy         =  35.7
# Epoch 90
# 	Batch   0, Loss = 1.1298 , Rolling Mean Loss = 1.2864 , Batch Accuracy = 58.75
# 	Batch  20, Loss = 1.1912 , Rolling Mean Loss = 1.2696 , Batch Accuracy = 56.25
# 	Batch  40, Loss = 1.1993 , Rolling Mean Loss = 1.2567 , Batch Accuracy = 55.0
# 	Batch  60, Loss = 1.1843 , Rolling Mean Loss = 1.2529 , Batch Accuracy = 55.5
# 	Batch  80, Loss = 1.1519 , Rolling Mean Loss = 1.2487 , Batch Accuracy = 59.75
# 	Batch 100, Loss = 1.3285 , Rolling Mean Loss = 1.2417 , Batch Accuracy = 55.75
# 	Batch 120, Loss = 1.2019 , Rolling Mean Loss = 1.2539 , Batch Accuracy = 56.0
# 	Batch 140, Loss = 1.2928 , Rolling Mean Loss = 1.2591 , Batch Accuracy = 57.25
# 	Batch 160, Loss = 1.3075 , Rolling Mean Loss = 1.2621 , Batch Accuracy = 55.0
# 	Batch 180, Loss = 1.2775 , Rolling Mean Loss = 1.2605 , Batch Accuracy = 56.5
# 	Batch 200, Loss = 1.1224 , Rolling Mean Loss = 1.2565 , Batch Accuracy = 59.0
# 	Batch 220, Loss = 1.2101 , Rolling Mean Loss = 1.2594 , Batch Accuracy = 59.75
# 	Train Accuracy (mean) =  56.61
# 	Test Accuracy         =  34.9
# Epoch 91
# 	Batch   0, Loss = 1.0915 , Rolling Mean Loss = 1.256 , Batch Accuracy = 60.0
# 	Batch  20, Loss = 1.1797 , Rolling Mean Loss = 1.2406 , Batch Accuracy = 56.75
# 	Batch  40, Loss = 1.1684 , Rolling Mean Loss = 1.2289 , Batch Accuracy = 57.25
# 	Batch  60, Loss = 1.1718 , Rolling Mean Loss = 1.226 , Batch Accuracy = 59.0
# 	Batch  80, Loss = 1.2677 , Rolling Mean Loss = 1.2264 , Batch Accuracy = 54.25
# 	Batch 100, Loss = 1.2635 , Rolling Mean Loss = 1.2157 , Batch Accuracy = 56.5
# 	Batch 120, Loss = 1.2539 , Rolling Mean Loss = 1.2352 , Batch Accuracy = 56.5
# 	Batch 140, Loss = 1.1963 , Rolling Mean Loss = 1.2389 , Batch Accuracy = 56.25
# 	Batch 160, Loss = 1.2885 , Rolling Mean Loss = 1.2381 , Batch Accuracy = 56.5
# 	Batch 180, Loss = 1.4128 , Rolling Mean Loss = 1.2461 , Batch Accuracy = 52.25
# 	Batch 200, Loss = 1.2772 , Rolling Mean Loss = 1.2601 , Batch Accuracy = 59.25
# 	Batch 220, Loss = 1.3318 , Rolling Mean Loss = 1.2625 , Batch Accuracy = 51.0
# 	Train Accuracy (mean) =  56.8
# 	Test Accuracy         =  34.5
# Epoch 92
# 	Batch   0, Loss = 1.2448 , Rolling Mean Loss = 1.2709 , Batch Accuracy = 56.75
# 	Batch  20, Loss = 1.2638 , Rolling Mean Loss = 1.2725 , Batch Accuracy = 56.5
# 	Batch  40, Loss = 1.285 , Rolling Mean Loss = 1.2605 , Batch Accuracy = 55.5
# 	Batch  60, Loss = 1.2767 , Rolling Mean Loss = 1.2458 , Batch Accuracy = 58.25
# 	Batch  80, Loss = 1.1202 , Rolling Mean Loss = 1.2382 , Batch Accuracy = 58.5
# 	Batch 100, Loss = 1.2401 , Rolling Mean Loss = 1.2188 , Batch Accuracy = 56.0
# 	Batch 120, Loss = 1.2075 , Rolling Mean Loss = 1.2215 , Batch Accuracy = 57.0
# 	Batch 140, Loss = 1.2943 , Rolling Mean Loss = 1.2389 , Batch Accuracy = 57.75
# 	Batch 160, Loss = 1.1749 , Rolling Mean Loss = 1.239 , Batch Accuracy = 60.0
# 	Batch 180, Loss = 1.3259 , Rolling Mean Loss = 1.2415 , Batch Accuracy = 57.0
# 	Batch 200, Loss = 1.3845 , Rolling Mean Loss = 1.2607 , Batch Accuracy = 52.75
# 	Batch 220, Loss = 1.2517 , Rolling Mean Loss = 1.255 , Batch Accuracy = 57.0
# 	Train Accuracy (mean) =  56.92
# 	Test Accuracy         =  34.5
# Epoch 93
# 	Batch   0, Loss = 1.1458 , Rolling Mean Loss = 1.2557 , Batch Accuracy = 58.75
# 	Batch  20, Loss = 1.1977 , Rolling Mean Loss = 1.2415 , Batch Accuracy = 56.75
# 	Batch  40, Loss = 1.1077 , Rolling Mean Loss = 1.2402 , Batch Accuracy = 59.25
# 	Batch  60, Loss = 1.0834 , Rolling Mean Loss = 1.2374 , Batch Accuracy = 59.75
# 	Batch  80, Loss = 1.1701 , Rolling Mean Loss = 1.2308 , Batch Accuracy = 57.25
# 	Batch 100, Loss = 1.2175 , Rolling Mean Loss = 1.2306 , Batch Accuracy = 56.5
# 	Batch 120, Loss = 1.3981 , Rolling Mean Loss = 1.2414 , Batch Accuracy = 54.75
# 	Batch 140, Loss = 1.2818 , Rolling Mean Loss = 1.2451 , Batch Accuracy = 56.5
# 	Batch 160, Loss = 1.3152 , Rolling Mean Loss = 1.2472 , Batch Accuracy = 54.0
# 	Batch 180, Loss = 1.3628 , Rolling Mean Loss = 1.2523 , Batch Accuracy = 56.75
# 	Batch 200, Loss = 1.2726 , Rolling Mean Loss = 1.2584 , Batch Accuracy = 56.75
# 	Batch 220, Loss = 1.4801 , Rolling Mean Loss = 1.2576 , Batch Accuracy = 53.0
# 	Train Accuracy (mean) =  56.74
# 	Test Accuracy         =  34.9
# Epoch 94
# 	Batch   0, Loss = 1.1215 , Rolling Mean Loss = 1.2616 , Batch Accuracy = 62.75
# 	Batch  20, Loss = 1.2882 , Rolling Mean Loss = 1.241 , Batch Accuracy = 58.5
# 	Batch  40, Loss = 1.1708 , Rolling Mean Loss = 1.2412 , Batch Accuracy = 56.75
# 	Batch  60, Loss = 1.2137 , Rolling Mean Loss = 1.2217 , Batch Accuracy = 59.0
# 	Batch  80, Loss = 1.1864 , Rolling Mean Loss = 1.2173 , Batch Accuracy = 54.0
# 	Batch 100, Loss = 1.3161 , Rolling Mean Loss = 1.219 , Batch Accuracy = 57.0
# 	Batch 120, Loss = 1.1907 , Rolling Mean Loss = 1.2292 , Batch Accuracy = 55.75
# 	Batch 140, Loss = 1.2147 , Rolling Mean Loss = 1.233 , Batch Accuracy = 58.5
# 	Batch 160, Loss = 1.2377 , Rolling Mean Loss = 1.241 , Batch Accuracy = 57.75
# 	Batch 180, Loss = 1.1717 , Rolling Mean Loss = 1.2369 , Batch Accuracy = 62.5
# 	Batch 200, Loss = 1.0282 , Rolling Mean Loss = 1.2351 , Batch Accuracy = 58.5
# 	Batch 220, Loss = 1.2312 , Rolling Mean Loss = 1.238 , Batch Accuracy = 55.5
# 	Train Accuracy (mean) =  57.07
# 	Test Accuracy         =  36.2
# Epoch 95
# 	Batch   0, Loss = 1.2237 , Rolling Mean Loss = 1.2374 , Batch Accuracy = 55.75
# 	Batch  20, Loss = 1.2366 , Rolling Mean Loss = 1.2307 , Batch Accuracy = 58.5
# 	Batch  40, Loss = 1.2392 , Rolling Mean Loss = 1.2276 , Batch Accuracy = 56.5
# 	Batch  60, Loss = 1.2513 , Rolling Mean Loss = 1.2284 , Batch Accuracy = 57.5
# 	Batch  80, Loss = 1.3351 , Rolling Mean Loss = 1.2242 , Batch Accuracy = 53.75
# 	Batch 100, Loss = 1.1554 , Rolling Mean Loss = 1.2205 , Batch Accuracy = 55.0
# 	Batch 120, Loss = 1.1642 , Rolling Mean Loss = 1.2121 , Batch Accuracy = 60.5
# 	Batch 140, Loss = 1.4443 , Rolling Mean Loss = 1.2224 , Batch Accuracy = 53.25
# 	Batch 160, Loss = 1.2892 , Rolling Mean Loss = 1.213 , Batch Accuracy = 54.5
# 	Batch 180, Loss = 1.3927 , Rolling Mean Loss = 1.2145 , Batch Accuracy = 54.0
# 	Batch 200, Loss = 1.4151 , Rolling Mean Loss = 1.2291 , Batch Accuracy = 55.75
# 	Batch 220, Loss = 1.2846 , Rolling Mean Loss = 1.2466 , Batch Accuracy = 54.5
# 	Train Accuracy (mean) =  57.15
# 	Test Accuracy         =  35.0
# Epoch 96
# 	Batch   0, Loss = 1.1293 , Rolling Mean Loss = 1.2469 , Batch Accuracy = 57.5
# 	Batch  20, Loss = 1.1578 , Rolling Mean Loss = 1.2359 , Batch Accuracy = 60.0
# 	Batch  40, Loss = 1.0822 , Rolling Mean Loss = 1.2259 , Batch Accuracy = 60.25
# 	Batch  60, Loss = 1.0231 , Rolling Mean Loss = 1.2187 , Batch Accuracy = 62.0
# 	Batch  80, Loss = 1.2421 , Rolling Mean Loss = 1.2105 , Batch Accuracy = 58.75
# 	Batch 100, Loss = 1.1956 , Rolling Mean Loss = 1.2086 , Batch Accuracy = 57.5
# 	Batch 120, Loss = 1.382 , Rolling Mean Loss = 1.2227 , Batch Accuracy = 52.5
# 	Batch 140, Loss = 1.2025 , Rolling Mean Loss = 1.2343 , Batch Accuracy = 59.0
# 	Batch 160, Loss = 1.3319 , Rolling Mean Loss = 1.2328 , Batch Accuracy = 56.75
# 	Batch 180, Loss = 1.074 , Rolling Mean Loss = 1.2366 , Batch Accuracy = 58.25
# 	Batch 200, Loss = 1.1941 , Rolling Mean Loss = 1.2452 , Batch Accuracy = 57.25
# 	Batch 220, Loss = 1.2921 , Rolling Mean Loss = 1.2431 , Batch Accuracy = 54.5
# 	Train Accuracy (mean) =  57.09
# 	Test Accuracy         =  36.5
# Epoch 97
# 	Batch   0, Loss = 1.1101 , Rolling Mean Loss = 1.2396 , Batch Accuracy = 59.75
# 	Batch  20, Loss = 1.1373 , Rolling Mean Loss = 1.2377 , Batch Accuracy = 58.5
# 	Batch  40, Loss = 1.1774 , Rolling Mean Loss = 1.2295 , Batch Accuracy = 61.0
# 	Batch  60, Loss = 1.3574 , Rolling Mean Loss = 1.2219 , Batch Accuracy = 52.5
# 	Batch  80, Loss = 1.1979 , Rolling Mean Loss = 1.2207 , Batch Accuracy = 56.0
# 	Batch 100, Loss = 1.196 , Rolling Mean Loss = 1.2188 , Batch Accuracy = 57.0
# 	Batch 120, Loss = 1.2432 , Rolling Mean Loss = 1.2207 , Batch Accuracy = 57.25
# 	Batch 140, Loss = 1.1876 , Rolling Mean Loss = 1.2186 , Batch Accuracy = 60.25
# 	Batch 160, Loss = 1.2146 , Rolling Mean Loss = 1.218 , Batch Accuracy = 56.0
# 	Batch 180, Loss = 0.9899 , Rolling Mean Loss = 1.2078 , Batch Accuracy = 62.75
# 	Batch 200, Loss = 1.1814 , Rolling Mean Loss = 1.2089 , Batch Accuracy = 56.0
# 	Batch 220, Loss = 1.3263 , Rolling Mean Loss = 1.2143 , Batch Accuracy = 57.5
# 	Train Accuracy (mean) =  57.27
# 	Test Accuracy         =  35.1
# Epoch 98
# 	Batch   0, Loss = 1.0339 , Rolling Mean Loss = 1.2153 , Batch Accuracy = 61.25
# 	Batch  20, Loss = 1.0516 , Rolling Mean Loss = 1.21 , Batch Accuracy = 60.75
# 	Batch  40, Loss = 1.202 , Rolling Mean Loss = 1.1958 , Batch Accuracy = 55.25
# 	Batch  60, Loss = 1.2649 , Rolling Mean Loss = 1.1995 , Batch Accuracy = 57.75
# 	Batch  80, Loss = 1.2437 , Rolling Mean Loss = 1.1933 , Batch Accuracy = 58.5
# 	Batch 100, Loss = 1.2171 , Rolling Mean Loss = 1.1928 , Batch Accuracy = 55.75
# 	Batch 120, Loss = 1.1188 , Rolling Mean Loss = 1.2004 , Batch Accuracy = 62.5
# 	Batch 140, Loss = 1.2025 , Rolling Mean Loss = 1.2056 , Batch Accuracy = 57.5
# 	Batch 160, Loss = 1.1035 , Rolling Mean Loss = 1.21 , Batch Accuracy = 59.75
# 	Batch 180, Loss = 1.231 , Rolling Mean Loss = 1.2195 , Batch Accuracy = 61.0
# 	Batch 200, Loss = 1.1743 , Rolling Mean Loss = 1.2227 , Batch Accuracy = 59.75
# 	Batch 220, Loss = 1.2064 , Rolling Mean Loss = 1.2328 , Batch Accuracy = 58.75
# 	Train Accuracy (mean) =  57.48
# 	Test Accuracy         =  34.9
# Epoch 99
# 	Batch   0, Loss = 1.0922 , Rolling Mean Loss = 1.2347 , Batch Accuracy = 58.0
# 	Batch  20, Loss = 1.3776 , Rolling Mean Loss = 1.2255 , Batch Accuracy = 55.0
# 	Batch  40, Loss = 1.2607 , Rolling Mean Loss = 1.2153 , Batch Accuracy = 58.5
# 	Batch  60, Loss = 1.3158 , Rolling Mean Loss = 1.2088 , Batch Accuracy = 54.75
# 	Batch  80, Loss = 1.375 , Rolling Mean Loss = 1.2059 , Batch Accuracy = 51.75
# 	Batch 100, Loss = 1.1709 , Rolling Mean Loss = 1.1998 , Batch Accuracy = 53.75
# 	Batch 120, Loss = 1.1891 , Rolling Mean Loss = 1.2097 , Batch Accuracy = 56.75
# 	Batch 140, Loss = 1.253 , Rolling Mean Loss = 1.2183 , Batch Accuracy = 57.0
# 	Batch 160, Loss = 1.1889 , Rolling Mean Loss = 1.2192 , Batch Accuracy = 58.5
# 	Batch 180, Loss = 1.2478 , Rolling Mean Loss = 1.2265 , Batch Accuracy = 55.25
# 	Batch 200, Loss = 1.1714 , Rolling Mean Loss = 1.2308 , Batch Accuracy = 58.0
# 	Batch 220, Loss = 1.1361 , Rolling Mean Loss = 1.2327 , Batch Accuracy = 62.0
# 	Train Accuracy (mean) =  57.28
# 	Test Accuracy         =  35.1
#
# Final Loss = 1.0371
# Final Rolling Loss = 1.2427
#
# Final Test Accuracy  = 35.10%
# Final Train Accuracy = 61.87%
#
# Running Time = 39 min, 36 sec.

# %%
import pandas as pd

df = pd.DataFrame(L)
Lmean = df.rolling(100).mean().values

plt.figure(figsize=(15,7.5))
plt.title('Model Loss During Training')
plt.scatter(range(len(L)),L,5,alpha=.5,color='C1',label='Loss')
plt.scatter(range(len(Lmean)),Lmean,1,color='C0',label='Loss (100 Iteration Rolling Mean)')
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.ylim([0,5])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7.5))
plt.title('Model Accuracy During Training')
plt.plot([tmea*100 for tmea in train_mean_epoch_accuracy],label='Train Mean Epoch Accuracy')
plt.plot([tea*100 for tea in test_epoch_accuracy],label='Test Epoch Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
import pickle

LA = test_epoch_loss

file_name = 'Original_ResNet'
variables_list = [L,LA,
                  train_mean_epoch_accuracy,test_epoch_accuracy,
                  final_train_accuracy,final_test_accuracy,
                  word2idx]

with open('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/' + file_name + '.pkl','wb') as file:
  pickle.dump(variables_list,file)
