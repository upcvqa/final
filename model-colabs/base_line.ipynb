# %% [markdown]
# # VQA Model
#
# ![image.png](data:image/png;base64,...)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from skimage import io
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import json
import pprint
import numpy as np
import time
from datetime import timedelta

# %% [markdown]
# Mounting shared Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

import sys
sys.path.append('/content/drive/My Drive/aidl/lib')
# Out:
# Mounted at /content/drive

# %%
! ls -1 '/content/drive/My Drive/aidl/coco/'*.jpg | wc -l
# Out:
# 18152

# %% [markdown]
# Global Parameters

# %%
batch_size = 30
num_epochs = 20
learning_rate = 0.001
#dataset_root = "/content/model1000_any"
#dataset_root = "/content/drive/My Drive/aidl"
#dataset_root = "/content/drive/My Drive/aidl/Dataset100"
#dataset_root = "/content/drive/My Drive/aidl/model5000_1_20"
#dataset_root = "/content/drive/My Drive/aidl/model10000_1_20"
#dataset_root = "/content/drive/My Drive/aidl/model1000_any"
#dataset_root = "/content/drive/My Drive/aidl/model10000_yes_no"
dataset_root = "/content"

# !ls -lh '$dataset_root'
device = torch.device('cuda')
# Out:
# total 6.3G
# drwxr-xr-x 2 root root 2.3M Nov 12 19:09 coco
# drwx------ 5 root root 4.0K Nov 12 18:55 drive
# -rw------- 1 root root  16M Nov 12 18:57 mscoco_a.json
# -rw------- 1 root root 342K Nov 12 18:57 mscoco_i2.txt
# -rw------- 1 root root 5.4M Nov 12 18:57 mscoco_q.json
# -rw------- 1 root root  20K Nov 12 18:57 mscoco_qtest_full.txt
# -rw------- 1 root root 1.9K Nov 12 18:57 mscoco_qtest.txt
# -rw------- 1 root root  58K Nov 12 18:57 mscoco_qtrain.txt
# drwxr-xr-x 1 root root 4.0K Nov  6 17:30 sample_data
# -rw-r--r-- 1 root root 6.2G Jul 11  2018 val2014.zip

# %%
#!mkdir "model1000_any"
#!cp -r "/content/drive/My Drive/aidl/model1000_any" "model1000_any"
#!cp "/content/drive/My Drive/aidl/coco"/*.jpg /content/model1000_any/coco
#!cp '/content/drive/My Drive/aidl/model10000_yes_no'/*.txt .
#!cp '/content/drive/My Drive/aidl/model10000_yes_no'/*.json .
#!mkdir coco
# !wget 'http://images.cocodataset.org/zips/val2014.zip'
# !unzip -qj val2014.zip -d coco
# Out:
# --2020-11-12 19:03:33--  http://images.cocodataset.org/zips/val2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.16.84
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.16.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6645013297 (6.2G) [application/zip]
# Saving to: ‘val2014.zip’
#
# val2014.zip         100%[===================>]   6.19G  42.0MB/s    in 3m 9s
#
# 2020-11-12 19:06:43 (33.6 MB/s) - ‘val2014.zip’ saved [6645013297/6645013297]

# %% [markdown]
# Custom Data Loader

# %%
"""
     Data structure:

     root_dir
        |_ mscoco_qtrain.txt [list of question IDs for training]
        |_ mscoco_qtest.txt  [list of question IDs for testing]
        |_ mscoco_q.json     [json of questions]
        |_ mscoco_a.json     [json of annotations]
        |_ coco              [subdirectory for images]
            |_ image 1
            |_ image 2
              ...
            |_ image n

"""

class TestDataset(Dataset):
#
#   _ _ i n i t _ _
#
    def __init__(self, root_dir, train=False, transform=None):
        """
        Args:
            root_dir (string): root directory for the data           
            train (bool, optional): choose training or testing datasets
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """

        super().__init__()

        # Define some constants to access files
        self.image_prefix = "COCO_val2014_"
        self.image_postfix = ".jpg"
        self.image_subdir = 'coco'
        self.questions_list_train_fname = 'mscoco_qtrain.txt'
        self.questions_list_test_fname = 'mscoco_qtest.txt'
        self.questions_fname = 'mscoco_q.json'
        self.annotations_fname = 'mscoco_a.json'

        # Store parameters as class attributes
        self.root_dir = root_dir
        self.train = train
        self.transform = transform

        # Load questions json file
        fqfname = os.path.join(self.root_dir, self.questions_fname)
        self.questions = json.load(open(fqfname, 'r'))

        # Load annotations json file
        fqfname = os.path.join(self.root_dir, self.annotations_fname)
        self.annotations = json.load(open(fqfname, 'r'))

        # Compute list of unique answers (train + test)
        fqfname = os.path.join(self.root_dir, self.questions_list_train_fname)
        with open(fqfname) as f:
          tmp = f.read().splitlines()
        ql_train = list(map(int, tmp))

        fqfname = os.path.join(self.root_dir, self.questions_list_test_fname)
        with open(fqfname) as f:
          tmp = f.read().splitlines()
        ql_test = list(map(int, tmp))

        ql_global = set(ql_train + ql_test)

        self.annotation_map = {}
        self.annotation_classdist = {}
        annotation_id = 0
        for a in self.annotations:
            if a['question_id'] in ql_global:
                if not(a['multiple_choice_answer'] in self.annotation_map):
                    self.annotation_map[a['multiple_choice_answer']] = annotation_id
                    annotation_id += 1
                self.annotation_classdist.update({a['multiple_choice_answer'] : self.annotation_classdist.get(a['multiple_choice_answer'],0) + 1})

        #print (self.annotation_map)
        #print (self.annotation_classdist)

        print("Dataset: training {} / testing {}".format(len(ql_train), len(ql_test)))

        # Depending on self.train, assign either training question list or
        #   testing question list
        if (self.train):
            self.questions_list = ql_train
        else:
            self.questions_list = ql_test
#
#   _ _ l e n _ _
#
    def __len__(self):
        return len(self.questions_list)
#
#   _ _ g e t i t e m _ _
#
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        # Get question_id from the list
        question_id = self.questions_list[idx]

        # Find corresponding question and annotation
        #   (use next() to get a single value from the list comprehension)
        question = next(x for x in self.questions if x['question_id'] == question_id)
        annotation = next(a for a in self.annotations if a['question_id'] == question_id)

        image_id = question['image_id']
        file_name = self.image_prefix+("0"*12+str(image_id))[-12:]+self.image_postfix
        fqfname = os.path.join(self.root_dir,self.image_subdir,file_name)
        image = Image.open(fqfname)
 
        # Fix B&W images
        if image.mode != 'RGB':
            image = image.convert('RGB')

        # Apply transformation if there is any
        if self.transform:
            image = self.transform(image)

        # Translate annotation to its ID
        annotation_ID = self.annotation_map[annotation['multiple_choice_answer']]

        # return tuple: image, question text, answer text
        return image, question['question'], annotation_ID

# %% [markdown]
# Image Embeddings (pretrained VGG-16)

# %%
from torchvision import models, transforms

model = models.vgg16(pretrained=True)
model.to(device)
model.eval()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
import torch.nn as nn
class ImageEmbedding(nn.Module):

    def __init__(self, base_model):
        super().__init__()
        self.features = base_model.features
        self.avgpool = base_model.avgpool
        self.classifier = base_model.classifier

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        for i, layer in enumerate(self.classifier):
            x = layer(x)
            if i == 3:
                break
        return x

# %% [markdown]
# Text Embeddings (Google Universal Sentence Encoder)

# %%
from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import pandas as pd
import re

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"

sentence_embedding_generator = hub.load(module_url)
print ("module %s loaded" % module_url)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %% [markdown]
# VQA Model

# %%
import torch.nn.functional as F
"""
class VQAm1(nn.Module):
    def __init__(self, D_in, H, D_out):
        super().__init__()
        self.linear1 = torch.nn.Linear(D_in, H)
        self.batchnorm1 = nn.BatchNorm1d(num_features=H)
        self.dropout1 = torch.nn.Dropout(p=0.5)
        self.linear2 = torch.nn.Linear(H, H)
        self.batchnorm2 = nn.BatchNorm1d(num_features=H)
        self.dropout2 = torch.nn.Dropout(p=0.5)
        self.linear3 = torch.nn.Linear(H, D_out)
#        self.classifier = torch.nn.LogSoftmax(dim=1)

    def forward(self, x):
        h_relu =  F.relu(self.linear1(x))
        h_relu = self.batchnorm1(h_relu)
        h_relu = self.dropout1(h_relu)
        h_relu =  F.relu(self.linear2(h_relu))
        h_relu = self.batchnorm2(h_relu)
        h_relu = self.dropout2(h_relu)
        y_pred = self.linear3(h_relu)
#        r = self.classifier(y_pred)
        return y_pred #r
"""
class VQAm1(nn.Module):
    def __init__(self, D_in, H, D_out):
        super().__init__()
        self.linear1 = torch.nn.Linear(D_in, 2*H)
        self.batchnorm1 = nn.BatchNorm1d(num_features=2*H,track_running_stats=False)
        self.dropout1 = torch.nn.Dropout(p=0.5)
        self.linear2 = torch.nn.Linear(2*H, H)
        self.batchnorm2 = nn.BatchNorm1d(num_features=H,track_running_stats=False)
        self.dropout2 = torch.nn.Dropout(p=0.5)
        self.linear3 = torch.nn.Linear(H, D_out)

    def forward(self, x):
        h_relu =  F.relu(self.linear1(x))
        h_relu = self.batchnorm1(h_relu)
        h_relu = self.dropout1(h_relu)
        h_relu =  F.relu(self.linear2(h_relu))
        h_relu = self.batchnorm2(h_relu)
        h_relu = self.dropout2(h_relu)
        y_pred = self.linear3(h_relu)

        return y_pred

# %% [markdown]
# Training VQA Model

# %%
# Execute an evaluation using test data

def evaluation(model,loader):
    correct = 0
    total = 0
    model.eval()
    with torch.no_grad():
        for batch, (image, question, annotation) in enumerate(loader):
    #        print("-->", annotation)
            annotation = annotation.to(device)
            image = image.to(device)
            image_embedding = image_embedding_extractor.forward(image)
            image_embedding = F.normalize(image_embedding)
    #   image_embedding.shape) = torch.Size([batch_size, 4096])
            question_embedding = sentence_embedding_generator(question).numpy()
            question_embedding = t(question_embedding)
            question_embedding = question_embedding.squeeze_(0).to(device)
    #   question_embedding.shape = torch.Size([batch_size, 512])
            combined_embedding = torch.cat((image_embedding,question_embedding),dim=1)
    #   combined_embedding.shape) = torch.Size([batch_size, 4608])
            combined_embedding = combined_embedding.to(device)

            y_pred = model(combined_embedding)
            _, results = torch.max(y_pred, 1)

            loss = criterion(y_pred, annotation)

            correct += (results == annotation).sum().item()
            total += annotation.size(0)
#           print("Correct {}/{}".format((results == annotation).sum().item(),annotation.size(0)))


    return 100 * correct / total, loss

# %%
img_size = 512

transform = transforms.Compose([
                                transforms.Resize(img_size),
                                transforms.CenterCrop(img_size),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                     std=[0.229, 0.224, 0.225])
                            ])

# Create Dataset & Dataloader
ds = TestDataset(dataset_root,train=True,transform=transform)
dl = DataLoader(ds,batch_size=batch_size,shuffle=True,num_workers=4)

test_dataset = TestDataset(dataset_root,train=False,transform=transform)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=4)

# Instantiate VQAmodel
VQAmodel = VQAm1(4608,128,len(ds.annotation_map))
VQAmodel.to(device)

image_embedding_extractor = ImageEmbedding(model)
for p in image_embedding_extractor.parameters():
    p.requires_grad = False
t = transforms.ToTensor()

#w = torch.tensor([sum(ds.annotation_classdist.values())/v for v in ds.annotation_classdist.values()])
#w.true_divide_(sum(w))
#w = w.to(device)

#criterion = torch.nn.CrossEntropyLoss(weight=w)
criterion = torch.nn.CrossEntropyLoss()
#optimizer = torch.optim.SGD(VQAmodel.parameters(), lr=1e-4)
optimizer = torch.optim.AdamW(VQAmodel.parameters(),lr=learning_rate)

iteration = 1
iters = []
losses = []
accur = []
epoch_e_accur = []
epoch_e_loss = []
start_time = time.time()
for epoch in range(num_epochs):
    VQAmodel.train()
    epoch_accur = []
    epoch_loss = []
    epoch_start_time = time.time()
    for batch, (image, question, annotation) in enumerate(dl):
        batch_start_time = time.time()
#        print("-->", annotation)
#        annotation = torch.tensor([int(i)-1 for i in annotation]).to(device)
        annotation = annotation.to(device)
        image = image.to(device)
        image_embedding = image_embedding_extractor.forward(image)
        image_embedding = F.normalize(image_embedding)
#   image_embedding.shape) = torch.Size([batch_size, 4096])
        question_embedding = sentence_embedding_generator(question).numpy()
        question_embedding = t(question_embedding)
        question_embedding = question_embedding.squeeze_(0).to(device)
#   question_embedding.shape = torch.Size([batch_size, 512])
        combined_embedding = torch.cat((image_embedding,question_embedding),dim=1)
#   combined_embedding.shape = torch.Size([batch_size, 4608])
        combined_embedding = combined_embedding.to(device)

        y_pred = VQAmodel.forward(combined_embedding)

        loss = criterion(y_pred, annotation)
        
#   Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #information on progress
        _, results = torch.max(y_pred, 1)
        accuracy = 100*sum(results == annotation).true_divide(len(annotation))

        iters.append(iteration)
        #losses.append(float(loss)/annotation.size(0))
        epoch_accur.append(accuracy)
        epoch_loss.append(float(loss))
        if (iteration % 10 == 0):
            print ("Epoch {:3d} Batch {:3d} Loss: {:6.4f} {:3.1f}% ({:3d})".format(epoch,batch,float(loss),sum(epoch_accur)/len(epoch_accur), annotation.size(0)))

        iteration += 1

    accur.append(sum(epoch_accur)/len(epoch_accur))
    losses.append(sum(epoch_loss)/len(epoch_loss))
    e_acc, e_loss = evaluation(VQAmodel,test_loader)
    epoch_e_accur.append(e_acc)
    epoch_e_loss.append(e_loss)
    epoch_end_time = time.time()
    #if (iteration % batch_size == 0):
    print ("Epoch {:3d} Evaluation acc :{:3.1f}% Duration: {}".format(epoch,e_acc,
                                                                   str(timedelta(seconds=int(epoch_end_time - epoch_start_time)))))

end_time = time.time()

print ("Total elapsed time : {}".format(str(timedelta(seconds=end_time - start_time))))
print("{} samples in {:,.0f} seconds : {:4.1f} samples/sec".format(len(ds)*num_epochs,end_time-start_time,len(ds)*num_epochs/(end_time-start_time)))
# Out:
# Dataset: training 7500 / testing 250
# Dataset: training 7500 / testing 250
# Epoch   0 Batch   9 Loss: 1.0112 53.7% ( 30)
# Epoch   0 Batch  19 Loss: 0.7681 53.8% ( 30)
# Epoch   0 Batch  29 Loss: 0.7484 53.3% ( 30)
# Epoch   0 Batch  39 Loss: 0.7091 53.5% ( 30)
# Epoch   0 Batch  49 Loss: 0.7870 54.5% ( 30)
# Epoch   0 Batch  59 Loss: 0.6967 54.8% ( 30)
# Epoch   0 Batch  69 Loss: 0.8634 54.5% ( 30)
# Epoch   0 Batch  79 Loss: 0.7484 54.5% ( 30)
# Epoch   0 Batch  89 Loss: 0.8894 54.2% ( 30)
# Epoch   0 Batch  99 Loss: 0.7496 54.5% ( 30)
# Epoch   0 Batch 109 Loss: 0.8034 54.2% ( 30)
# Epoch   0 Batch 119 Loss: 0.7577 54.3% ( 30)
# Epoch   0 Batch 129 Loss: 0.6589 54.5% ( 30)
# Epoch   0 Batch 139 Loss: 0.7380 54.5% ( 30)
# Epoch   0 Batch 149 Loss: 0.6330 54.6% ( 30)
# Epoch   0 Batch 159 Loss: 0.6978 54.7% ( 30)
# Epoch   0 Batch 169 Loss: 0.7850 54.8% ( 30)
# Epoch   0 Batch 179 Loss: 0.8048 54.7% ( 30)
# Epoch   0 Batch 189 Loss: 0.6904 54.8% ( 30)
# Epoch   0 Batch 199 Loss: 0.6355 54.8% ( 30)
# Epoch   0 Batch 209 Loss: 0.6933 54.8% ( 30)
# Epoch   0 Batch 219 Loss: 0.6048 55.1% ( 30)
# Epoch   0 Batch 229 Loss: 0.7007 55.3% ( 30)
# Epoch   0 Batch 239 Loss: 0.6273 55.4% ( 30)
# Epoch   0 Batch 249 Loss: 0.6790 55.5% ( 30)
# Epoch   0 Evaluation acc :64.4% Duration: 0:03:23
# Epoch   1 Batch   9 Loss: 0.5873 59.0% ( 30)
# Epoch   1 Batch  19 Loss: 0.6499 57.2% ( 30)
# Epoch   1 Batch  29 Loss: 0.7313 56.8% ( 30)
# Epoch   1 Batch  39 Loss: 0.6404 57.6% ( 30)
# Epoch   1 Batch  49 Loss: 0.6878 57.5% ( 30)
# Epoch   1 Batch  59 Loss: 0.7314 57.3% ( 30)
# Epoch   1 Batch  69 Loss: 0.6930 57.9% ( 30)
# Epoch   1 Batch  79 Loss: 0.7062 58.5% ( 30)
# Epoch   1 Batch  89 Loss: 0.6461 58.9% ( 30)
# Epoch   1 Batch  99 Loss: 0.5999 59.0% ( 30)
# Epoch   1 Batch 109 Loss: 0.6741 59.3% ( 30)
# Epoch   1 Batch 119 Loss: 0.6474 59.6% ( 30)
# Epoch   1 Batch 129 Loss: 0.6612 59.4% ( 30)
# Epoch   1 Batch 139 Loss: 0.6835 59.1% ( 30)
# Epoch   1 Batch 149 Loss: 0.6938 59.1% ( 30)
# Epoch   1 Batch 159 Loss: 0.6873 59.1% ( 30)
# Epoch   1 Batch 169 Loss: 0.6521 59.4% ( 30)
# Epoch   1 Batch 179 Loss: 0.5836 59.4% ( 30)
# Epoch   1 Batch 189 Loss: 0.6936 59.7% ( 30)
# Epoch   1 Batch 199 Loss: 0.6941 59.4% ( 30)
# Epoch   1 Batch 209 Loss: 0.8055 59.5% ( 30)
# Epoch   1 Batch 219 Loss: 0.6631 59.5% ( 30)
# Epoch   1 Batch 229 Loss: 0.5939 59.7% ( 30)
# Epoch   1 Batch 239 Loss: 0.6765 59.7% ( 30)
# Epoch   1 Batch 249 Loss: 0.6006 59.9% ( 30)
# Epoch   1 Evaluation acc :62.0% Duration: 0:03:31
# Epoch   2 Batch   9 Loss: 0.6321 62.3% ( 30)
# Epoch   2 Batch  19 Loss: 0.6484 64.2% ( 30)
# Epoch   2 Batch  29 Loss: 0.6531 63.9% ( 30)
# Epoch   2 Batch  39 Loss: 0.6028 64.4% ( 30)
# Epoch   2 Batch  49 Loss: 0.6028 64.6% ( 30)
# Epoch   2 Batch  59 Loss: 0.7503 64.4% ( 30)
# Epoch   2 Batch  69 Loss: 0.6103 65.0% ( 30)
# Epoch   2 Batch  79 Loss: 0.6628 65.0% ( 30)
# Epoch   2 Batch  89 Loss: 0.7190 64.6% ( 30)
# Epoch   2 Batch  99 Loss: 0.5899 64.7% ( 30)
# Epoch   2 Batch 109 Loss: 0.5971 64.9% ( 30)
# Epoch   2 Batch 119 Loss: 0.6553 64.9% ( 30)
# Epoch   2 Batch 129 Loss: 0.5806 64.6% ( 30)
# Epoch   2 Batch 139 Loss: 0.7483 64.4% ( 30)
# Epoch   2 Batch 149 Loss: 0.7456 64.1% ( 30)
# Epoch   2 Batch 159 Loss: 0.6649 63.8% ( 30)
# Epoch   2 Batch 169 Loss: 0.6304 63.7% ( 30)
# Epoch   2 Batch 179 Loss: 0.7057 63.8% ( 30)
# Epoch   2 Batch 189 Loss: 0.7459 63.5% ( 30)
# Epoch   2 Batch 199 Loss: 0.7960 63.7% ( 30)
# Epoch   2 Batch 209 Loss: 0.7438 63.7% ( 30)
# Epoch   2 Batch 219 Loss: 0.6456 63.3% ( 30)
# Epoch   2 Batch 229 Loss: 0.6173 63.6% ( 30)
# Epoch   2 Batch 239 Loss: 0.7083 63.3% ( 30)
# Epoch   2 Batch 249 Loss: 0.6804 63.2% ( 30)
# Epoch   2 Evaluation acc :63.2% Duration: 0:03:33
# Epoch   3 Batch   9 Loss: 0.6441 63.0% ( 30)
# Epoch   3 Batch  19 Loss: 0.5457 63.7% ( 30)
# Epoch   3 Batch  29 Loss: 0.6342 63.3% ( 30)
# Epoch   3 Batch  39 Loss: 0.7189 63.4% ( 30)
# Epoch   3 Batch  49 Loss: 0.6375 64.1% ( 30)
# Epoch   3 Batch  59 Loss: 0.5416 64.9% ( 30)
# Epoch   3 Batch  69 Loss: 0.7565 64.1% ( 30)
# Epoch   3 Batch  79 Loss: 0.6522 63.6% ( 30)
# Epoch   3 Batch  89 Loss: 0.5265 63.6% ( 30)
# Epoch   3 Batch  99 Loss: 0.7398 63.5% ( 30)
# Epoch   3 Batch 109 Loss: 0.5742 63.7% ( 30)
# Epoch   3 Batch 119 Loss: 0.7558 63.7% ( 30)
# Epoch   3 Batch 129 Loss: 0.5715 63.6% ( 30)
# Epoch   3 Batch 139 Loss: 0.5351 63.8% ( 30)
# Epoch   3 Batch 149 Loss: 0.6968 63.6% ( 30)
# Epoch   3 Batch 159 Loss: 0.6739 63.4% ( 30)
# Epoch   3 Batch 169 Loss: 0.6271 63.7% ( 30)
# Epoch   3 Batch 179 Loss: 0.6552 63.6% ( 30)
# Epoch   3 Batch 189 Loss: 0.6232 63.8% ( 30)
# Epoch   3 Batch 199 Loss: 0.7175 63.7% ( 30)
# Epoch   3 Batch 209 Loss: 0.6661 63.7% ( 30)
# Epoch   3 Batch 219 Loss: 0.5747 63.6% ( 30)
# Epoch   3 Batch 229 Loss: 0.6379 63.8% ( 30)
# Epoch   3 Batch 239 Loss: 0.6019 63.6% ( 30)
# Epoch   3 Batch 249 Loss: 0.5592 63.5% ( 30)
# Epoch   3 Evaluation acc :58.4% Duration: 0:03:30
# Epoch   4 Batch   9 Loss: 0.6194 65.3% ( 30)
# Epoch   4 Batch  19 Loss: 0.6649 66.2% ( 30)
# Epoch   4 Batch  29 Loss: 0.5033 66.9% ( 30)
# Epoch   4 Batch  39 Loss: 0.5148 67.3% ( 30)
# Epoch   4 Batch  49 Loss: 0.5225 66.9% ( 30)
# Epoch   4 Batch  59 Loss: 0.6766 65.5% ( 30)
# Epoch   4 Batch  69 Loss: 0.6633 64.9% ( 30)
# Epoch   4 Batch  79 Loss: 0.6354 64.6% ( 30)
# Epoch   4 Batch  89 Loss: 0.6806 64.1% ( 30)
# Epoch   4 Batch  99 Loss: 0.5843 64.5% ( 30)
# Epoch   4 Batch 109 Loss: 0.6519 64.6% ( 30)
# Epoch   4 Batch 119 Loss: 0.5039 64.8% ( 30)
# Epoch   4 Batch 129 Loss: 0.8185 64.6% ( 30)
# Epoch   4 Batch 139 Loss: 0.5831 64.7% ( 30)
# Epoch   4 Batch 149 Loss: 0.6409 64.7% ( 30)
# Epoch   4 Batch 159 Loss: 0.6838 64.5% ( 30)
# Epoch   4 Batch 169 Loss: 0.6919 64.3% ( 30)
# Epoch   4 Batch 179 Loss: 0.4936 64.4% ( 30)
# Epoch   4 Batch 189 Loss: 0.6464 64.3% ( 30)
# Epoch   4 Batch 199 Loss: 0.5358 64.2% ( 30)
# Epoch   4 Batch 209 Loss: 0.6287 64.2% ( 30)
# Epoch   4 Batch 219 Loss: 0.6614 64.1% ( 30)
# Epoch   4 Batch 229 Loss: 0.6130 64.0% ( 30)
# Epoch   4 Batch 239 Loss: 0.7521 63.9% ( 30)
# Epoch   4 Batch 249 Loss: 0.6093 63.9% ( 30)
# Epoch   4 Evaluation acc :60.8% Duration: 0:03:28
# Epoch   5 Batch   9 Loss: 0.7238 62.7% ( 30)
# Epoch   5 Batch  19 Loss: 0.5483 64.0% ( 30)
# Epoch   5 Batch  29 Loss: 0.5670 65.4% ( 30)
# Epoch   5 Batch  39 Loss: 0.5689 65.2% ( 30)
# Epoch   5 Batch  49 Loss: 0.5588 65.5% ( 30)
# Epoch   5 Batch  59 Loss: 0.6018 64.8% ( 30)
# Epoch   5 Batch  69 Loss: 0.5235 65.3% ( 30)
# Epoch   5 Batch  79 Loss: 0.7393 65.2% ( 30)
# Epoch   5 Batch  89 Loss: 0.6566 65.3% ( 30)
# Epoch   5 Batch  99 Loss: 0.7606 65.5% ( 30)
# Epoch   5 Batch 109 Loss: 0.5623 65.0% ( 30)
# Epoch   5 Batch 119 Loss: 0.6315 65.0% ( 30)
# Epoch   5 Batch 129 Loss: 0.7570 65.0% ( 30)
# Epoch   5 Batch 139 Loss: 0.5912 65.0% ( 30)
# Epoch   5 Batch 149 Loss: 0.6090 65.1% ( 30)
# Epoch   5 Batch 159 Loss: 0.5795 65.3% ( 30)
# Epoch   5 Batch 169 Loss: 0.5328 65.6% ( 30)
# Epoch   5 Batch 179 Loss: 0.6530 65.5% ( 30)
# Epoch   5 Batch 189 Loss: 0.8184 65.4% ( 30)
# Epoch   5 Batch 199 Loss: 0.5776 65.5% ( 30)
# Epoch   5 Batch 209 Loss: 0.5766 65.5% ( 30)
# Epoch   5 Batch 219 Loss: 0.7528 65.7% ( 30)
# Epoch   5 Batch 229 Loss: 0.5819 65.6% ( 30)
# Epoch   5 Batch 239 Loss: 0.4913 65.5% ( 30)
# Epoch   5 Batch 249 Loss: 0.7048 65.3% ( 30)
# Epoch   5 Evaluation acc :63.2% Duration: 0:03:26
# Epoch   6 Batch   9 Loss: 0.7054 69.3% ( 30)
# Epoch   6 Batch  19 Loss: 0.7850 69.0% ( 30)
# Epoch   6 Batch  29 Loss: 0.6763 67.1% ( 30)
# Epoch   6 Batch  39 Loss: 0.6065 66.3% ( 30)
# Epoch   6 Batch  49 Loss: 0.5825 66.5% ( 30)
# Epoch   6 Batch  59 Loss: 0.6072 67.0% ( 30)
# Epoch   6 Batch  69 Loss: 0.5019 67.4% ( 30)
# Epoch   6 Batch  79 Loss: 0.6552 66.8% ( 30)
# Epoch   6 Batch  89 Loss: 0.7577 65.8% ( 30)
# Epoch   6 Batch  99 Loss: 0.6433 65.9% ( 30)
# Epoch   6 Batch 109 Loss: 0.6063 65.8% ( 30)
# Epoch   6 Batch 119 Loss: 0.5279 66.0% ( 30)
# Epoch   6 Batch 129 Loss: 0.6095 65.7% ( 30)
# Epoch   6 Batch 139 Loss: 0.5261 65.6% ( 30)
# Epoch   6 Batch 149 Loss: 0.6326 65.4% ( 30)
# Epoch   6 Batch 159 Loss: 0.5607 65.6% ( 30)
# Epoch   6 Batch 169 Loss: 0.5880 65.8% ( 30)
# Epoch   6 Batch 179 Loss: 0.5406 65.7% ( 30)
# Epoch   6 Batch 189 Loss: 0.6878 65.9% ( 30)
# Epoch   6 Batch 199 Loss: 0.5785 66.0% ( 30)
# Epoch   6 Batch 209 Loss: 0.5484 66.0% ( 30)
# Epoch   6 Batch 219 Loss: 0.6540 66.0% ( 30)
# Epoch   6 Batch 229 Loss: 0.6985 66.0% ( 30)
# Epoch   6 Batch 239 Loss: 0.7134 65.9% ( 30)
# Epoch   6 Batch 249 Loss: 0.6185 65.9% ( 30)
# Epoch   6 Evaluation acc :61.6% Duration: 0:03:29
# Epoch   7 Batch   9 Loss: 0.5413 69.0% ( 30)
# Epoch   7 Batch  19 Loss: 0.6300 68.0% ( 30)
# Epoch   7 Batch  29 Loss: 0.4988 68.1% ( 30)
# Epoch   7 Batch  39 Loss: 0.6066 68.5% ( 30)
# Epoch   7 Batch  49 Loss: 0.4880 67.8% ( 30)
# Epoch   7 Batch  59 Loss: 0.6825 67.7% ( 30)
# Epoch   7 Batch  69 Loss: 0.7476 67.8% ( 30)
# Epoch   7 Batch  79 Loss: 0.4840 67.1% ( 30)
# Epoch   7 Batch  89 Loss: 0.5994 67.1% ( 30)
# Epoch   7 Batch  99 Loss: 0.6263 67.4% ( 30)
# Epoch   7 Batch 109 Loss: 0.6087 67.1% ( 30)
# Epoch   7 Batch 119 Loss: 0.6207 67.3% ( 30)
# Epoch   7 Batch 129 Loss: 0.5515 67.3% ( 30)
# Epoch   7 Batch 139 Loss: 0.5487 67.0% ( 30)
# Epoch   7 Batch 149 Loss: 0.7253 66.7% ( 30)
# Epoch   7 Batch 159 Loss: 0.6493 66.8% ( 30)
# Epoch   7 Batch 169 Loss: 0.5340 66.6% ( 30)
# Epoch   7 Batch 179 Loss: 0.5479 66.7% ( 30)
# Epoch   7 Batch 189 Loss: 0.6230 66.9% ( 30)
# Epoch   7 Batch 199 Loss: 0.5384 66.8% ( 30)
# Epoch   7 Batch 209 Loss: 0.5655 67.1% ( 30)
# Epoch   7 Batch 219 Loss: 0.7446 67.2% ( 30)
# Epoch   7 Batch 229 Loss: 0.5476 67.0% ( 30)
# Epoch   7 Batch 239 Loss: 0.7142 66.9% ( 30)
# Epoch   7 Batch 249 Loss: 0.5391 67.0% ( 30)
# Epoch   7 Evaluation acc :62.8% Duration: 0:03:32
# Epoch   8 Batch   9 Loss: 0.5537 68.0% ( 30)
# Epoch   8 Batch  19 Loss: 0.6574 67.3% ( 30)
# Epoch   8 Batch  29 Loss: 0.5589 67.4% ( 30)
# Epoch   8 Batch  39 Loss: 0.6701 67.7% ( 30)
# Epoch   8 Batch  49 Loss: 0.6762 68.0% ( 30)
# Epoch   8 Batch  59 Loss: 0.7387 67.8% ( 30)
# Epoch   8 Batch  69 Loss: 0.6265 67.9% ( 30)
# Epoch   8 Batch  79 Loss: 0.6462 67.8% ( 30)
# Epoch   8 Batch  89 Loss: 0.7029 67.6% ( 30)
# Epoch   8 Batch  99 Loss: 0.6358 67.4% ( 30)
# Epoch   8 Batch 109 Loss: 0.5941 67.7% ( 30)
# Epoch   8 Batch 119 Loss: 0.6143 67.5% ( 30)
# Epoch   8 Batch 129 Loss: 0.6855 67.3% ( 30)
# Epoch   8 Batch 139 Loss: 0.6420 67.5% ( 30)
# Epoch   8 Batch 149 Loss: 0.5320 67.5% ( 30)
# Epoch   8 Batch 159 Loss: 0.6339 67.4% ( 30)
# Epoch   8 Batch 169 Loss: 0.4685 67.6% ( 30)
# Epoch   8 Batch 179 Loss: 0.5904 67.4% ( 30)
# Epoch   8 Batch 189 Loss: 0.4860 67.4% ( 30)
# Epoch   8 Batch 199 Loss: 0.7875 67.3% ( 30)
# Epoch   8 Batch 209 Loss: 0.7192 67.3% ( 30)
# Epoch   8 Batch 219 Loss: 0.6847 67.5% ( 30)
# Epoch   8 Batch 229 Loss: 0.6907 67.3% ( 30)
# Epoch   8 Batch 239 Loss: 0.7938 67.2% ( 30)
# Epoch   8 Batch 249 Loss: 0.6950 67.0% ( 30)
# Epoch   8 Evaluation acc :61.2% Duration: 0:03:32
# Epoch   9 Batch   9 Loss: 0.5451 66.7% ( 30)
# Epoch   9 Batch  19 Loss: 0.5263 71.7% ( 30)
# Epoch   9 Batch  29 Loss: 0.5669 71.8% ( 30)
# Epoch   9 Batch  39 Loss: 0.6606 70.2% ( 30)
# Epoch   9 Batch  49 Loss: 0.5478 70.4% ( 30)
# Epoch   9 Batch  59 Loss: 0.3973 70.3% ( 30)
# Epoch   9 Batch  69 Loss: 0.5164 69.9% ( 30)
# Epoch   9 Batch  79 Loss: 0.6033 70.0% ( 30)
# Epoch   9 Batch  89 Loss: 0.5896 69.6% ( 30)
# Epoch   9 Batch  99 Loss: 0.6556 69.4% ( 30)
# Epoch   9 Batch 109 Loss: 0.7995 69.1% ( 30)
# Epoch   9 Batch 119 Loss: 0.5155 69.3% ( 30)
# Epoch   9 Batch 129 Loss: 0.5854 69.4% ( 30)
# Epoch   9 Batch 139 Loss: 0.6693 69.1% ( 30)
# Epoch   9 Batch 149 Loss: 0.5726 69.3% ( 30)
# Epoch   9 Batch 159 Loss: 0.6476 69.3% ( 30)
# Epoch   9 Batch 169 Loss: 0.5775 69.1% ( 30)
# Epoch   9 Batch 179 Loss: 0.5654 69.0% ( 30)
# Epoch   9 Batch 189 Loss: 0.5628 68.8% ( 30)
# Epoch   9 Batch 199 Loss: 0.6560 68.8% ( 30)
# Epoch   9 Batch 209 Loss: 0.6192 68.7% ( 30)
# Epoch   9 Batch 219 Loss: 0.5199 68.7% ( 30)
# Epoch   9 Batch 229 Loss: 0.4668 68.7% ( 30)
# Epoch   9 Batch 239 Loss: 0.5964 68.6% ( 30)
# Epoch   9 Batch 249 Loss: 0.5140 68.6% ( 30)
# Epoch   9 Evaluation acc :60.4% Duration: 0:03:33
# Epoch  10 Batch   9 Loss: 0.6564 68.0% ( 30)
# Epoch  10 Batch  19 Loss: 0.5833 68.0% ( 30)
# Epoch  10 Batch  29 Loss: 0.4467 69.4% ( 30)
# Epoch  10 Batch  39 Loss: 0.5309 69.9% ( 30)
# Epoch  10 Batch  49 Loss: 0.5029 71.1% ( 30)
# Epoch  10 Batch  59 Loss: 0.5418 70.8% ( 30)
# Epoch  10 Batch  69 Loss: 0.5616 71.0% ( 30)
# Epoch  10 Batch  79 Loss: 0.4430 71.1% ( 30)
# Epoch  10 Batch  89 Loss: 0.6649 70.3% ( 30)
# Epoch  10 Batch  99 Loss: 0.6573 70.0% ( 30)
# Epoch  10 Batch 109 Loss: 0.6470 70.2% ( 30)
# Epoch  10 Batch 119 Loss: 0.5281 69.4% ( 30)
# Epoch  10 Batch 129 Loss: 0.5327 69.4% ( 30)
# Epoch  10 Batch 139 Loss: 0.6418 69.1% ( 30)
# Epoch  10 Batch 149 Loss: 0.5385 69.2% ( 30)
# Epoch  10 Batch 159 Loss: 0.4812 69.3% ( 30)
# Epoch  10 Batch 169 Loss: 0.7515 69.1% ( 30)
# Epoch  10 Batch 179 Loss: 0.7058 69.1% ( 30)
# Epoch  10 Batch 189 Loss: 0.5739 69.2% ( 30)
# Epoch  10 Batch 199 Loss: 0.8177 68.9% ( 30)
# Epoch  10 Batch 209 Loss: 0.7064 68.8% ( 30)
# Epoch  10 Batch 219 Loss: 0.5490 69.0% ( 30)
# Epoch  10 Batch 229 Loss: 0.5422 69.0% ( 30)
# Epoch  10 Batch 239 Loss: 0.5350 69.1% ( 30)
# Epoch  10 Batch 249 Loss: 0.4886 69.0% ( 30)
# Epoch  10 Evaluation acc :59.2% Duration: 0:03:31
# Epoch  11 Batch   9 Loss: 0.5594 70.7% ( 30)
# Epoch  11 Batch  19 Loss: 0.5680 70.2% ( 30)
# Epoch  11 Batch  29 Loss: 0.5278 70.3% ( 30)
# Epoch  11 Batch  39 Loss: 0.6207 69.8% ( 30)
# Epoch  11 Batch  49 Loss: 0.5109 70.1% ( 30)
# Epoch  11 Batch  59 Loss: 0.5749 70.8% ( 30)
# Epoch  11 Batch  69 Loss: 0.6224 70.6% ( 30)
# Epoch  11 Batch  79 Loss: 0.7522 69.8% ( 30)
# Epoch  11 Batch  89 Loss: 0.4969 70.2% ( 30)
# Epoch  11 Batch  99 Loss: 0.7100 70.2% ( 30)
# Epoch  11 Batch 109 Loss: 0.5851 69.8% ( 30)
# Epoch  11 Batch 119 Loss: 0.4566 69.9% ( 30)
# Epoch  11 Batch 129 Loss: 0.5719 69.7% ( 30)
# Epoch  11 Batch 139 Loss: 0.6173 69.6% ( 30)
# Epoch  11 Batch 149 Loss: 0.5603 69.6% ( 30)
# Epoch  11 Batch 159 Loss: 0.5446 69.7% ( 30)
# Epoch  11 Batch 169 Loss: 0.4975 69.6% ( 30)
# Epoch  11 Batch 179 Loss: 0.6678 69.6% ( 30)
# Epoch  11 Batch 189 Loss: 0.5092 69.5% ( 30)
# Epoch  11 Batch 199 Loss: 0.7360 69.3% ( 30)
# Epoch  11 Batch 209 Loss: 0.5065 69.1% ( 30)
# Epoch  11 Batch 219 Loss: 0.5112 69.2% ( 30)
# Epoch  11 Batch 229 Loss: 0.5528 69.3% ( 30)
# Epoch  11 Batch 239 Loss: 0.6914 69.3% ( 30)
# Epoch  11 Batch 249 Loss: 0.5719 69.2% ( 30)
# Epoch  11 Evaluation acc :60.8% Duration: 0:03:29
# Epoch  12 Batch   9 Loss: 0.4797 68.7% ( 30)
# Epoch  12 Batch  19 Loss: 0.3880 71.8% ( 30)
# Epoch  12 Batch  29 Loss: 0.5753 72.0% ( 30)
# Epoch  12 Batch  39 Loss: 0.6320 71.5% ( 30)
# Epoch  12 Batch  49 Loss: 0.5972 71.4% ( 30)
# Epoch  12 Batch  59 Loss: 0.4737 72.2% ( 30)
# Epoch  12 Batch  69 Loss: 0.4773 72.1% ( 30)
# Epoch  12 Batch  79 Loss: 0.5900 71.8% ( 30)
# Epoch  12 Batch  89 Loss: 0.8858 71.6% ( 30)
# Epoch  12 Batch  99 Loss: 0.5582 71.5% ( 30)
# Epoch  12 Batch 109 Loss: 0.6043 71.3% ( 30)
# Epoch  12 Batch 119 Loss: 0.6179 71.1% ( 30)
# Epoch  12 Batch 129 Loss: 0.5231 70.7% ( 30)
# Epoch  12 Batch 139 Loss: 0.7119 70.6% ( 30)
# Epoch  12 Batch 149 Loss: 0.4997 70.7% ( 30)
# Epoch  12 Batch 159 Loss: 0.6276 70.6% ( 30)
# Epoch  12 Batch 169 Loss: 0.5126 70.7% ( 30)
# Epoch  12 Batch 179 Loss: 0.5288 70.4% ( 30)
# Epoch  12 Batch 189 Loss: 0.5558 70.3% ( 30)
# Epoch  12 Batch 199 Loss: 0.6093 70.4% ( 30)
# Epoch  12 Batch 209 Loss: 0.4909 70.4% ( 30)
# Epoch  12 Batch 219 Loss: 0.5696 70.1% ( 30)
# Epoch  12 Batch 229 Loss: 0.6769 69.9% ( 30)
# Epoch  12 Batch 239 Loss: 0.4499 70.0% ( 30)
# Epoch  12 Batch 249 Loss: 0.6375 69.8% ( 30)
# Epoch  12 Evaluation acc :62.0% Duration: 0:03:33
# Epoch  13 Batch   9 Loss: 0.7477 70.0% ( 30)
# Epoch  13 Batch  19 Loss: 0.5323 69.5% ( 30)
# Epoch  13 Batch  29 Loss: 0.5655 70.9% ( 30)
# Epoch  13 Batch  39 Loss: 0.6843 70.5% ( 30)
# Epoch  13 Batch  49 Loss: 0.5718 71.3% ( 30)
# Epoch  13 Batch  59 Loss: 0.6290 70.9% ( 30)
# Epoch  13 Batch  69 Loss: 0.5286 70.9% ( 30)
# Epoch  13 Batch  79 Loss: 0.5099 70.8% ( 30)
# Epoch  13 Batch  89 Loss: 0.5093 71.1% ( 30)
# Epoch  13 Batch  99 Loss: 0.4888 71.1% ( 30)
# Epoch  13 Batch 109 Loss: 0.6342 70.9% ( 30)
# Epoch  13 Batch 119 Loss: 0.5938 70.7% ( 30)
# Epoch  13 Batch 129 Loss: 0.5218 70.6% ( 30)
# Epoch  13 Batch 139 Loss: 0.5727 70.5% ( 30)
# Epoch  13 Batch 149 Loss: 0.5983 70.4% ( 30)
# Epoch  13 Batch 159 Loss: 0.4562 70.4% ( 30)
# Epoch  13 Batch 169 Loss: 0.6395 70.4% ( 30)
# Epoch  13 Batch 179 Loss: 0.5744 70.3% ( 30)
# Epoch  13 Batch 189 Loss: 0.6261 70.2% ( 30)
# Epoch  13 Batch 199 Loss: 0.5665 70.2% ( 30)
# Epoch  13 Batch 209 Loss: 0.6110 70.2% ( 30)
# Epoch  13 Batch 219 Loss: 0.7127 70.1% ( 30)
# Epoch  13 Batch 229 Loss: 0.5637 70.2% ( 30)
# Epoch  13 Batch 239 Loss: 0.5624 70.2% ( 30)
# Epoch  13 Batch 249 Loss: 0.4777 70.3% ( 30)
# Epoch  13 Evaluation acc :60.4% Duration: 0:03:33
# Epoch  14 Batch   9 Loss: 0.4948 70.0% ( 30)
# Epoch  14 Batch  19 Loss: 0.4773 71.2% ( 30)
# Epoch  14 Batch  29 Loss: 0.4638 71.9% ( 30)
# Epoch  14 Batch  39 Loss: 0.5116 72.2% ( 30)
# Epoch  14 Batch  49 Loss: 0.5045 71.9% ( 30)
# Epoch  14 Batch  59 Loss: 0.6552 72.2% ( 30)
# Epoch  14 Batch  69 Loss: 0.4946 71.8% ( 30)
# Epoch  14 Batch  79 Loss: 0.4591 72.1% ( 30)
# Epoch  14 Batch  89 Loss: 0.5239 72.3% ( 30)
# Epoch  14 Batch  99 Loss: 0.5225 72.2% ( 30)
# Epoch  14 Batch 109 Loss: 0.4341 72.2% ( 30)
# Epoch  14 Batch 119 Loss: 0.4900 72.4% ( 30)
# Epoch  14 Batch 129 Loss: 0.4342 72.0% ( 30)
# Epoch  14 Batch 139 Loss: 0.5847 72.0% ( 30)
# Epoch  14 Batch 149 Loss: 0.5938 71.7% ( 30)
# Epoch  14 Batch 159 Loss: 0.6373 71.8% ( 30)
# Epoch  14 Batch 169 Loss: 0.6298 71.8% ( 30)
# Epoch  14 Batch 179 Loss: 0.5750 71.9% ( 30)
# Epoch  14 Batch 189 Loss: 0.5648 72.2% ( 30)
# Epoch  14 Batch 199 Loss: 0.6654 72.1% ( 30)
# Epoch  14 Batch 209 Loss: 0.6474 71.8% ( 30)
# Epoch  14 Batch 219 Loss: 0.5264 71.9% ( 30)
# Epoch  14 Batch 229 Loss: 0.6848 71.6% ( 30)
# Epoch  14 Batch 239 Loss: 0.5135 71.6% ( 30)
# Epoch  14 Batch 249 Loss: 0.4810 71.6% ( 30)
# Epoch  14 Evaluation acc :60.8% Duration: 0:03:31
# Epoch  15 Batch   9 Loss: 0.4860 69.3% ( 30)
# Epoch  15 Batch  19 Loss: 0.5540 70.2% ( 30)
# Epoch  15 Batch  29 Loss: 0.5528 71.7% ( 30)
# Epoch  15 Batch  39 Loss: 0.5355 72.4% ( 30)
# Epoch  15 Batch  49 Loss: 0.6064 72.5% ( 30)
# Epoch  15 Batch  59 Loss: 0.5433 72.1% ( 30)
# Epoch  15 Batch  69 Loss: 0.5251 72.8% ( 30)
# Epoch  15 Batch  79 Loss: 0.4528 72.5% ( 30)
# Epoch  15 Batch  89 Loss: 0.4757 72.4% ( 30)
# Epoch  15 Batch  99 Loss: 0.4222 72.2% ( 30)
# Epoch  15 Batch 109 Loss: 0.4953 72.3% ( 30)
# Epoch  15 Batch 119 Loss: 0.6334 72.0% ( 30)
# Epoch  15 Batch 129 Loss: 0.6933 71.8% ( 30)
# Epoch  15 Batch 139 Loss: 0.5851 71.7% ( 30)
# Epoch  15 Batch 149 Loss: 0.5070 71.7% ( 30)
# Epoch  15 Batch 159 Loss: 0.5105 71.7% ( 30)
# Epoch  15 Batch 169 Loss: 0.5716 71.4% ( 30)
# Epoch  15 Batch 179 Loss: 0.5278 71.4% ( 30)
# Epoch  15 Batch 189 Loss: 0.5630 71.4% ( 30)
# Epoch  15 Batch 199 Loss: 0.6169 71.5% ( 30)
# Epoch  15 Batch 209 Loss: 0.5723 71.5% ( 30)
# Epoch  15 Batch 219 Loss: 0.5286 71.6% ( 30)
# Epoch  15 Batch 229 Loss: 0.6623 71.6% ( 30)
# Epoch  15 Batch 239 Loss: 0.7139 71.4% ( 30)
# Epoch  15 Batch 249 Loss: 0.5755 71.3% ( 30)
# Epoch  15 Evaluation acc :61.2% Duration: 0:03:33
# Epoch  16 Batch   9 Loss: 0.4420 74.7% ( 30)
# Epoch  16 Batch  19 Loss: 0.5181 73.8% ( 30)
# Epoch  16 Batch  29 Loss: 0.4992 72.3% ( 30)
# Epoch  16 Batch  39 Loss: 0.5537 71.9% ( 30)
# Epoch  16 Batch  49 Loss: 0.4853 72.1% ( 30)
# Epoch  16 Batch  59 Loss: 0.4567 71.9% ( 30)
# Epoch  16 Batch  69 Loss: 0.4638 72.0% ( 30)
# Epoch  16 Batch  79 Loss: 0.5641 72.5% ( 30)
# Epoch  16 Batch  89 Loss: 0.5616 72.1% ( 30)
# Epoch  16 Batch  99 Loss: 0.5762 72.5% ( 30)
# Epoch  16 Batch 109 Loss: 0.3802 72.5% ( 30)
# Epoch  16 Batch 119 Loss: 0.4972 72.2% ( 30)
# Epoch  16 Batch 129 Loss: 0.4669 72.6% ( 30)
# Epoch  16 Batch 139 Loss: 0.5895 72.5% ( 30)
# Epoch  16 Batch 149 Loss: 0.5546 72.3% ( 30)
# Epoch  16 Batch 159 Loss: 0.6924 72.2% ( 30)
# Epoch  16 Batch 169 Loss: 0.5864 72.4% ( 30)
# Epoch  16 Batch 179 Loss: 0.6818 72.1% ( 30)
# Epoch  16 Batch 189 Loss: 0.4714 72.3% ( 30)
# Epoch  16 Batch 199 Loss: 0.5831 72.1% ( 30)
# Epoch  16 Batch 209 Loss: 0.6966 72.1% ( 30)
# Epoch  16 Batch 219 Loss: 0.8149 71.9% ( 30)
# Epoch  16 Batch 229 Loss: 0.5116 71.8% ( 30)
# Epoch  16 Batch 239 Loss: 0.5986 71.5% ( 30)
# Epoch  16 Batch 249 Loss: 0.8233 71.4% ( 30)
# Epoch  16 Evaluation acc :60.8% Duration: 0:03:33
# Epoch  17 Batch   9 Loss: 0.5034 71.0% ( 30)
# Epoch  17 Batch  19 Loss: 0.5210 72.3% ( 30)
# Epoch  17 Batch  29 Loss: 0.6241 72.1% ( 30)
# Epoch  17 Batch  39 Loss: 0.7201 72.2% ( 30)
# Epoch  17 Batch  49 Loss: 0.5462 71.9% ( 30)
# Epoch  17 Batch  59 Loss: 0.5634 72.6% ( 30)
# Epoch  17 Batch  69 Loss: 0.6091 72.8% ( 30)
# Epoch  17 Batch  79 Loss: 0.4832 72.8% ( 30)
# Epoch  17 Batch  89 Loss: 0.5039 73.5% ( 30)
# Epoch  17 Batch  99 Loss: 0.4353 73.5% ( 30)
# Epoch  17 Batch 109 Loss: 0.6273 73.0% ( 30)
# Epoch  17 Batch 119 Loss: 0.6415 72.8% ( 30)
# Epoch  17 Batch 129 Loss: 0.5060 72.8% ( 30)
# Epoch  17 Batch 139 Loss: 0.3782 72.6% ( 30)
# Epoch  17 Batch 149 Loss: 0.5175 72.9% ( 30)
# Epoch  17 Batch 159 Loss: 0.5878 72.9% ( 30)
# Epoch  17 Batch 169 Loss: 0.5066 73.0% ( 30)
# Epoch  17 Batch 179 Loss: 0.8172 73.2% ( 30)
# Epoch  17 Batch 189 Loss: 0.4505 73.1% ( 30)
# Epoch  17 Batch 199 Loss: 0.3793 72.9% ( 30)
# Epoch  17 Batch 209 Loss: 0.6805 72.8% ( 30)
# Epoch  17 Batch 219 Loss: 0.5959 72.6% ( 30)
# Epoch  17 Batch 229 Loss: 0.6944 72.6% ( 30)
# Epoch  17 Batch 239 Loss: 0.5814 72.5% ( 30)
# Epoch  17 Batch 249 Loss: 0.5947 72.3% ( 30)
# Epoch  17 Evaluation acc :62.0% Duration: 0:03:33
# Epoch  18 Batch   9 Loss: 0.4921 73.3% ( 30)
# Epoch  18 Batch  19 Loss: 0.5045 74.8% ( 30)
# Epoch  18 Batch  29 Loss: 0.5990 75.0% ( 30)
# Epoch  18 Batch  39 Loss: 0.5079 75.7% ( 30)
# Epoch  18 Batch  49 Loss: 0.4895 74.7% ( 30)
# Epoch  18 Batch  59 Loss: 0.5430 74.3% ( 30)
# Epoch  18 Batch  69 Loss: 0.4871 73.9% ( 30)
# Epoch  18 Batch  79 Loss: 0.5852 73.9% ( 30)
# Epoch  18 Batch  89 Loss: 0.4969 73.9% ( 30)
# Epoch  18 Batch  99 Loss: 0.6168 73.6% ( 30)
# Epoch  18 Batch 109 Loss: 0.5343 73.6% ( 30)
# Epoch  18 Batch 119 Loss: 0.5257 73.5% ( 30)
# Epoch  18 Batch 129 Loss: 0.5261 73.6% ( 30)
# Epoch  18 Batch 139 Loss: 0.7228 73.3% ( 30)
# Epoch  18 Batch 149 Loss: 0.5166 73.1% ( 30)
# Epoch  18 Batch 159 Loss: 0.5322 72.9% ( 30)
# Epoch  18 Batch 169 Loss: 0.7413 72.7% ( 30)
# Epoch  18 Batch 179 Loss: 0.5807 72.8% ( 30)
# Epoch  18 Batch 189 Loss: 0.4615 73.0% ( 30)
# Epoch  18 Batch 199 Loss: 0.6858 72.9% ( 30)
# Epoch  18 Batch 209 Loss: 0.3883 72.8% ( 30)
# Epoch  18 Batch 219 Loss: 0.6741 72.8% ( 30)
# Epoch  18 Batch 229 Loss: 0.5404 72.9% ( 30)
# Epoch  18 Batch 239 Loss: 0.7021 72.8% ( 30)
# Epoch  18 Batch 249 Loss: 0.6136 72.8% ( 30)
# Epoch  18 Evaluation acc :64.8% Duration: 0:03:33
# Epoch  19 Batch   9 Loss: 0.5300 76.7% ( 30)
# Epoch  19 Batch  19 Loss: 0.3537 78.5% ( 30)
# Epoch  19 Batch  29 Loss: 0.5470 77.2% ( 30)
# Epoch  19 Batch  39 Loss: 0.5607 77.0% ( 30)
# Epoch  19 Batch  49 Loss: 0.6407 76.5% ( 30)
# Epoch  19 Batch  59 Loss: 0.4307 76.3% ( 30)
# Epoch  19 Batch  69 Loss: 0.5967 75.4% ( 30)
# Epoch  19 Batch  79 Loss: 0.6045 74.7% ( 30)
# Epoch  19 Batch  89 Loss: 0.5383 74.9% ( 30)
# Epoch  19 Batch  99 Loss: 0.6847 74.8% ( 30)
# Epoch  19 Batch 109 Loss: 0.5115 74.8% ( 30)
# Epoch  19 Batch 119 Loss: 0.4361 74.7% ( 30)
# Epoch  19 Batch 129 Loss: 0.4599 75.0% ( 30)
# Epoch  19 Batch 139 Loss: 0.4945 74.7% ( 30)
# Epoch  19 Batch 149 Loss: 0.4819 74.6% ( 30)
# Epoch  19 Batch 159 Loss: 0.4343 74.5% ( 30)
# Epoch  19 Batch 169 Loss: 0.5989 74.4% ( 30)
# Epoch  19 Batch 179 Loss: 0.5863 74.2% ( 30)
# Epoch  19 Batch 189 Loss: 0.6301 74.0% ( 30)
# Epoch  19 Batch 199 Loss: 0.4674 74.1% ( 30)
# Epoch  19 Batch 209 Loss: 0.6102 74.1% ( 30)
# Epoch  19 Batch 219 Loss: 0.3918 74.2% ( 30)
# Epoch  19 Batch 229 Loss: 0.4873 74.1% ( 30)
# Epoch  19 Batch 239 Loss: 0.5361 74.1% ( 30)
# Epoch  19 Batch 249 Loss: 0.4655 74.0% ( 30)
# Epoch  19 Evaluation acc :62.8% Duration: 0:03:33
# Total elapsed time : 1:10:27.194410
# 150000 samples in 4,227 seconds : 35.5 samples/sec

# %%
# plotting
fig, ax = plt.subplots(1,2,figsize=(15, 6))
ax[0].set_title("Training Curve (batch_size={}, lr={})".format(batch_size, learning_rate))
ax[0].plot(accur, label="Training")
ax[0].plot(epoch_e_accur, label="Validation")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")
ax[0].set_xticks(range(0,num_epochs,5))
ax[0].set_xticklabels(range(0,num_epochs,5))
ax[0].legend()

ax[1].set_title("Training Curve (batch_size={}, lr={})".format(batch_size, learning_rate))
ax[1].plot(losses, label="Training")
ax[1].plot(epoch_e_loss, label="Validation")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
ax[1].set_xticks(range(0,num_epochs,5))
ax[1].set_xticklabels(range(0,num_epochs,5))
ax[1].legend()
plt.show()
