# %%
import os
import time
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms
from torchsummary import summary

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
from torch.utils.data import Dataset, TensorDataset, ChainDataset, DataLoader
from sklearn.feature_extraction.text import CountVectorizer

# %%
device = torch.device('cuda')
print(device)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
if not os.path.exists('annotation_map.save'):
    # !unzip '/content/gdrive/My Drive/aidl/full_embeddings.zip'
# Out:
# Archive:  /content/gdrive/My Drive/aidl/full_embeddings.zip
#   inflating: annotation_map.save
#   inflating: image_embeddings_train.save
#   inflating: question_embeddings_train.save
#   inflating: annotations_train.save
#   inflating: metadatas_train.save
#   inflating: image_embeddings_test.save
#   inflating: question_embeddings_test.save
#   inflating: annotations_test.save
#   inflating: metadatas_test.save

# %%
dataset_root = "/content"
answer2idx = torch.load(os.path.join(dataset_root,'annotation_map.save'))
idx2answer = { idx: answer for answer, idx in answer2idx.items() }

# %%
image_embeddings_train = torch.load(os.path.join(dataset_root,'image_embeddings_train.save'))
#question_embeddings_train = torch.load(os.path.join(dataset_root,'question_embeddings_train.save'))
annotations_train = torch.load(os.path.join(dataset_root,'annotations_train.save'))

# %%
image_embeddings_test = torch.load(os.path.join(dataset_root,'image_embeddings_test.save'))
#question_embeddings_test = torch.load(os.path.join(dataset_root,'question_embeddings_test.save'))
annotations_test = torch.load(os.path.join(dataset_root,'annotations_test.save'))

# %%
metadatas_train = torch.load(os.path.join(dataset_root,'metadatas_train.save'))
df_train = pd.DataFrame(metadatas_train)
questions_train = df_train['question_text'].to_list()

metadatas_test = torch.load(os.path.join(dataset_root,'metadatas_test.save'))
df_test = pd.DataFrame(metadatas_test)
questions_test = df_test['question_text'].to_list()

# %%
countVec = CountVectorizer(stop_words=['?'],min_df=5)
countVec.fit_transform(df_train['question_text'])

word2idx = countVec.vocabulary_
idx2word = { idx: word for word, idx in word2idx.items() }

print(len(word2idx))
# Out:
# 3209

# %%
#   Create list a2mfa to reindex annotations for a fixed size classifier output (1000)

most_freq_answers = torch.load('/content/gdrive/My Drive/aidl/stats/1000w.save')
most_freq_answers_dict = { ans: answer2idx[ans] for ans in most_freq_answers }

new_idx = 0
answer2mfa = [999] * len(answer2idx)
for ans,idx in answer2idx.items():
  if ans in most_freq_answers:
    answer2mfa[idx] = new_idx
    new_idx += 1

# %%
'''
count = 0
for ans in annotations_train:
    if ans in most_freq_answers_idx:
        count +=1
print(count)
print(round(count/len(annotations_train)*100,2),'%')

OUT:
78619
86.27 %
'''
# Out:
# "\ncount = 0\nfor ans in annotations_train:\n    if ans in most_freq_answers_idx:\n        count +=1\nprint(count)\nprint(round(count/len(annotations_train)*100,2),'%')\n\nOUT:\n78619\n86.27 %\n"

# %%
'''
count = 0
for ans in annotations_test:
    if ans in most_freq_answers_idx:
        count +=1
print(count)
print(round(count/len(annotations_test)*100,2),'%')

OUT:
878
87.8 %
'''
# Out:
# "\ncount = 0\nfor ans in annotations_test:\n    if ans in most_freq_answers_idx:\n        count +=1\nprint(count)\nprint(round(count/len(annotations_test)*100,2),'%')\n\nOUT:\n878\n87.8 %\n"

# %%
class CustomDataset(Dataset):
    def __init__(self, questions, images, answers):

        assert len(questions) == len(images) & len(images) == len(answers), 'Different Lenghts!'

        self.questions = questions
        self.images = images
        self.answers = answers

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        return self.questions[idx], self.images[idx], self.answers[idx]

train_dataset = CustomDataset(image_embeddings_train,questions_train,annotations_train)
test_dataset = CustomDataset(image_embeddings_test,questions_test,annotations_test)

batch_size = 400
train_dataloader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
test_dataloader = DataLoader(test_dataset,batch_size=batch_size,shuffle=True)

# %%
class VQA2015(nn.Module):
    
    def __init__(self, embedding_dim, hidden_dim, vocab_size, image_dim, tagset_size):
        
        super(VQA2015, self).__init__()
        
        # Branca Llenguatge

        self.hidden_dim = hidden_dim
        
        self.word_embeddings = nn.Embedding(vocab_size + 1, embedding_dim, padding_idx = vocab_size)

        self.relu = nn.ReLU() # https://discuss.pytorch.org/t/torch-tanh-vs-torch-nn-functional-tanh/15897/7

        self.lstm = nn.LSTM(embedding_dim, hidden_dim,batch_first=True)

        self.txt_fcl = nn.Sequential(
            nn.Linear(2*hidden_dim, 2*hidden_dim),
            nn.ReLU()
            )
        
        # Branca Imatge (VGG16)

        self.img_fcl = nn.Sequential(
            nn.Linear(image_dim, 2*hidden_dim), 
            nn.ReLU()
            )

        # Classificador
                
        self.classificador = nn.Sequential(
            nn.Linear(2*hidden_dim, 1000),
            nn.ReLU(),
            nn.BatchNorm1d(num_features=1000),
            #nn.Dropout(),
            nn.Linear(1000, 1000),
            nn.ReLU(),
            nn.BatchNorm1d(num_features=1000),
            #nn.Dropout(),
            nn.Linear(1000, 1000),
            nn.BatchNorm1d(num_features=1000),
            nn.ReLU(),
            #nn.Dropout(),
            nn.Linear(1000, tagset_size),
          )
                
    def forward(self,sentence,image,questionLengths):

        # Question
        embeds = self.word_embeddings(sentence) # batch_size x seq_len x embedding_dim

        #embeds = self.relu(embeds) # batch_size x seq_len x embedding_dim

        embeds = pack_padded_sequence(embeds, questionLengths, batch_first=True, enforce_sorted = False)

        hidden0 = ( torch.zeros(1, batch_size, hidden_dim).to(device).detach(),
                    torch.zeros(1, batch_size, hidden_dim).to(device).detach() )

        _, hidden = self.lstm(embeds,hidden0) # ht i ct:  num_layer*num_directions x batch_size x hidden_dim

        lstm_out = torch.cat(hidden,2) # num_layer*num_directions x batch_size x 2*hidden_dim
        lstm_out = lstm_out.reshape((-1,2*self.hidden_dim)) # batch_size x 2*hidden_dim

        txt_embed = self.txt_fcl(lstm_out) # batch_size x tagset_size = vocab_size
        
        # Image
        
        img_embed = self.img_fcl(image)
        
        # Join

        txt_embed = F.normalize(txt_embed)
        img_embed = F.normalize(img_embed)
        
        txt_img_embed = txt_embed*img_embed
        tag_scores = self.classificador(txt_img_embed)
        
        return tag_scores

# %%
# Instancia Model

embedding_dim = 300
hidden_dim = 512
image_dim = 4096 # VGG16
vocab_size = len(word2idx)
tagset_size = 1000
    
modelVQA2015 = VQA2015(embedding_dim, hidden_dim, vocab_size, image_dim,tagset_size)
modelVQA2015 = modelVQA2015.to(device)

loss_function = nn.CrossEntropyLoss(ignore_index=999)
optimizer = optim.Adam(modelVQA2015.parameters(), lr=0.001)

# %%
for i, (imageBatch, questionBatch, answerBatch) in enumerate(train_dataloader):
     break

# %%
start = time.time()

wordIndices = [ torch.tensor(countVec.transform([question]).nonzero()[-1]) for question in questionBatch ]
paddedWordIndices = pad_sequence(wordIndices,batch_first=True,padding_value=vocab_size).long()

questionLengths = torch.tensor([ len(seq) for seq in wordIndices ]).to('cpu')
paddedWordIndices = paddedWordIndices.to(device)
imageBatch = imageBatch.to(device)

tag_scores = modelVQA2015(paddedWordIndices,imageBatch,questionLengths)

targets = torch.tensor([ answer2mfa[answer] for answer in answerBatch ]).to(device)

tag_scores = torch.nn.functional.log_softmax(tag_scores,dim=1)
tag_scores = torch.argmax(tag_scores,dim=1)

hits = (tag_scores == targets) & (tag_scores != 999)

end = time.time()
print(end - start)
# Out:
# 0.22837352752685547

# %%
#torch.argmax(tag_scores,dim=1)
#tag_scores
#[idx2answer[int(ans)] for ans in answerBatch]
#[idx2answer[int(ans)] for ans in targets]
#[idx2answer[int(ans)] for ans in most_freq_answers]
#most_freq_answers
#answerBatch
#[ answer2mfa.index(idx) for idx in targets ]
#targets

# %%
# Funció per evaluar l'accuracy d'un dataset

def VQA2015_model_accuracy(eval_model,eval_dataset,eval_batch_size,eval_countVec,eval_answer2mfa, ignore=999,eval=False):

    eval_dataloader = DataLoader(eval_dataset,batch_size=eval_batch_size)

    count = 0
    total = 0

    eval_L = []

    eval_model.eval()

    with torch.no_grad():

        for i, (eval_imageBatch, eval_questionBatch, eval_answerBatch) in enumerate(eval_dataloader):

            if eval:
                if i % 10 == 0: print('Batch',i)

            # Transofrma
          
            eval_wordIndices = [ torch.tensor(eval_countVec.transform([question]).nonzero()[-1]) for question in eval_questionBatch ]
            eval_paddedWordIndices = pad_sequence(eval_wordIndices,batch_first=True,padding_value=vocab_size).long()
            eval_questionLengths = torch.tensor([ len(seq) for seq in eval_wordIndices ]).to('cpu')
          
            eval_paddedWordIndices = eval_paddedWordIndices.to(device)
            eval_imageBatch = eval_imageBatch.to(device)
          
            eval_targets = torch.tensor([ eval_answer2mfa[answer] for answer in eval_answerBatch ]).to(device)
            
            # Run our forward pass.

            eval_tag_scores = eval_model(eval_paddedWordIndices,eval_imageBatch,eval_questionLengths)

            # Compute Loss
        
            eval_loss = loss_function(eval_tag_scores, eval_targets)
            eval_L.append(float(eval_loss))

            # Compute Accuracy

            eval_tag_scores = torch.nn.functional.log_softmax(eval_tag_scores,dim=1)
            eval_tag_scores = torch.argmax(eval_tag_scores,dim=1)

            eval_hits = (eval_tag_scores == eval_targets) & (eval_tag_scores != ignore)
          
            count += eval_hits.sum().item()
            total += len(eval_answerBatch)

    return count/total, sum(eval_L)/len(eval_L)

# %%
start = time.time()

pretrain_test_accuracy, pretrain_test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
print('\nAccuracy = %5.2f%%' % (pretrain_test_accuracy*100))
print('Loss  = %5.2f' % pretrain_test_loss )

end = time.time()
print(end - start,'seconds')
# Out:
# Accuracy =  0.00%
# Loss  =  6.90
# 0.24744200706481934 seconds

# %%
def compute_batch_accuracy(tag_scores,targets,ignore=999):

  pred = torch.nn.functional.log_softmax(tag_scores,dim=1) 
  pred = torch.argmax(pred,dim=1)
  hits = (pred == targets) & (pred != ignore)
   
  return hits.sum().item()/len(pred)

# %%
# %% Train: basat en el link més algunes modificacions per adaptar-ho al cas

start = time.time()

ignore = 999

L = [] # loss

train_mean_epoch_accuracy = []
test_epoch_accuracy = []
test_epoch_loss = []

num_epochs = 100

for epoch in range(num_epochs):  # again, normally you would NOT do 300 epochs, it is toy data
    
    print('Epoch', epoch)

    modelVQA2015.train()

    hidden = ( torch.zeros(1, batch_size, hidden_dim).to(device),
               torch.zeros(1, batch_size, hidden_dim).to(device) )

    train_batch_accuracy = []

    for i, (imageBatch, questionBatch, answerBatch) in enumerate(train_dataloader):
        
        if i % 20 == 0: print('\tBatch', '%3d' % i, end = ', ')
                    
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        
        optimizer.zero_grad()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.

        wordIndices = [ torch.tensor(countVec.transform([question]).nonzero()[-1]) for question in questionBatch ]
        paddedWordIndices = pad_sequence(wordIndices,batch_first=True,padding_value=vocab_size).long()
        questionLengths = torch.tensor([ len(seq) for seq in wordIndices ]).to('cpu')
        
        paddedWordIndices = paddedWordIndices.to(device)
        imageBatch = imageBatch.to(device)
        
        # Step 3. Run our forward pass.

        tag_scores = modelVQA2015(paddedWordIndices,imageBatch,questionLengths)

        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()        
        
        targets = torch.tensor([ answer2mfa[answer] for answer in answerBatch ]).to(device)
        
        loss = loss_function(tag_scores, targets)
        
        loss.backward()
        optimizer.step()

        # Monitoritza el procés

        batch_accuracy = compute_batch_accuracy(tag_scores,targets)

        train_batch_accuracy.append(batch_accuracy)

        L.append(float(loss))

        if len(L) >= 100:
          rolling_loss = sum(L[-100:])/100
        else:
          rolling_loss = sum(L)/len(L)

        if i % 20 == 0: print('Loss =',round(float(loss),4),', Rolling Mean Loss =',round(rolling_loss,4),', Batch Accuracy =',round(100*batch_accuracy,2))

    train_mean_epoch_accuracy.append( sum(train_batch_accuracy)/len(train_batch_accuracy) )
    print('\tTrain Accuracy (mean) = ',round(100*train_mean_epoch_accuracy[-1],2))

    test_accuracy, test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
    test_epoch_accuracy.append(test_accuracy)
    test_epoch_loss.append(test_loss)
    print('\tTest Accuracy         = ',round(100*test_epoch_accuracy[-1],2))

print('')

print('Final Loss =',round(float(loss),4))
print('Final Rolling Loss =',round(float(rolling_loss),4))

print('')
final_test_accuracy, final_test_loss = VQA2015_model_accuracy(modelVQA2015,test_dataset,batch_size,countVec,answer2mfa)
print('Final Test Accuracy  = %5.2f%%' % (100*final_test_accuracy))

final_train_accuracy, final_train_loss = VQA2015_model_accuracy(modelVQA2015,train_dataset,batch_size,countVec,answer2mfa)
print('Final Train Accuracy = %5.2f%%' % (100*final_train_accuracy))

print('')
end = time.time()
total_time = round(end -start)
print('Running Time =', total_time//60,'min,',total_time % 60, 'sec.')
# Out:
# Epoch 0
# 	Batch   0, Loss = 6.8996 , Rolling Mean Loss = 6.8996 , Batch Accuracy = 0.0
# 	Batch  20, Loss = 3.0616 , Rolling Mean Loss = 3.6932 , Batch Accuracy = 27.75
# 	Batch  40, Loss = 3.0457 , Rolling Mean Loss = 3.395 , Batch Accuracy = 24.25
# 	Batch  60, Loss = 2.8095 , Rolling Mean Loss = 3.2346 , Batch Accuracy = 29.0
# 	Batch  80, Loss = 2.4055 , Rolling Mean Loss = 3.1319 , Batch Accuracy = 31.0
# 	Batch 100, Loss = 2.5733 , Rolling Mean Loss = 2.9964 , Batch Accuracy = 31.5
# 	Batch 120, Loss = 2.3955 , Rolling Mean Loss = 2.8063 , Batch Accuracy = 36.5
# 	Batch 140, Loss = 2.4942 , Rolling Mean Loss = 2.6885 , Batch Accuracy = 35.25
# 	Batch 160, Loss = 2.3978 , Rolling Mean Loss = 2.5963 , Batch Accuracy = 30.5
# 	Batch 180, Loss = 2.3427 , Rolling Mean Loss = 2.5005 , Batch Accuracy = 33.5
# 	Batch 200, Loss = 2.2226 , Rolling Mean Loss = 2.4369 , Batch Accuracy = 35.25
# 	Batch 220, Loss = 2.2821 , Rolling Mean Loss = 2.3699 , Batch Accuracy = 34.25
# 	Train Accuracy (mean) =  31.18
# 	Test Accuracy         =  33.2
# Epoch 1
# 	Batch   0, Loss = 2.3257 , Rolling Mean Loss = 2.3506 , Batch Accuracy = 33.0
# 	Batch  20, Loss = 2.0531 , Rolling Mean Loss = 2.2765 , Batch Accuracy = 40.5
# 	Batch  40, Loss = 2.1163 , Rolling Mean Loss = 2.2264 , Batch Accuracy = 37.5
# 	Batch  60, Loss = 1.8981 , Rolling Mean Loss = 2.1697 , Batch Accuracy = 44.0
# 	Batch  80, Loss = 1.9805 , Rolling Mean Loss = 2.1297 , Batch Accuracy = 39.75
# 	Batch 100, Loss = 1.8651 , Rolling Mean Loss = 2.0784 , Batch Accuracy = 41.0
# 	Batch 120, Loss = 2.0037 , Rolling Mean Loss = 2.0656 , Batch Accuracy = 36.25
# 	Batch 140, Loss = 2.0654 , Rolling Mean Loss = 2.0447 , Batch Accuracy = 38.75
# 	Batch 160, Loss = 2.1323 , Rolling Mean Loss = 2.0313 , Batch Accuracy = 36.75
# 	Batch 180, Loss = 1.9694 , Rolling Mean Loss = 1.9988 , Batch Accuracy = 35.25
# 	Batch 200, Loss = 1.885 , Rolling Mean Loss = 1.9883 , Batch Accuracy = 38.75
# 	Batch 220, Loss = 1.6225 , Rolling Mean Loss = 1.9586 , Batch Accuracy = 44.25
# 	Train Accuracy (mean) =  38.09
# 	Test Accuracy         =  37.0
# Epoch 2
# 	Batch   0, Loss = 1.8171 , Rolling Mean Loss = 1.952 , Batch Accuracy = 43.5
# 	Batch  20, Loss = 1.8071 , Rolling Mean Loss = 1.8918 , Batch Accuracy = 40.0
# 	Batch  40, Loss = 1.8393 , Rolling Mean Loss = 1.8418 , Batch Accuracy = 37.25
# 	Batch  60, Loss = 2.0083 , Rolling Mean Loss = 1.8053 , Batch Accuracy = 33.25
# 	Batch  80, Loss = 1.6557 , Rolling Mean Loss = 1.7664 , Batch Accuracy = 44.75
# 	Batch 100, Loss = 1.6967 , Rolling Mean Loss = 1.722 , Batch Accuracy = 42.5
# 	Batch 120, Loss = 1.7591 , Rolling Mean Loss = 1.7305 , Batch Accuracy = 40.0
# 	Batch 140, Loss = 1.7747 , Rolling Mean Loss = 1.7359 , Batch Accuracy = 44.5
# 	Batch 160, Loss = 1.6121 , Rolling Mean Loss = 1.7238 , Batch Accuracy = 44.25
# 	Batch 180, Loss = 1.5226 , Rolling Mean Loss = 1.7304 , Batch Accuracy = 44.0
# 	Batch 200, Loss = 1.6559 , Rolling Mean Loss = 1.7355 , Batch Accuracy = 44.75
# 	Batch 220, Loss = 1.8467 , Rolling Mean Loss = 1.7247 , Batch Accuracy = 43.0
# 	Train Accuracy (mean) =  42.49
# 	Test Accuracy         =  39.3
# Epoch 3
# 	Batch   0, Loss = 1.5475 , Rolling Mean Loss = 1.7236 , Batch Accuracy = 46.0
# 	Batch  20, Loss = 1.6207 , Rolling Mean Loss = 1.6759 , Batch Accuracy = 46.5
# 	Batch  40, Loss = 1.5602 , Rolling Mean Loss = 1.6297 , Batch Accuracy = 46.5
# 	Batch  60, Loss = 1.565 , Rolling Mean Loss = 1.5818 , Batch Accuracy = 46.25
# 	Batch  80, Loss = 1.5065 , Rolling Mean Loss = 1.5477 , Batch Accuracy = 47.5
# 	Batch 100, Loss = 1.5245 , Rolling Mean Loss = 1.5028 , Batch Accuracy = 46.5
# 	Batch 120, Loss = 1.3987 , Rolling Mean Loss = 1.5038 , Batch Accuracy = 48.0
# 	Batch 140, Loss = 1.5191 , Rolling Mean Loss = 1.5069 , Batch Accuracy = 46.75
# 	Batch 160, Loss = 1.583 , Rolling Mean Loss = 1.5094 , Batch Accuracy = 46.75
# 	Batch 180, Loss = 1.5699 , Rolling Mean Loss = 1.5135 , Batch Accuracy = 43.25
# 	Batch 200, Loss = 1.5291 , Rolling Mean Loss = 1.5235 , Batch Accuracy = 46.75
# 	Batch 220, Loss = 1.5394 , Rolling Mean Loss = 1.5285 , Batch Accuracy = 44.75
# 	Train Accuracy (mean) =  45.99
# 	Test Accuracy         =  40.5
# Epoch 4
# 	Batch   0, Loss = 1.226 , Rolling Mean Loss = 1.5282 , Batch Accuracy = 54.5
# 	Batch  20, Loss = 1.2149 , Rolling Mean Loss = 1.474 , Batch Accuracy = 52.0
# 	Batch  40, Loss = 1.4342 , Rolling Mean Loss = 1.4295 , Batch Accuracy = 49.0
# 	Batch  60, Loss = 1.3411 , Rolling Mean Loss = 1.3797 , Batch Accuracy = 49.25
# 	Batch  80, Loss = 1.2266 , Rolling Mean Loss = 1.3408 , Batch Accuracy = 51.5
# 	Batch 100, Loss = 1.2431 , Rolling Mean Loss = 1.2989 , Batch Accuracy = 52.5
# 	Batch 120, Loss = 1.4438 , Rolling Mean Loss = 1.3097 , Batch Accuracy = 50.0
# 	Batch 140, Loss = 1.4094 , Rolling Mean Loss = 1.3216 , Batch Accuracy = 46.0
# 	Batch 160, Loss = 1.3143 , Rolling Mean Loss = 1.3278 , Batch Accuracy = 52.25
# 	Batch 180, Loss = 1.2498 , Rolling Mean Loss = 1.3386 , Batch Accuracy = 49.25
# 	Batch 200, Loss = 1.3427 , Rolling Mean Loss = 1.349 , Batch Accuracy = 52.0
# 	Batch 220, Loss = 1.2468 , Rolling Mean Loss = 1.3524 , Batch Accuracy = 51.5
# 	Train Accuracy (mean) =  49.82
# 	Test Accuracy         =  40.5
# Epoch 5
# 	Batch   0, Loss = 1.0835 , Rolling Mean Loss = 1.3569 , Batch Accuracy = 53.75
# 	Batch  20, Loss = 1.0273 , Rolling Mean Loss = 1.2968 , Batch Accuracy = 55.25
# 	Batch  40, Loss = 1.0342 , Rolling Mean Loss = 1.2389 , Batch Accuracy = 55.75
# 	Batch  60, Loss = 1.1408 , Rolling Mean Loss = 1.1874 , Batch Accuracy = 51.75
# 	Batch  80, Loss = 1.2296 , Rolling Mean Loss = 1.1383 , Batch Accuracy = 53.0
# 	Batch 100, Loss = 1.2152 , Rolling Mean Loss = 1.0935 , Batch Accuracy = 53.5
# 	Batch 120, Loss = 1.2114 , Rolling Mean Loss = 1.1189 , Batch Accuracy = 54.0
# 	Batch 140, Loss = 1.1669 , Rolling Mean Loss = 1.1384 , Batch Accuracy = 52.0
# 	Batch 160, Loss = 1.3153 , Rolling Mean Loss = 1.1582 , Batch Accuracy = 52.75
# 	Batch 180, Loss = 1.2018 , Rolling Mean Loss = 1.1762 , Batch Accuracy = 52.0
# 	Batch 200, Loss = 1.1087 , Rolling Mean Loss = 1.1856 , Batch Accuracy = 55.5
# 	Batch 220, Loss = 1.2032 , Rolling Mean Loss = 1.1835 , Batch Accuracy = 53.75
# 	Train Accuracy (mean) =  53.96
# 	Test Accuracy         =  41.6
# Epoch 6
# 	Batch   0, Loss = 0.8871 , Rolling Mean Loss = 1.1849 , Batch Accuracy = 63.25
# 	Batch  20, Loss = 0.9263 , Rolling Mean Loss = 1.1355 , Batch Accuracy = 60.0
# 	Batch  40, Loss = 0.9499 , Rolling Mean Loss = 1.0716 , Batch Accuracy = 60.5
# 	Batch  60, Loss = 0.9211 , Rolling Mean Loss = 1.0108 , Batch Accuracy = 59.75
# 	Batch  80, Loss = 0.953 , Rolling Mean Loss = 0.9506 , Batch Accuracy = 58.0
# 	Batch 100, Loss = 0.9027 , Rolling Mean Loss = 0.9081 , Batch Accuracy = 60.5
# 	Batch 120, Loss = 0.9597 , Rolling Mean Loss = 0.9198 , Batch Accuracy = 56.25
# 	Batch 140, Loss = 0.8593 , Rolling Mean Loss = 0.9392 , Batch Accuracy = 60.5
# 	Batch 160, Loss = 1.0997 , Rolling Mean Loss = 0.9552 , Batch Accuracy = 54.75
# 	Batch 180, Loss = 0.9683 , Rolling Mean Loss = 0.976 , Batch Accuracy = 61.5
# 	Batch 200, Loss = 0.9714 , Rolling Mean Loss = 0.9847 , Batch Accuracy = 58.5
# 	Batch 220, Loss = 1.0184 , Rolling Mean Loss = 0.9975 , Batch Accuracy = 58.5
# 	Train Accuracy (mean) =  59.07
# 	Test Accuracy         =  41.2
# Epoch 7
# 	Batch   0, Loss = 0.834 , Rolling Mean Loss = 0.9965 , Batch Accuracy = 65.0
# 	Batch  20, Loss = 0.6369 , Rolling Mean Loss = 0.9488 , Batch Accuracy = 70.0
# 	Batch  40, Loss = 0.7348 , Rolling Mean Loss = 0.8886 , Batch Accuracy = 66.0
# 	Batch  60, Loss = 0.7807 , Rolling Mean Loss = 0.8324 , Batch Accuracy = 59.5
# 	Batch  80, Loss = 0.7871 , Rolling Mean Loss = 0.7688 , Batch Accuracy = 66.5
# 	Batch 100, Loss = 0.7266 , Rolling Mean Loss = 0.7251 , Batch Accuracy = 66.5
# 	Batch 120, Loss = 0.7685 , Rolling Mean Loss = 0.7395 , Batch Accuracy = 62.25
# 	Batch 140, Loss = 0.6938 , Rolling Mean Loss = 0.7558 , Batch Accuracy = 62.75
# 	Batch 160, Loss = 1.0138 , Rolling Mean Loss = 0.7723 , Batch Accuracy = 58.5
# 	Batch 180, Loss = 0.7686 , Rolling Mean Loss = 0.7974 , Batch Accuracy = 65.5
# 	Batch 200, Loss = 0.9084 , Rolling Mean Loss = 0.812 , Batch Accuracy = 60.75
# 	Batch 220, Loss = 0.883 , Rolling Mean Loss = 0.821 , Batch Accuracy = 59.25
# 	Train Accuracy (mean) =  63.88
# 	Test Accuracy         =  41.9
# Epoch 8
# 	Batch   0, Loss = 0.4893 , Rolling Mean Loss = 0.8218 , Batch Accuracy = 72.5
# 	Batch  20, Loss = 0.5427 , Rolling Mean Loss = 0.7776 , Batch Accuracy = 72.0
# 	Batch  40, Loss = 0.5901 , Rolling Mean Loss = 0.7272 , Batch Accuracy = 68.0
# 	Batch  60, Loss = 0.64 , Rolling Mean Loss = 0.6723 , Batch Accuracy = 67.75
# 	Batch  80, Loss = 0.6237 , Rolling Mean Loss = 0.6248 , Batch Accuracy = 69.25
# 	Batch 100, Loss = 0.4844 , Rolling Mean Loss = 0.578 , Batch Accuracy = 73.0
# 	Batch 120, Loss = 0.6413 , Rolling Mean Loss = 0.5925 , Batch Accuracy = 69.25
# 	Batch 140, Loss = 0.5581 , Rolling Mean Loss = 0.6075 , Batch Accuracy = 69.5
# 	Batch 160, Loss = 0.7214 , Rolling Mean Loss = 0.6185 , Batch Accuracy = 68.0
# 	Batch 180, Loss = 0.5713 , Rolling Mean Loss = 0.6251 , Batch Accuracy = 72.0
# 	Batch 200, Loss = 0.6906 , Rolling Mean Loss = 0.6396 , Batch Accuracy = 68.5
# 	Batch 220, Loss = 0.6554 , Rolling Mean Loss = 0.6511 , Batch Accuracy = 68.5
# 	Train Accuracy (mean) =  68.62
# 	Test Accuracy         =  39.8
# Epoch 9
# 	Batch   0, Loss = 0.4381 , Rolling Mean Loss = 0.6538 , Batch Accuracy = 75.5
# 	Batch  20, Loss = 0.3795 , Rolling Mean Loss = 0.6169 , Batch Accuracy = 77.5
# 	Batch  40, Loss = 0.4512 , Rolling Mean Loss = 0.5801 , Batch Accuracy = 72.5
# 	Batch  60, Loss = 0.3944 , Rolling Mean Loss = 0.5385 , Batch Accuracy = 79.0
# 	Batch  80, Loss = 0.4467 , Rolling Mean Loss = 0.4951 , Batch Accuracy = 74.0
# 	Batch 100, Loss = 0.5589 , Rolling Mean Loss = 0.4608 , Batch Accuracy = 71.75
# 	Batch 120, Loss = 0.4575 , Rolling Mean Loss = 0.4697 , Batch Accuracy = 74.25
# 	Batch 140, Loss = 0.4455 , Rolling Mean Loss = 0.4803 , Batch Accuracy = 72.75
# 	Batch 160, Loss = 0.4354 , Rolling Mean Loss = 0.4931 , Batch Accuracy = 75.75
# 	Batch 180, Loss = 0.6762 , Rolling Mean Loss = 0.5111 , Batch Accuracy = 67.75
# 	Batch 200, Loss = 0.5239 , Rolling Mean Loss = 0.5221 , Batch Accuracy = 71.5
# 	Batch 220, Loss = 0.5497 , Rolling Mean Loss = 0.5294 , Batch Accuracy = 69.75
# 	Train Accuracy (mean) =  72.01
# 	Test Accuracy         =  39.9
# Epoch 10
# 	Batch   0, Loss = 0.3297 , Rolling Mean Loss = 0.5332 , Batch Accuracy = 81.5
# 	Batch  20, Loss = 0.351 , Rolling Mean Loss = 0.5033 , Batch Accuracy = 78.0
# 	Batch  40, Loss = 0.2977 , Rolling Mean Loss = 0.4696 , Batch Accuracy = 79.75
# 	Batch  60, Loss = 0.3621 , Rolling Mean Loss = 0.4307 , Batch Accuracy = 75.75
# 	Batch  80, Loss = 0.4092 , Rolling Mean Loss = 0.3936 , Batch Accuracy = 75.0
# 	Batch 100, Loss = 0.4004 , Rolling Mean Loss = 0.3582 , Batch Accuracy = 74.75
# 	Batch 120, Loss = 0.3631 , Rolling Mean Loss = 0.3665 , Batch Accuracy = 74.25
# 	Batch 140, Loss = 0.4238 , Rolling Mean Loss = 0.3784 , Batch Accuracy = 73.0
# 	Batch 160, Loss = 0.44 , Rolling Mean Loss = 0.3942 , Batch Accuracy = 72.25
# 	Batch 180, Loss = 0.576 , Rolling Mean Loss = 0.4089 , Batch Accuracy = 68.25
# 	Batch 200, Loss = 0.3756 , Rolling Mean Loss = 0.4221 , Batch Accuracy = 74.75
# 	Batch 220, Loss = 0.4608 , Rolling Mean Loss = 0.4376 , Batch Accuracy = 73.75
# 	Train Accuracy (mean) =  74.87
# 	Test Accuracy         =  40.0
# Epoch 11
# 	Batch   0, Loss = 0.295 , Rolling Mean Loss = 0.4383 , Batch Accuracy = 77.0
# 	Batch  20, Loss = 0.2615 , Rolling Mean Loss = 0.4132 , Batch Accuracy = 81.25
# 	Batch  40, Loss = 0.2613 , Rolling Mean Loss = 0.3837 , Batch Accuracy = 75.5
# 	Batch  60, Loss = 0.2838 , Rolling Mean Loss = 0.3508 , Batch Accuracy = 79.0
# 	Batch  80, Loss = 0.2727 , Rolling Mean Loss = 0.3201 , Batch Accuracy = 77.0
# 	Batch 100, Loss = 0.2956 , Rolling Mean Loss = 0.2895 , Batch Accuracy = 80.75
# 	Batch 120, Loss = 0.3052 , Rolling Mean Loss = 0.2946 , Batch Accuracy = 78.75
# 	Batch 140, Loss = 0.3063 , Rolling Mean Loss = 0.3008 , Batch Accuracy = 78.0
# 	Batch 160, Loss = 0.3858 , Rolling Mean Loss = 0.314 , Batch Accuracy = 73.5
# 	Batch 180, Loss = 0.3439 , Rolling Mean Loss = 0.3255 , Batch Accuracy = 77.0
# 	Batch 200, Loss = 0.3076 , Rolling Mean Loss = 0.3345 , Batch Accuracy = 78.25
# 	Batch 220, Loss = 0.4193 , Rolling Mean Loss = 0.345 , Batch Accuracy = 74.0
# 	Train Accuracy (mean) =  77.13
# 	Test Accuracy         =  38.8
# Epoch 12
# 	Batch   0, Loss = 0.2797 , Rolling Mean Loss = 0.349 , Batch Accuracy = 80.0
# 	Batch  20, Loss = 0.2943 , Rolling Mean Loss = 0.3298 , Batch Accuracy = 78.0
# 	Batch  40, Loss = 0.2181 , Rolling Mean Loss = 0.3033 , Batch Accuracy = 79.25
# 	Batch  60, Loss = 0.2506 , Rolling Mean Loss = 0.2758 , Batch Accuracy = 80.0
# 	Batch  80, Loss = 0.265 , Rolling Mean Loss = 0.25 , Batch Accuracy = 79.75
# 	Batch 100, Loss = 0.2453 , Rolling Mean Loss = 0.2207 , Batch Accuracy = 81.25
# 	Batch 120, Loss = 0.2669 , Rolling Mean Loss = 0.2223 , Batch Accuracy = 75.25
# 	Batch 140, Loss = 0.2308 , Rolling Mean Loss = 0.2361 , Batch Accuracy = 80.75
# 	Batch 160, Loss = 0.219 , Rolling Mean Loss = 0.2452 , Batch Accuracy = 81.75
# 	Batch 180, Loss = 0.2945 , Rolling Mean Loss = 0.2543 , Batch Accuracy = 75.75
# 	Batch 200, Loss = 0.2632 , Rolling Mean Loss = 0.2752 , Batch Accuracy = 78.5
# 	Batch 220, Loss = 0.2408 , Rolling Mean Loss = 0.2884 , Batch Accuracy = 78.75
# 	Train Accuracy (mean) =  79.02
# 	Test Accuracy         =  39.5
# Epoch 13
# 	Batch   0, Loss = 0.1888 , Rolling Mean Loss = 0.2897 , Batch Accuracy = 81.25
# 	Batch  20, Loss = 0.3463 , Rolling Mean Loss = 0.2764 , Batch Accuracy = 77.25
# 	Batch  40, Loss = 0.1972 , Rolling Mean Loss = 0.2593 , Batch Accuracy = 82.75
# 	Batch  60, Loss = 0.2146 , Rolling Mean Loss = 0.2359 , Batch Accuracy = 78.25
# 	Batch  80, Loss = 0.2063 , Rolling Mean Loss = 0.2091 , Batch Accuracy = 79.5
# 	Batch 100, Loss = 0.167 , Rolling Mean Loss = 0.1869 , Batch Accuracy = 83.0
# 	Batch 120, Loss = 0.2513 , Rolling Mean Loss = 0.1893 , Batch Accuracy = 80.25
# 	Batch 140, Loss = 0.2116 , Rolling Mean Loss = 0.1913 , Batch Accuracy = 84.0
# 	Batch 160, Loss = 0.2332 , Rolling Mean Loss = 0.1979 , Batch Accuracy = 79.25
# 	Batch 180, Loss = 0.1951 , Rolling Mean Loss = 0.2073 , Batch Accuracy = 79.75
# 	Batch 200, Loss = 0.2333 , Rolling Mean Loss = 0.2155 , Batch Accuracy = 78.25
# 	Batch 220, Loss = 0.2834 , Rolling Mean Loss = 0.2219 , Batch Accuracy = 80.25
# 	Train Accuracy (mean) =  80.46
# 	Test Accuracy         =  38.8
# Epoch 14
# 	Batch   0, Loss = 0.1726 , Rolling Mean Loss = 0.2259 , Batch Accuracy = 84.25
# 	Batch  20, Loss = 0.167 , Rolling Mean Loss = 0.2158 , Batch Accuracy = 80.75
# 	Batch  40, Loss = 0.1604 , Rolling Mean Loss = 0.2067 , Batch Accuracy = 80.5
# 	Batch  60, Loss = 0.1504 , Rolling Mean Loss = 0.1888 , Batch Accuracy = 82.0
# 	Batch  80, Loss = 0.1598 , Rolling Mean Loss = 0.1698 , Batch Accuracy = 78.75
# 	Batch 100, Loss = 0.1624 , Rolling Mean Loss = 0.158 , Batch Accuracy = 80.25
# 	Batch 120, Loss = 0.1808 , Rolling Mean Loss = 0.1625 , Batch Accuracy = 79.25
# 	Batch 140, Loss = 0.1958 , Rolling Mean Loss = 0.1665 , Batch Accuracy = 79.0
# 	Batch 160, Loss = 0.2008 , Rolling Mean Loss = 0.1749 , Batch Accuracy = 79.75
# 	Batch 180, Loss = 0.141 , Rolling Mean Loss = 0.1833 , Batch Accuracy = 82.0
# 	Batch 200, Loss = 0.2427 , Rolling Mean Loss = 0.1892 , Batch Accuracy = 77.5
# 	Batch 220, Loss = 0.2953 , Rolling Mean Loss = 0.1977 , Batch Accuracy = 73.5
# 	Train Accuracy (mean) =  81.17
# 	Test Accuracy         =  38.2
# Epoch 15
# 	Batch   0, Loss = 0.1395 , Rolling Mean Loss = 0.2022 , Batch Accuracy = 83.0
# 	Batch  20, Loss = 0.1253 , Rolling Mean Loss = 0.1928 , Batch Accuracy = 83.25
# 	Batch  40, Loss = 0.1142 , Rolling Mean Loss = 0.182 , Batch Accuracy = 82.0
# 	Batch  60, Loss = 0.1238 , Rolling Mean Loss = 0.1696 , Batch Accuracy = 80.25
# 	Batch  80, Loss = 0.128 , Rolling Mean Loss = 0.1537 , Batch Accuracy = 83.75
# 	Batch 100, Loss = 0.1502 , Rolling Mean Loss = 0.1376 , Batch Accuracy = 84.75
# 	Batch 120, Loss = 0.2379 , Rolling Mean Loss = 0.1398 , Batch Accuracy = 79.5
# 	Batch 140, Loss = 0.1825 , Rolling Mean Loss = 0.1409 , Batch Accuracy = 81.0
# 	Batch 160, Loss = 0.1919 , Rolling Mean Loss = 0.1467 , Batch Accuracy = 81.25
# 	Batch 180, Loss = 0.2013 , Rolling Mean Loss = 0.1571 , Batch Accuracy = 82.0
# 	Batch 200, Loss = 0.1701 , Rolling Mean Loss = 0.1659 , Batch Accuracy = 80.25
# 	Batch 220, Loss = 0.1682 , Rolling Mean Loss = 0.1748 , Batch Accuracy = 81.25
# 	Train Accuracy (mean) =  81.92
# 	Test Accuracy         =  40.2
# Epoch 16
# 	Batch   0, Loss = 0.1246 , Rolling Mean Loss = 0.1779 , Batch Accuracy = 83.0
# 	Batch  20, Loss = 0.1696 , Rolling Mean Loss = 0.1745 , Batch Accuracy = 81.0
# 	Batch  40, Loss = 0.1145 , Rolling Mean Loss = 0.1658 , Batch Accuracy = 83.25
# 	Batch  60, Loss = 0.1052 , Rolling Mean Loss = 0.1533 , Batch Accuracy = 86.25
# 	Batch  80, Loss = 0.1146 , Rolling Mean Loss = 0.1384 , Batch Accuracy = 80.25
# 	Batch 100, Loss = 0.1539 , Rolling Mean Loss = 0.1252 , Batch Accuracy = 82.75
# 	Batch 120, Loss = 0.1999 , Rolling Mean Loss = 0.1261 , Batch Accuracy = 81.25
# 	Batch 140, Loss = 0.2194 , Rolling Mean Loss = 0.1307 , Batch Accuracy = 80.75
# 	Batch 160, Loss = 0.1663 , Rolling Mean Loss = 0.1335 , Batch Accuracy = 82.5
# 	Batch 180, Loss = 0.1089 , Rolling Mean Loss = 0.1387 , Batch Accuracy = 80.5
# 	Batch 200, Loss = 0.2179 , Rolling Mean Loss = 0.1475 , Batch Accuracy = 81.0
# 	Batch 220, Loss = 0.1519 , Rolling Mean Loss = 0.1533 , Batch Accuracy = 82.0
# 	Train Accuracy (mean) =  82.39
# 	Test Accuracy         =  38.9
# Epoch 17
# 	Batch   0, Loss = 0.0886 , Rolling Mean Loss = 0.1544 , Batch Accuracy = 85.0
# 	Batch  20, Loss = 0.0913 , Rolling Mean Loss = 0.1472 , Batch Accuracy = 85.0
# 	Batch  40, Loss = 0.1498 , Rolling Mean Loss = 0.1387 , Batch Accuracy = 84.75
# 	Batch  60, Loss = 0.0707 , Rolling Mean Loss = 0.1277 , Batch Accuracy = 85.0
# 	Batch  80, Loss = 0.081 , Rolling Mean Loss = 0.1169 , Batch Accuracy = 83.25
# 	Batch 100, Loss = 0.0971 , Rolling Mean Loss = 0.1119 , Batch Accuracy = 86.0
# 	Batch 120, Loss = 0.1239 , Rolling Mean Loss = 0.1149 , Batch Accuracy = 81.75
# 	Batch 140, Loss = 0.1352 , Rolling Mean Loss = 0.1169 , Batch Accuracy = 84.5
# 	Batch 160, Loss = 0.1203 , Rolling Mean Loss = 0.1194 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.1459 , Rolling Mean Loss = 0.1261 , Batch Accuracy = 80.25
# 	Batch 200, Loss = 0.1456 , Rolling Mean Loss = 0.1262 , Batch Accuracy = 80.25
# 	Batch 220, Loss = 0.2078 , Rolling Mean Loss = 0.1337 , Batch Accuracy = 79.25
# 	Train Accuracy (mean) =  82.78
# 	Test Accuracy         =  38.1
# Epoch 18
# 	Batch   0, Loss = 0.1416 , Rolling Mean Loss = 0.1358 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.093 , Rolling Mean Loss = 0.13 , Batch Accuracy = 83.75
# 	Batch  40, Loss = 0.0694 , Rolling Mean Loss = 0.1242 , Batch Accuracy = 87.5
# 	Batch  60, Loss = 0.0953 , Rolling Mean Loss = 0.1154 , Batch Accuracy = 83.5
# 	Batch  80, Loss = 0.104 , Rolling Mean Loss = 0.1091 , Batch Accuracy = 83.75
# 	Batch 100, Loss = 0.0793 , Rolling Mean Loss = 0.0986 , Batch Accuracy = 84.0
# 	Batch 120, Loss = 0.1104 , Rolling Mean Loss = 0.1004 , Batch Accuracy = 81.75
# 	Batch 140, Loss = 0.1538 , Rolling Mean Loss = 0.1034 , Batch Accuracy = 80.75
# 	Batch 160, Loss = 0.1165 , Rolling Mean Loss = 0.1076 , Batch Accuracy = 78.75
# 	Batch 180, Loss = 0.1656 , Rolling Mean Loss = 0.1101 , Batch Accuracy = 81.5
# 	Batch 200, Loss = 0.1393 , Rolling Mean Loss = 0.1162 , Batch Accuracy = 81.5
# 	Batch 220, Loss = 0.0976 , Rolling Mean Loss = 0.1263 , Batch Accuracy = 82.0
# 	Train Accuracy (mean) =  83.15
# 	Test Accuracy         =  39.0
# Epoch 19
# 	Batch   0, Loss = 0.0729 , Rolling Mean Loss = 0.1292 , Batch Accuracy = 87.25
# 	Batch  20, Loss = 0.0941 , Rolling Mean Loss = 0.1236 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.085 , Rolling Mean Loss = 0.1187 , Batch Accuracy = 84.25
# 	Batch  60, Loss = 0.1156 , Rolling Mean Loss = 0.1104 , Batch Accuracy = 82.0
# 	Batch  80, Loss = 0.0523 , Rolling Mean Loss = 0.1027 , Batch Accuracy = 83.5
# 	Batch 100, Loss = 0.1054 , Rolling Mean Loss = 0.0914 , Batch Accuracy = 82.5
# 	Batch 120, Loss = 0.074 , Rolling Mean Loss = 0.0918 , Batch Accuracy = 83.5
# 	Batch 140, Loss = 0.08 , Rolling Mean Loss = 0.0929 , Batch Accuracy = 84.0
# 	Batch 160, Loss = 0.1086 , Rolling Mean Loss = 0.0972 , Batch Accuracy = 82.5
# 	Batch 180, Loss = 0.1156 , Rolling Mean Loss = 0.1046 , Batch Accuracy = 81.25
# 	Batch 200, Loss = 0.1446 , Rolling Mean Loss = 0.113 , Batch Accuracy = 80.5
# 	Batch 220, Loss = 0.1377 , Rolling Mean Loss = 0.1238 , Batch Accuracy = 84.5
# 	Train Accuracy (mean) =  83.28
# 	Test Accuracy         =  38.2
# Epoch 20
# 	Batch   0, Loss = 0.0527 , Rolling Mean Loss = 0.1264 , Batch Accuracy = 88.25
# 	Batch  20, Loss = 0.0868 , Rolling Mean Loss = 0.1244 , Batch Accuracy = 84.25
# 	Batch  40, Loss = 0.107 , Rolling Mean Loss = 0.1199 , Batch Accuracy = 82.75
# 	Batch  60, Loss = 0.0627 , Rolling Mean Loss = 0.1078 , Batch Accuracy = 86.5
# 	Batch  80, Loss = 0.0884 , Rolling Mean Loss = 0.1 , Batch Accuracy = 84.0
# 	Batch 100, Loss = 0.1026 , Rolling Mean Loss = 0.0898 , Batch Accuracy = 84.0
# 	Batch 120, Loss = 0.0973 , Rolling Mean Loss = 0.0887 , Batch Accuracy = 83.75
# 	Batch 140, Loss = 0.1074 , Rolling Mean Loss = 0.0885 , Batch Accuracy = 83.75
# 	Batch 160, Loss = 0.0976 , Rolling Mean Loss = 0.095 , Batch Accuracy = 83.0
# 	Batch 180, Loss = 0.0715 , Rolling Mean Loss = 0.0972 , Batch Accuracy = 82.25
# 	Batch 200, Loss = 0.1359 , Rolling Mean Loss = 0.1035 , Batch Accuracy = 81.75
# 	Batch 220, Loss = 0.1422 , Rolling Mean Loss = 0.1111 , Batch Accuracy = 82.0
# 	Train Accuracy (mean) =  83.47
# 	Test Accuracy         =  39.6
# Epoch 21
# 	Batch   0, Loss = 0.1534 , Rolling Mean Loss = 0.1136 , Batch Accuracy = 82.75
# 	Batch  20, Loss = 0.0829 , Rolling Mean Loss = 0.1108 , Batch Accuracy = 83.75
# 	Batch  40, Loss = 0.0646 , Rolling Mean Loss = 0.1066 , Batch Accuracy = 83.0
# 	Batch  60, Loss = 0.0693 , Rolling Mean Loss = 0.1017 , Batch Accuracy = 84.25
# 	Batch  80, Loss = 0.0737 , Rolling Mean Loss = 0.0918 , Batch Accuracy = 84.0
# 	Batch 100, Loss = 0.1137 , Rolling Mean Loss = 0.0838 , Batch Accuracy = 83.25
# 	Batch 120, Loss = 0.1229 , Rolling Mean Loss = 0.0825 , Batch Accuracy = 85.0
# 	Batch 140, Loss = 0.0935 , Rolling Mean Loss = 0.0844 , Batch Accuracy = 82.75
# 	Batch 160, Loss = 0.0993 , Rolling Mean Loss = 0.085 , Batch Accuracy = 83.75
# 	Batch 180, Loss = 0.1326 , Rolling Mean Loss = 0.0914 , Batch Accuracy = 84.5
# 	Batch 200, Loss = 0.1036 , Rolling Mean Loss = 0.0947 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0613 , Rolling Mean Loss = 0.099 , Batch Accuracy = 83.75
# 	Train Accuracy (mean) =  83.7
# 	Test Accuracy         =  38.5
# Epoch 22
# 	Batch   0, Loss = 0.0612 , Rolling Mean Loss = 0.1009 , Batch Accuracy = 85.5
# 	Batch  20, Loss = 0.037 , Rolling Mean Loss = 0.0943 , Batch Accuracy = 83.5
# 	Batch  40, Loss = 0.066 , Rolling Mean Loss = 0.0907 , Batch Accuracy = 86.0
# 	Batch  60, Loss = 0.0377 , Rolling Mean Loss = 0.084 , Batch Accuracy = 85.0
# 	Batch  80, Loss = 0.0833 , Rolling Mean Loss = 0.0774 , Batch Accuracy = 86.5
# 	Batch 100, Loss = 0.065 , Rolling Mean Loss = 0.0724 , Batch Accuracy = 86.75
# 	Batch 120, Loss = 0.0636 , Rolling Mean Loss = 0.0737 , Batch Accuracy = 83.75
# 	Batch 140, Loss = 0.0646 , Rolling Mean Loss = 0.0754 , Batch Accuracy = 79.75
# 	Batch 160, Loss = 0.1589 , Rolling Mean Loss = 0.0773 , Batch Accuracy = 82.75
# 	Batch 180, Loss = 0.0901 , Rolling Mean Loss = 0.0808 , Batch Accuracy = 84.75
# 	Batch 200, Loss = 0.0876 , Rolling Mean Loss = 0.0855 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0948 , Rolling Mean Loss = 0.0923 , Batch Accuracy = 86.25
# 	Train Accuracy (mean) =  84.01
# 	Test Accuracy         =  38.9
# Epoch 23
# 	Batch   0, Loss = 0.0342 , Rolling Mean Loss = 0.0945 , Batch Accuracy = 85.25
# 	Batch  20, Loss = 0.096 , Rolling Mean Loss = 0.0922 , Batch Accuracy = 81.0
# 	Batch  40, Loss = 0.0494 , Rolling Mean Loss = 0.0878 , Batch Accuracy = 86.5
# 	Batch  60, Loss = 0.0481 , Rolling Mean Loss = 0.0819 , Batch Accuracy = 82.25
# 	Batch  80, Loss = 0.0798 , Rolling Mean Loss = 0.0762 , Batch Accuracy = 82.25
# 	Batch 100, Loss = 0.0468 , Rolling Mean Loss = 0.067 , Batch Accuracy = 85.25
# 	Batch 120, Loss = 0.0943 , Rolling Mean Loss = 0.0666 , Batch Accuracy = 84.5
# 	Batch 140, Loss = 0.069 , Rolling Mean Loss = 0.0681 , Batch Accuracy = 84.25
# 	Batch 160, Loss = 0.0973 , Rolling Mean Loss = 0.0699 , Batch Accuracy = 85.25
# 	Batch 180, Loss = 0.0822 , Rolling Mean Loss = 0.0742 , Batch Accuracy = 81.25
# 	Batch 200, Loss = 0.0921 , Rolling Mean Loss = 0.0785 , Batch Accuracy = 83.25
# 	Batch 220, Loss = 0.0494 , Rolling Mean Loss = 0.083 , Batch Accuracy = 81.25
# 	Train Accuracy (mean) =  84.17
# 	Test Accuracy         =  38.5
# Epoch 24
# 	Batch   0, Loss = 0.0583 , Rolling Mean Loss = 0.0855 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.1035 , Rolling Mean Loss = 0.0847 , Batch Accuracy = 87.75
# 	Batch  40, Loss = 0.0599 , Rolling Mean Loss = 0.0822 , Batch Accuracy = 85.75
# 	Batch  60, Loss = 0.0423 , Rolling Mean Loss = 0.0775 , Batch Accuracy = 85.0
# 	Batch  80, Loss = 0.0348 , Rolling Mean Loss = 0.0733 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0997 , Rolling Mean Loss = 0.0677 , Batch Accuracy = 86.75
# 	Batch 120, Loss = 0.0479 , Rolling Mean Loss = 0.0663 , Batch Accuracy = 83.5
# 	Batch 140, Loss = 0.0852 , Rolling Mean Loss = 0.0679 , Batch Accuracy = 84.5
# 	Batch 160, Loss = 0.0779 , Rolling Mean Loss = 0.0694 , Batch Accuracy = 83.25
# 	Batch 180, Loss = 0.0852 , Rolling Mean Loss = 0.0723 , Batch Accuracy = 82.25
# 	Batch 200, Loss = 0.0687 , Rolling Mean Loss = 0.0747 , Batch Accuracy = 87.5
# 	Batch 220, Loss = 0.1057 , Rolling Mean Loss = 0.0805 , Batch Accuracy = 83.25
# 	Train Accuracy (mean) =  84.28
# 	Test Accuracy         =  38.5
# Epoch 25
# 	Batch   0, Loss = 0.0771 , Rolling Mean Loss = 0.0809 , Batch Accuracy = 84.0
# 	Batch  20, Loss = 0.049 , Rolling Mean Loss = 0.0785 , Batch Accuracy = 84.0
# 	Batch  40, Loss = 0.0768 , Rolling Mean Loss = 0.0761 , Batch Accuracy = 84.75
# 	Batch  60, Loss = 0.0677 , Rolling Mean Loss = 0.0722 , Batch Accuracy = 84.75
# 	Batch  80, Loss = 0.0232 , Rolling Mean Loss = 0.0662 , Batch Accuracy = 88.0
# 	Batch 100, Loss = 0.0631 , Rolling Mean Loss = 0.0608 , Batch Accuracy = 83.25
# 	Batch 120, Loss = 0.0494 , Rolling Mean Loss = 0.0612 , Batch Accuracy = 83.25
# 	Batch 140, Loss = 0.0724 , Rolling Mean Loss = 0.0644 , Batch Accuracy = 84.75
# 	Batch 160, Loss = 0.0447 , Rolling Mean Loss = 0.068 , Batch Accuracy = 85.0
# 	Batch 180, Loss = 0.0961 , Rolling Mean Loss = 0.0748 , Batch Accuracy = 81.0
# 	Batch 200, Loss = 0.0906 , Rolling Mean Loss = 0.0794 , Batch Accuracy = 84.0
# 	Batch 220, Loss = 0.0677 , Rolling Mean Loss = 0.0839 , Batch Accuracy = 85.5
# 	Train Accuracy (mean) =  84.3
# 	Test Accuracy         =  40.4
# Epoch 26
# 	Batch   0, Loss = 0.0791 , Rolling Mean Loss = 0.0857 , Batch Accuracy = 84.75
# 	Batch  20, Loss = 0.0607 , Rolling Mean Loss = 0.0822 , Batch Accuracy = 82.0
# 	Batch  40, Loss = 0.0691 , Rolling Mean Loss = 0.0778 , Batch Accuracy = 84.0
# 	Batch  60, Loss = 0.0822 , Rolling Mean Loss = 0.0727 , Batch Accuracy = 86.25
# 	Batch  80, Loss = 0.0807 , Rolling Mean Loss = 0.0696 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0508 , Rolling Mean Loss = 0.0648 , Batch Accuracy = 86.75
# 	Batch 120, Loss = 0.0847 , Rolling Mean Loss = 0.0661 , Batch Accuracy = 86.0
# 	Batch 140, Loss = 0.0889 , Rolling Mean Loss = 0.07 , Batch Accuracy = 83.75
# 	Batch 160, Loss = 0.0732 , Rolling Mean Loss = 0.0725 , Batch Accuracy = 84.5
# 	Batch 180, Loss = 0.0752 , Rolling Mean Loss = 0.0747 , Batch Accuracy = 83.25
# 	Batch 200, Loss = 0.0816 , Rolling Mean Loss = 0.0796 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.1125 , Rolling Mean Loss = 0.0851 , Batch Accuracy = 82.25
# 	Train Accuracy (mean) =  84.1
# 	Test Accuracy         =  39.0
# Epoch 27
# 	Batch   0, Loss = 0.0591 , Rolling Mean Loss = 0.0887 , Batch Accuracy = 90.25
# 	Batch  20, Loss = 0.0469 , Rolling Mean Loss = 0.0859 , Batch Accuracy = 87.25
# 	Batch  40, Loss = 0.0606 , Rolling Mean Loss = 0.0839 , Batch Accuracy = 87.25
# 	Batch  60, Loss = 0.0858 , Rolling Mean Loss = 0.0806 , Batch Accuracy = 83.25
# 	Batch  80, Loss = 0.0633 , Rolling Mean Loss = 0.0726 , Batch Accuracy = 84.25
# 	Batch 100, Loss = 0.1054 , Rolling Mean Loss = 0.0655 , Batch Accuracy = 82.75
# 	Batch 120, Loss = 0.0941 , Rolling Mean Loss = 0.0664 , Batch Accuracy = 84.5
# 	Batch 140, Loss = 0.0965 , Rolling Mean Loss = 0.0666 , Batch Accuracy = 83.0
# 	Batch 160, Loss = 0.0896 , Rolling Mean Loss = 0.069 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0812 , Rolling Mean Loss = 0.0708 , Batch Accuracy = 83.5
# 	Batch 200, Loss = 0.0712 , Rolling Mean Loss = 0.0744 , Batch Accuracy = 83.0
# 	Batch 220, Loss = 0.0922 , Rolling Mean Loss = 0.0806 , Batch Accuracy = 81.5
# 	Train Accuracy (mean) =  84.23
# 	Test Accuracy         =  39.5
# Epoch 28
# 	Batch   0, Loss = 0.0658 , Rolling Mean Loss = 0.082 , Batch Accuracy = 82.75
# 	Batch  20, Loss = 0.0626 , Rolling Mean Loss = 0.0787 , Batch Accuracy = 85.25
# 	Batch  40, Loss = 0.0232 , Rolling Mean Loss = 0.0731 , Batch Accuracy = 85.25
# 	Batch  60, Loss = 0.0724 , Rolling Mean Loss = 0.0689 , Batch Accuracy = 85.75
# 	Batch  80, Loss = 0.0885 , Rolling Mean Loss = 0.0636 , Batch Accuracy = 85.5
# 	Batch 100, Loss = 0.0681 , Rolling Mean Loss = 0.0554 , Batch Accuracy = 83.5
# 	Batch 120, Loss = 0.0857 , Rolling Mean Loss = 0.0552 , Batch Accuracy = 80.25
# 	Batch 140, Loss = 0.0708 , Rolling Mean Loss = 0.0573 , Batch Accuracy = 84.75
# 	Batch 160, Loss = 0.0424 , Rolling Mean Loss = 0.0588 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0572 , Rolling Mean Loss = 0.0646 , Batch Accuracy = 86.25
# 	Batch 200, Loss = 0.0618 , Rolling Mean Loss = 0.0714 , Batch Accuracy = 85.0
# 	Batch 220, Loss = 0.1237 , Rolling Mean Loss = 0.0795 , Batch Accuracy = 83.25
# 	Train Accuracy (mean) =  84.49
# 	Test Accuracy         =  39.4
# Epoch 29
# 	Batch   0, Loss = 0.0887 , Rolling Mean Loss = 0.0821 , Batch Accuracy = 84.25
# 	Batch  20, Loss = 0.1571 , Rolling Mean Loss = 0.082 , Batch Accuracy = 83.25
# 	Batch  40, Loss = 0.0521 , Rolling Mean Loss = 0.0785 , Batch Accuracy = 82.75
# 	Batch  60, Loss = 0.056 , Rolling Mean Loss = 0.0718 , Batch Accuracy = 83.25
# 	Batch  80, Loss = 0.0626 , Rolling Mean Loss = 0.0626 , Batch Accuracy = 85.25
# 	Batch 100, Loss = 0.028 , Rolling Mean Loss = 0.0565 , Batch Accuracy = 84.25
# 	Batch 120, Loss = 0.0656 , Rolling Mean Loss = 0.055 , Batch Accuracy = 86.0
# 	Batch 140, Loss = 0.0537 , Rolling Mean Loss = 0.0559 , Batch Accuracy = 84.0
# 	Batch 160, Loss = 0.0599 , Rolling Mean Loss = 0.0579 , Batch Accuracy = 84.25
# 	Batch 180, Loss = 0.0615 , Rolling Mean Loss = 0.0599 , Batch Accuracy = 83.75
# 	Batch 200, Loss = 0.0417 , Rolling Mean Loss = 0.0612 , Batch Accuracy = 86.75
# 	Batch 220, Loss = 0.061 , Rolling Mean Loss = 0.0651 , Batch Accuracy = 84.75
# 	Train Accuracy (mean) =  84.56
# 	Test Accuracy         =  40.2
# Epoch 30
# 	Batch   0, Loss = 0.046 , Rolling Mean Loss = 0.0655 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.0497 , Rolling Mean Loss = 0.0641 , Batch Accuracy = 84.5
# 	Batch  40, Loss = 0.0443 , Rolling Mean Loss = 0.0592 , Batch Accuracy = 87.25
# 	Batch  60, Loss = 0.0167 , Rolling Mean Loss = 0.0547 , Batch Accuracy = 86.75
# 	Batch  80, Loss = 0.0434 , Rolling Mean Loss = 0.0485 , Batch Accuracy = 85.75
# 	Batch 100, Loss = 0.0184 , Rolling Mean Loss = 0.043 , Batch Accuracy = 87.25
# 	Batch 120, Loss = 0.0454 , Rolling Mean Loss = 0.0437 , Batch Accuracy = 86.5
# 	Batch 140, Loss = 0.0273 , Rolling Mean Loss = 0.0456 , Batch Accuracy = 85.25
# 	Batch 160, Loss = 0.0506 , Rolling Mean Loss = 0.0485 , Batch Accuracy = 86.0
# 	Batch 180, Loss = 0.0416 , Rolling Mean Loss = 0.0501 , Batch Accuracy = 83.0
# 	Batch 200, Loss = 0.0932 , Rolling Mean Loss = 0.0561 , Batch Accuracy = 84.75
# 	Batch 220, Loss = 0.0518 , Rolling Mean Loss = 0.0623 , Batch Accuracy = 87.75
# 	Train Accuracy (mean) =  84.81
# 	Test Accuracy         =  39.2
# Epoch 31
# 	Batch   0, Loss = 0.1316 , Rolling Mean Loss = 0.0658 , Batch Accuracy = 84.75
# 	Batch  20, Loss = 0.0559 , Rolling Mean Loss = 0.067 , Batch Accuracy = 83.5
# 	Batch  40, Loss = 0.062 , Rolling Mean Loss = 0.0668 , Batch Accuracy = 86.5
# 	Batch  60, Loss = 0.0417 , Rolling Mean Loss = 0.0651 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.0843 , Rolling Mean Loss = 0.0608 , Batch Accuracy = 83.25
# 	Batch 100, Loss = 0.0526 , Rolling Mean Loss = 0.053 , Batch Accuracy = 85.0
# 	Batch 120, Loss = 0.0558 , Rolling Mean Loss = 0.0537 , Batch Accuracy = 86.5
# 	Batch 140, Loss = 0.0566 , Rolling Mean Loss = 0.0574 , Batch Accuracy = 87.25
# 	Batch 160, Loss = 0.0854 , Rolling Mean Loss = 0.0597 , Batch Accuracy = 82.5
# 	Batch 180, Loss = 0.0581 , Rolling Mean Loss = 0.0656 , Batch Accuracy = 86.5
# 	Batch 200, Loss = 0.0404 , Rolling Mean Loss = 0.0698 , Batch Accuracy = 88.0
# 	Batch 220, Loss = 0.0331 , Rolling Mean Loss = 0.071 , Batch Accuracy = 82.25
# 	Train Accuracy (mean) =  84.58
# 	Test Accuracy         =  38.5
# Epoch 32
# 	Batch   0, Loss = 0.0789 , Rolling Mean Loss = 0.0717 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.0695 , Rolling Mean Loss = 0.0676 , Batch Accuracy = 85.0
# 	Batch  40, Loss = 0.0932 , Rolling Mean Loss = 0.0627 , Batch Accuracy = 85.0
# 	Batch  60, Loss = 0.0555 , Rolling Mean Loss = 0.0584 , Batch Accuracy = 82.25
# 	Batch  80, Loss = 0.0472 , Rolling Mean Loss = 0.0533 , Batch Accuracy = 88.0
# 	Batch 100, Loss = 0.0564 , Rolling Mean Loss = 0.0504 , Batch Accuracy = 84.75
# 	Batch 120, Loss = 0.0781 , Rolling Mean Loss = 0.0523 , Batch Accuracy = 83.75
# 	Batch 140, Loss = 0.0498 , Rolling Mean Loss = 0.0544 , Batch Accuracy = 87.25
# 	Batch 160, Loss = 0.1158 , Rolling Mean Loss = 0.0575 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.098 , Rolling Mean Loss = 0.0624 , Batch Accuracy = 85.0
# 	Batch 200, Loss = 0.0897 , Rolling Mean Loss = 0.0681 , Batch Accuracy = 82.25
# 	Batch 220, Loss = 0.0698 , Rolling Mean Loss = 0.072 , Batch Accuracy = 86.0
# 	Train Accuracy (mean) =  84.61
# 	Test Accuracy         =  39.3
# Epoch 33
# 	Batch   0, Loss = 0.0468 , Rolling Mean Loss = 0.0737 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.0665 , Rolling Mean Loss = 0.0717 , Batch Accuracy = 83.25
# 	Batch  40, Loss = 0.0677 , Rolling Mean Loss = 0.0683 , Batch Accuracy = 86.0
# 	Batch  60, Loss = 0.0421 , Rolling Mean Loss = 0.0634 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.028 , Rolling Mean Loss = 0.0563 , Batch Accuracy = 84.0
# 	Batch 100, Loss = 0.0513 , Rolling Mean Loss = 0.0505 , Batch Accuracy = 84.5
# 	Batch 120, Loss = 0.0247 , Rolling Mean Loss = 0.0486 , Batch Accuracy = 85.5
# 	Batch 140, Loss = 0.0275 , Rolling Mean Loss = 0.0499 , Batch Accuracy = 85.0
# 	Batch 160, Loss = 0.0295 , Rolling Mean Loss = 0.0491 , Batch Accuracy = 82.0
# 	Batch 180, Loss = 0.084 , Rolling Mean Loss = 0.0533 , Batch Accuracy = 85.5
# 	Batch 200, Loss = 0.0724 , Rolling Mean Loss = 0.0555 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0698 , Rolling Mean Loss = 0.0603 , Batch Accuracy = 82.5
# 	Train Accuracy (mean) =  84.73
# 	Test Accuracy         =  40.8
# Epoch 34
# 	Batch   0, Loss = 0.058 , Rolling Mean Loss = 0.0614 , Batch Accuracy = 84.75
# 	Batch  20, Loss = 0.0495 , Rolling Mean Loss = 0.0618 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.0508 , Rolling Mean Loss = 0.06 , Batch Accuracy = 83.5
# 	Batch  60, Loss = 0.0351 , Rolling Mean Loss = 0.0564 , Batch Accuracy = 87.25
# 	Batch  80, Loss = 0.0392 , Rolling Mean Loss = 0.0527 , Batch Accuracy = 85.5
# 	Batch 100, Loss = 0.0781 , Rolling Mean Loss = 0.0499 , Batch Accuracy = 84.25
# 	Batch 120, Loss = 0.0712 , Rolling Mean Loss = 0.051 , Batch Accuracy = 87.5
# 	Batch 140, Loss = 0.0453 , Rolling Mean Loss = 0.0512 , Batch Accuracy = 87.0
# 	Batch 160, Loss = 0.0479 , Rolling Mean Loss = 0.0526 , Batch Accuracy = 85.5
# 	Batch 180, Loss = 0.0922 , Rolling Mean Loss = 0.0559 , Batch Accuracy = 82.5
# 	Batch 200, Loss = 0.0957 , Rolling Mean Loss = 0.0576 , Batch Accuracy = 84.25
# 	Batch 220, Loss = 0.0701 , Rolling Mean Loss = 0.0609 , Batch Accuracy = 83.0
# 	Train Accuracy (mean) =  84.8
# 	Test Accuracy         =  39.9
# Epoch 35
# 	Batch   0, Loss = 0.0205 , Rolling Mean Loss = 0.0624 , Batch Accuracy = 86.75
# 	Batch  20, Loss = 0.0286 , Rolling Mean Loss = 0.0631 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.041 , Rolling Mean Loss = 0.0599 , Batch Accuracy = 84.25
# 	Batch  60, Loss = 0.0608 , Rolling Mean Loss = 0.0564 , Batch Accuracy = 85.75
# 	Batch  80, Loss = 0.0518 , Rolling Mean Loss = 0.053 , Batch Accuracy = 86.25
# 	Batch 100, Loss = 0.0561 , Rolling Mean Loss = 0.0489 , Batch Accuracy = 84.25
# 	Batch 120, Loss = 0.0302 , Rolling Mean Loss = 0.0481 , Batch Accuracy = 82.25
# 	Batch 140, Loss = 0.0337 , Rolling Mean Loss = 0.0486 , Batch Accuracy = 84.25
# 	Batch 160, Loss = 0.0315 , Rolling Mean Loss = 0.0519 , Batch Accuracy = 86.75
# 	Batch 180, Loss = 0.0368 , Rolling Mean Loss = 0.0536 , Batch Accuracy = 88.75
# 	Batch 200, Loss = 0.0559 , Rolling Mean Loss = 0.0573 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.0688 , Rolling Mean Loss = 0.0638 , Batch Accuracy = 84.5
# 	Train Accuracy (mean) =  84.78
# 	Test Accuracy         =  39.9
# Epoch 36
# 	Batch   0, Loss = 0.0444 , Rolling Mean Loss = 0.0643 , Batch Accuracy = 86.75
# 	Batch  20, Loss = 0.0666 , Rolling Mean Loss = 0.0636 , Batch Accuracy = 84.0
# 	Batch  40, Loss = 0.0208 , Rolling Mean Loss = 0.0585 , Batch Accuracy = 83.5
# 	Batch  60, Loss = 0.0254 , Rolling Mean Loss = 0.0543 , Batch Accuracy = 85.5
# 	Batch  80, Loss = 0.0233 , Rolling Mean Loss = 0.0458 , Batch Accuracy = 83.5
# 	Batch 100, Loss = 0.0556 , Rolling Mean Loss = 0.042 , Batch Accuracy = 84.25
# 	Batch 120, Loss = 0.0426 , Rolling Mean Loss = 0.0434 , Batch Accuracy = 84.75
# 	Batch 140, Loss = 0.0161 , Rolling Mean Loss = 0.0453 , Batch Accuracy = 84.75
# 	Batch 160, Loss = 0.0427 , Rolling Mean Loss = 0.0478 , Batch Accuracy = 86.5
# 	Batch 180, Loss = 0.0285 , Rolling Mean Loss = 0.0508 , Batch Accuracy = 82.0
# 	Batch 200, Loss = 0.0605 , Rolling Mean Loss = 0.053 , Batch Accuracy = 86.5
# 	Batch 220, Loss = 0.061 , Rolling Mean Loss = 0.0543 , Batch Accuracy = 82.0
# 	Train Accuracy (mean) =  84.96
# 	Test Accuracy         =  39.9
# Epoch 37
# 	Batch   0, Loss = 0.0286 , Rolling Mean Loss = 0.0541 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0178 , Rolling Mean Loss = 0.0528 , Batch Accuracy = 85.0
# 	Batch  40, Loss = 0.048 , Rolling Mean Loss = 0.0481 , Batch Accuracy = 86.5
# 	Batch  60, Loss = 0.0454 , Rolling Mean Loss = 0.0458 , Batch Accuracy = 84.0
# 	Batch  80, Loss = 0.0665 , Rolling Mean Loss = 0.0428 , Batch Accuracy = 84.75
# 	Batch 100, Loss = 0.0521 , Rolling Mean Loss = 0.0408 , Batch Accuracy = 84.0
# 	Batch 120, Loss = 0.078 , Rolling Mean Loss = 0.0436 , Batch Accuracy = 85.75
# 	Batch 140, Loss = 0.0832 , Rolling Mean Loss = 0.0471 , Batch Accuracy = 81.75
# 	Batch 160, Loss = 0.0407 , Rolling Mean Loss = 0.0471 , Batch Accuracy = 84.75
# 	Batch 180, Loss = 0.0354 , Rolling Mean Loss = 0.0486 , Batch Accuracy = 85.75
# 	Batch 200, Loss = 0.0766 , Rolling Mean Loss = 0.0511 , Batch Accuracy = 83.0
# 	Batch 220, Loss = 0.0819 , Rolling Mean Loss = 0.0523 , Batch Accuracy = 88.75
# 	Train Accuracy (mean) =  85.01
# 	Test Accuracy         =  39.7
# Epoch 38
# 	Batch   0, Loss = 0.0222 , Rolling Mean Loss = 0.0536 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0267 , Rolling Mean Loss = 0.0514 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.0149 , Rolling Mean Loss = 0.0501 , Batch Accuracy = 86.25
# 	Batch  60, Loss = 0.0382 , Rolling Mean Loss = 0.0454 , Batch Accuracy = 84.5
# 	Batch  80, Loss = 0.0647 , Rolling Mean Loss = 0.041 , Batch Accuracy = 86.5
# 	Batch 100, Loss = 0.0397 , Rolling Mean Loss = 0.0371 , Batch Accuracy = 86.75
# 	Batch 120, Loss = 0.0202 , Rolling Mean Loss = 0.0358 , Batch Accuracy = 85.0
# 	Batch 140, Loss = 0.0468 , Rolling Mean Loss = 0.0359 , Batch Accuracy = 85.0
# 	Batch 160, Loss = 0.0264 , Rolling Mean Loss = 0.038 , Batch Accuracy = 86.75
# 	Batch 180, Loss = 0.059 , Rolling Mean Loss = 0.0414 , Batch Accuracy = 87.0
# 	Batch 200, Loss = 0.0263 , Rolling Mean Loss = 0.0441 , Batch Accuracy = 83.0
# 	Batch 220, Loss = 0.0253 , Rolling Mean Loss = 0.0472 , Batch Accuracy = 87.0
# 	Train Accuracy (mean) =  85.15
# 	Test Accuracy         =  40.8
# Epoch 39
# 	Batch   0, Loss = 0.0354 , Rolling Mean Loss = 0.0487 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.049 , Rolling Mean Loss = 0.0482 , Batch Accuracy = 88.75
# 	Batch  40, Loss = 0.0373 , Rolling Mean Loss = 0.047 , Batch Accuracy = 84.5
# 	Batch  60, Loss = 0.0445 , Rolling Mean Loss = 0.0435 , Batch Accuracy = 86.75
# 	Batch  80, Loss = 0.0321 , Rolling Mean Loss = 0.0403 , Batch Accuracy = 83.25
# 	Batch 100, Loss = 0.0354 , Rolling Mean Loss = 0.0381 , Batch Accuracy = 84.5
# 	Batch 120, Loss = 0.0235 , Rolling Mean Loss = 0.0372 , Batch Accuracy = 85.5
# 	Batch 140, Loss = 0.0553 , Rolling Mean Loss = 0.0391 , Batch Accuracy = 86.0
# 	Batch 160, Loss = 0.0568 , Rolling Mean Loss = 0.0434 , Batch Accuracy = 87.0
# 	Batch 180, Loss = 0.032 , Rolling Mean Loss = 0.0452 , Batch Accuracy = 78.0
# 	Batch 200, Loss = 0.075 , Rolling Mean Loss = 0.0485 , Batch Accuracy = 82.25
# 	Batch 220, Loss = 0.0487 , Rolling Mean Loss = 0.0534 , Batch Accuracy = 85.25
# 	Train Accuracy (mean) =  85.11
# 	Test Accuracy         =  40.2
# Epoch 40
# 	Batch   0, Loss = 0.0318 , Rolling Mean Loss = 0.0541 , Batch Accuracy = 87.5
# 	Batch  20, Loss = 0.0307 , Rolling Mean Loss = 0.0499 , Batch Accuracy = 88.25
# 	Batch  40, Loss = 0.0466 , Rolling Mean Loss = 0.0487 , Batch Accuracy = 85.75
# 	Batch  60, Loss = 0.0294 , Rolling Mean Loss = 0.0483 , Batch Accuracy = 84.5
# 	Batch  80, Loss = 0.0383 , Rolling Mean Loss = 0.0476 , Batch Accuracy = 87.75
# 	Batch 100, Loss = 0.1003 , Rolling Mean Loss = 0.0494 , Batch Accuracy = 82.5
# 	Batch 120, Loss = 0.0454 , Rolling Mean Loss = 0.0536 , Batch Accuracy = 84.25
# 	Batch 140, Loss = 0.0517 , Rolling Mean Loss = 0.0544 , Batch Accuracy = 88.25
# 	Batch 160, Loss = 0.0258 , Rolling Mean Loss = 0.058 , Batch Accuracy = 88.75
# 	Batch 180, Loss = 0.1197 , Rolling Mean Loss = 0.0608 , Batch Accuracy = 83.5
# 	Batch 200, Loss = 0.0642 , Rolling Mean Loss = 0.0611 , Batch Accuracy = 83.25
# 	Batch 220, Loss = 0.1051 , Rolling Mean Loss = 0.0657 , Batch Accuracy = 82.25
# 	Train Accuracy (mean) =  84.69
# 	Test Accuracy         =  39.4
# Epoch 41
# 	Batch   0, Loss = 0.0726 , Rolling Mean Loss = 0.0684 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.0708 , Rolling Mean Loss = 0.0679 , Batch Accuracy = 86.25
# 	Batch  40, Loss = 0.0729 , Rolling Mean Loss = 0.0676 , Batch Accuracy = 84.75
# 	Batch  60, Loss = 0.0535 , Rolling Mean Loss = 0.0663 , Batch Accuracy = 84.5
# 	Batch  80, Loss = 0.061 , Rolling Mean Loss = 0.0647 , Batch Accuracy = 85.25
# 	Batch 100, Loss = 0.0732 , Rolling Mean Loss = 0.0601 , Batch Accuracy = 84.5
# 	Batch 120, Loss = 0.0387 , Rolling Mean Loss = 0.0612 , Batch Accuracy = 86.75
# 	Batch 140, Loss = 0.0521 , Rolling Mean Loss = 0.0601 , Batch Accuracy = 86.5
# 	Batch 160, Loss = 0.0175 , Rolling Mean Loss = 0.0595 , Batch Accuracy = 89.25
# 	Batch 180, Loss = 0.0253 , Rolling Mean Loss = 0.0584 , Batch Accuracy = 86.0
# 	Batch 200, Loss = 0.0556 , Rolling Mean Loss = 0.0583 , Batch Accuracy = 83.75
# 	Batch 220, Loss = 0.1123 , Rolling Mean Loss = 0.0606 , Batch Accuracy = 81.5
# 	Train Accuracy (mean) =  84.66
# 	Test Accuracy         =  40.8
# Epoch 42
# 	Batch   0, Loss = 0.026 , Rolling Mean Loss = 0.0596 , Batch Accuracy = 84.5
# 	Batch  20, Loss = 0.0391 , Rolling Mean Loss = 0.0569 , Batch Accuracy = 87.0
# 	Batch  40, Loss = 0.044 , Rolling Mean Loss = 0.0538 , Batch Accuracy = 86.75
# 	Batch  60, Loss = 0.0385 , Rolling Mean Loss = 0.051 , Batch Accuracy = 85.25
# 	Batch  80, Loss = 0.0589 , Rolling Mean Loss = 0.0453 , Batch Accuracy = 84.25
# 	Batch 100, Loss = 0.007 , Rolling Mean Loss = 0.0412 , Batch Accuracy = 87.75
# 	Batch 120, Loss = 0.0309 , Rolling Mean Loss = 0.0414 , Batch Accuracy = 86.5
# 	Batch 140, Loss = 0.0617 , Rolling Mean Loss = 0.0428 , Batch Accuracy = 81.5
# 	Batch 160, Loss = 0.106 , Rolling Mean Loss = 0.0454 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0416 , Rolling Mean Loss = 0.0466 , Batch Accuracy = 83.5
# 	Batch 200, Loss = 0.0527 , Rolling Mean Loss = 0.0496 , Batch Accuracy = 85.0
# 	Batch 220, Loss = 0.1131 , Rolling Mean Loss = 0.0528 , Batch Accuracy = 82.25
# 	Train Accuracy (mean) =  85.02
# 	Test Accuracy         =  40.6
# Epoch 43
# 	Batch   0, Loss = 0.0391 , Rolling Mean Loss = 0.0532 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.0119 , Rolling Mean Loss = 0.0488 , Batch Accuracy = 83.75
# 	Batch  40, Loss = 0.0539 , Rolling Mean Loss = 0.0462 , Batch Accuracy = 82.5
# 	Batch  60, Loss = 0.0598 , Rolling Mean Loss = 0.0437 , Batch Accuracy = 85.25
# 	Batch  80, Loss = 0.0414 , Rolling Mean Loss = 0.039 , Batch Accuracy = 88.0
# 	Batch 100, Loss = 0.0165 , Rolling Mean Loss = 0.036 , Batch Accuracy = 83.75
# 	Batch 120, Loss = 0.0175 , Rolling Mean Loss = 0.0406 , Batch Accuracy = 81.5
# 	Batch 140, Loss = 0.0262 , Rolling Mean Loss = 0.0404 , Batch Accuracy = 86.5
# 	Batch 160, Loss = 0.0738 , Rolling Mean Loss = 0.0406 , Batch Accuracy = 84.25
# 	Batch 180, Loss = 0.0474 , Rolling Mean Loss = 0.0429 , Batch Accuracy = 87.25
# 	Batch 200, Loss = 0.0513 , Rolling Mean Loss = 0.0455 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0651 , Rolling Mean Loss = 0.0445 , Batch Accuracy = 87.0
# 	Train Accuracy (mean) =  85.18
# 	Test Accuracy         =  39.8
# Epoch 44
# 	Batch   0, Loss = 0.01 , Rolling Mean Loss = 0.0444 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.0357 , Rolling Mean Loss = 0.0441 , Batch Accuracy = 85.5
# 	Batch  40, Loss = 0.0286 , Rolling Mean Loss = 0.0409 , Batch Accuracy = 85.0
# 	Batch  60, Loss = 0.0153 , Rolling Mean Loss = 0.0368 , Batch Accuracy = 87.5
# 	Batch  80, Loss = 0.0279 , Rolling Mean Loss = 0.034 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0526 , Rolling Mean Loss = 0.0302 , Batch Accuracy = 84.0
# 	Batch 120, Loss = 0.0256 , Rolling Mean Loss = 0.0289 , Batch Accuracy = 88.75
# 	Batch 140, Loss = 0.0232 , Rolling Mean Loss = 0.0293 , Batch Accuracy = 85.75
# 	Batch 160, Loss = 0.0226 , Rolling Mean Loss = 0.0292 , Batch Accuracy = 88.75
# 	Batch 180, Loss = 0.0149 , Rolling Mean Loss = 0.0294 , Batch Accuracy = 83.75
# 	Batch 200, Loss = 0.0284 , Rolling Mean Loss = 0.0306 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.0091 , Rolling Mean Loss = 0.032 , Batch Accuracy = 86.0
# 	Train Accuracy (mean) =  85.49
# 	Test Accuracy         =  39.3
# Epoch 45
# 	Batch   0, Loss = 0.0058 , Rolling Mean Loss = 0.0322 , Batch Accuracy = 86.25
# 	Batch  20, Loss = 0.0238 , Rolling Mean Loss = 0.0318 , Batch Accuracy = 84.0
# 	Batch  40, Loss = 0.0121 , Rolling Mean Loss = 0.0307 , Batch Accuracy = 88.0
# 	Batch  60, Loss = 0.0314 , Rolling Mean Loss = 0.029 , Batch Accuracy = 86.5
# 	Batch  80, Loss = 0.0085 , Rolling Mean Loss = 0.028 , Batch Accuracy = 86.0
# 	Batch 100, Loss = 0.0121 , Rolling Mean Loss = 0.0257 , Batch Accuracy = 85.5
# 	Batch 120, Loss = 0.0394 , Rolling Mean Loss = 0.0273 , Batch Accuracy = 84.75
# 	Batch 140, Loss = 0.0309 , Rolling Mean Loss = 0.0279 , Batch Accuracy = 85.5
# 	Batch 160, Loss = 0.0433 , Rolling Mean Loss = 0.0287 , Batch Accuracy = 83.0
# 	Batch 180, Loss = 0.0188 , Rolling Mean Loss = 0.0291 , Batch Accuracy = 85.75
# 	Batch 200, Loss = 0.0181 , Rolling Mean Loss = 0.0296 , Batch Accuracy = 87.25
# 	Batch 220, Loss = 0.0058 , Rolling Mean Loss = 0.0297 , Batch Accuracy = 83.75
# 	Train Accuracy (mean) =  85.53
# 	Test Accuracy         =  38.7
# Epoch 46
# 	Batch   0, Loss = 0.0182 , Rolling Mean Loss = 0.0301 , Batch Accuracy = 87.25
# 	Batch  20, Loss = 0.0138 , Rolling Mean Loss = 0.0293 , Batch Accuracy = 87.75
# 	Batch  40, Loss = 0.0159 , Rolling Mean Loss = 0.0287 , Batch Accuracy = 81.75
# 	Batch  60, Loss = 0.0185 , Rolling Mean Loss = 0.0289 , Batch Accuracy = 86.0
# 	Batch  80, Loss = 0.0365 , Rolling Mean Loss = 0.0268 , Batch Accuracy = 87.5
# 	Batch 100, Loss = 0.0218 , Rolling Mean Loss = 0.0269 , Batch Accuracy = 86.25
# 	Batch 120, Loss = 0.0145 , Rolling Mean Loss = 0.0267 , Batch Accuracy = 81.75
# 	Batch 140, Loss = 0.019 , Rolling Mean Loss = 0.0271 , Batch Accuracy = 85.75
# 	Batch 160, Loss = 0.0104 , Rolling Mean Loss = 0.0278 , Batch Accuracy = 86.25
# 	Batch 180, Loss = 0.0351 , Rolling Mean Loss = 0.03 , Batch Accuracy = 87.0
# 	Batch 200, Loss = 0.0385 , Rolling Mean Loss = 0.0329 , Batch Accuracy = 87.75
# ...
# 	Batch 140, Loss = 0.0881 , Rolling Mean Loss = 0.0394 , Batch Accuracy = 84.0
# 	Batch 160, Loss = 0.0752 , Rolling Mean Loss = 0.039 , Batch Accuracy = 85.25
# 	Batch 180, Loss = 0.0791 , Rolling Mean Loss = 0.0389 , Batch Accuracy = 82.25
# 	Batch 200, Loss = 0.0247 , Rolling Mean Loss = 0.0392 , Batch Accuracy = 87.0
# 	Batch 220, Loss = 0.0451 , Rolling Mean Loss = 0.0404 , Batch Accuracy = 87.0
# 	Train Accuracy (mean) =  85.16
# 	Test Accuracy         =  39.2
# Epoch 85
# 	Batch   0, Loss = 0.0173 , Rolling Mean Loss = 0.0414 , Batch Accuracy = 82.5
# 	Batch  20, Loss = 0.014 , Rolling Mean Loss = 0.0392 , Batch Accuracy = 87.25
# 	Batch  40, Loss = 0.0061 , Rolling Mean Loss = 0.0353 , Batch Accuracy = 85.25
# 	Batch  60, Loss = 0.0072 , Rolling Mean Loss = 0.0302 , Batch Accuracy = 85.75
# 	Batch  80, Loss = 0.0043 , Rolling Mean Loss = 0.024 , Batch Accuracy = 89.25
# 	Batch 100, Loss = 0.0109 , Rolling Mean Loss = 0.018 , Batch Accuracy = 85.0
# 	Batch 120, Loss = 0.0048 , Rolling Mean Loss = 0.0159 , Batch Accuracy = 86.25
# 	Batch 140, Loss = 0.0026 , Rolling Mean Loss = 0.0167 , Batch Accuracy = 85.5
# 	Batch 160, Loss = 0.0046 , Rolling Mean Loss = 0.017 , Batch Accuracy = 85.25
# 	Batch 180, Loss = 0.0156 , Rolling Mean Loss = 0.0172 , Batch Accuracy = 86.5
# 	Batch 200, Loss = 0.0088 , Rolling Mean Loss = 0.0179 , Batch Accuracy = 84.5
# 	Batch 220, Loss = 0.0123 , Rolling Mean Loss = 0.0191 , Batch Accuracy = 88.5
# 	Train Accuracy (mean) =  85.8
# 	Test Accuracy         =  39.5
# Epoch 86
# 	Batch   0, Loss = 0.0175 , Rolling Mean Loss = 0.0197 , Batch Accuracy = 88.25
# 	Batch  20, Loss = 0.0431 , Rolling Mean Loss = 0.0183 , Batch Accuracy = 88.25
# 	Batch  40, Loss = 0.0182 , Rolling Mean Loss = 0.0175 , Batch Accuracy = 84.25
# 	Batch  60, Loss = 0.0154 , Rolling Mean Loss = 0.0162 , Batch Accuracy = 88.0
# 	Batch  80, Loss = 0.0138 , Rolling Mean Loss = 0.0143 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0067 , Rolling Mean Loss = 0.012 , Batch Accuracy = 88.5
# 	Batch 120, Loss = 0.0072 , Rolling Mean Loss = 0.0114 , Batch Accuracy = 83.5
# 	Batch 140, Loss = 0.038 , Rolling Mean Loss = 0.0108 , Batch Accuracy = 84.5
# 	Batch 160, Loss = 0.0021 , Rolling Mean Loss = 0.0104 , Batch Accuracy = 86.25
# 	Batch 180, Loss = 0.0026 , Rolling Mean Loss = 0.0102 , Batch Accuracy = 87.25
# 	Batch 200, Loss = 0.0029 , Rolling Mean Loss = 0.0096 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.0137 , Rolling Mean Loss = 0.0104 , Batch Accuracy = 86.75
# 	Train Accuracy (mean) =  86.0
# 	Test Accuracy         =  40.2
# Epoch 87
# 	Batch   0, Loss = 0.0013 , Rolling Mean Loss = 0.01 , Batch Accuracy = 85.25
# 	Batch  20, Loss = 0.0023 , Rolling Mean Loss = 0.0092 , Batch Accuracy = 83.75
# 	Batch  40, Loss = 0.0032 , Rolling Mean Loss = 0.0083 , Batch Accuracy = 86.25
# 	Batch  60, Loss = 0.0024 , Rolling Mean Loss = 0.0075 , Batch Accuracy = 88.5
# 	Batch  80, Loss = 0.0016 , Rolling Mean Loss = 0.0066 , Batch Accuracy = 88.75
# 	Batch 100, Loss = 0.003 , Rolling Mean Loss = 0.0052 , Batch Accuracy = 87.25
# 	Batch 120, Loss = 0.0061 , Rolling Mean Loss = 0.0051 , Batch Accuracy = 88.75
# 	Batch 140, Loss = 0.0039 , Rolling Mean Loss = 0.0056 , Batch Accuracy = 89.5
# 	Batch 160, Loss = 0.0062 , Rolling Mean Loss = 0.0052 , Batch Accuracy = 86.5
# 	Batch 180, Loss = 0.0038 , Rolling Mean Loss = 0.0056 , Batch Accuracy = 87.0
# 	Batch 200, Loss = 0.0079 , Rolling Mean Loss = 0.0063 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.0045 , Rolling Mean Loss = 0.0069 , Batch Accuracy = 87.75
# 	Train Accuracy (mean) =  86.13
# 	Test Accuracy         =  39.6
# Epoch 88
# 	Batch   0, Loss = 0.002 , Rolling Mean Loss = 0.007 , Batch Accuracy = 82.5
# 	Batch  20, Loss = 0.0012 , Rolling Mean Loss = 0.0061 , Batch Accuracy = 85.75
# 	Batch  40, Loss = 0.0021 , Rolling Mean Loss = 0.0057 , Batch Accuracy = 85.75
# 	Batch  60, Loss = 0.0079 , Rolling Mean Loss = 0.0049 , Batch Accuracy = 88.25
# 	Batch  80, Loss = 0.0008 , Rolling Mean Loss = 0.0044 , Batch Accuracy = 84.25
# 	Batch 100, Loss = 0.0173 , Rolling Mean Loss = 0.0041 , Batch Accuracy = 86.0
# 	Batch 120, Loss = 0.02 , Rolling Mean Loss = 0.0049 , Batch Accuracy = 86.25
# 	Batch 140, Loss = 0.0044 , Rolling Mean Loss = 0.0048 , Batch Accuracy = 87.25
# 	Batch 160, Loss = 0.0042 , Rolling Mean Loss = 0.0061 , Batch Accuracy = 84.75
# 	Batch 180, Loss = 0.008 , Rolling Mean Loss = 0.0064 , Batch Accuracy = 86.25
# 	Batch 200, Loss = 0.0055 , Rolling Mean Loss = 0.0066 , Batch Accuracy = 86.5
# 	Batch 220, Loss = 0.0186 , Rolling Mean Loss = 0.0063 , Batch Accuracy = 86.5
# 	Train Accuracy (mean) =  86.14
# 	Test Accuracy         =  39.1
# Epoch 89
# 	Batch   0, Loss = 0.0007 , Rolling Mean Loss = 0.0066 , Batch Accuracy = 87.75
# 	Batch  20, Loss = 0.0008 , Rolling Mean Loss = 0.0065 , Batch Accuracy = 86.5
# 	Batch  40, Loss = 0.0019 , Rolling Mean Loss = 0.0056 , Batch Accuracy = 87.0
# 	Batch  60, Loss = 0.0016 , Rolling Mean Loss = 0.0052 , Batch Accuracy = 88.0
# 	Batch  80, Loss = 0.0019 , Rolling Mean Loss = 0.0051 , Batch Accuracy = 87.25
# 	Batch 100, Loss = 0.0272 , Rolling Mean Loss = 0.005 , Batch Accuracy = 83.75
# 	Batch 120, Loss = 0.0014 , Rolling Mean Loss = 0.0047 , Batch Accuracy = 80.75
# 	Batch 140, Loss = 0.0032 , Rolling Mean Loss = 0.0049 , Batch Accuracy = 86.25
# 	Batch 160, Loss = 0.0011 , Rolling Mean Loss = 0.0049 , Batch Accuracy = 86.5
# 	Batch 180, Loss = 0.0021 , Rolling Mean Loss = 0.0056 , Batch Accuracy = 84.5
# 	Batch 200, Loss = 0.0017 , Rolling Mean Loss = 0.0058 , Batch Accuracy = 88.75
# 	Batch 220, Loss = 0.001 , Rolling Mean Loss = 0.007 , Batch Accuracy = 86.5
# 	Train Accuracy (mean) =  86.14
# 	Test Accuracy         =  39.3
# Epoch 90
# 	Batch   0, Loss = 0.0029 , Rolling Mean Loss = 0.0069 , Batch Accuracy = 85.0
# 	Batch  20, Loss = 0.001 , Rolling Mean Loss = 0.0073 , Batch Accuracy = 86.5
# 	Batch  40, Loss = 0.0179 , Rolling Mean Loss = 0.006 , Batch Accuracy = 89.0
# 	Batch  60, Loss = 0.0007 , Rolling Mean Loss = 0.0061 , Batch Accuracy = 87.5
# 	Batch  80, Loss = 0.0023 , Rolling Mean Loss = 0.0054 , Batch Accuracy = 83.75
# 	Batch 100, Loss = 0.0008 , Rolling Mean Loss = 0.006 , Batch Accuracy = 86.75
# 	Batch 120, Loss = 0.0015 , Rolling Mean Loss = 0.0068 , Batch Accuracy = 85.5
# 	Batch 140, Loss = 0.0072 , Rolling Mean Loss = 0.0075 , Batch Accuracy = 89.25
# 	Batch 160, Loss = 0.0107 , Rolling Mean Loss = 0.0077 , Batch Accuracy = 84.75
# 	Batch 180, Loss = 0.0056 , Rolling Mean Loss = 0.0085 , Batch Accuracy = 86.0
# 	Batch 200, Loss = 0.017 , Rolling Mean Loss = 0.0091 , Batch Accuracy = 87.5
# 	Batch 220, Loss = 0.0018 , Rolling Mean Loss = 0.009 , Batch Accuracy = 85.25
# 	Train Accuracy (mean) =  86.1
# 	Test Accuracy         =  39.8
# Epoch 91
# 	Batch   0, Loss = 0.0237 , Rolling Mean Loss = 0.0097 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0073 , Rolling Mean Loss = 0.0106 , Batch Accuracy = 87.25
# 	Batch  40, Loss = 0.0068 , Rolling Mean Loss = 0.0111 , Batch Accuracy = 87.0
# 	Batch  60, Loss = 0.0161 , Rolling Mean Loss = 0.0121 , Batch Accuracy = 84.0
# 	Batch  80, Loss = 0.0009 , Rolling Mean Loss = 0.014 , Batch Accuracy = 83.75
# 	Batch 100, Loss = 0.0082 , Rolling Mean Loss = 0.0144 , Batch Accuracy = 81.75
# 	Batch 120, Loss = 0.0117 , Rolling Mean Loss = 0.016 , Batch Accuracy = 82.5
# 	Batch 140, Loss = 0.0169 , Rolling Mean Loss = 0.0195 , Batch Accuracy = 86.5
# 	Batch 160, Loss = 0.0238 , Rolling Mean Loss = 0.0234 , Batch Accuracy = 88.75
# 	Batch 180, Loss = 0.0397 , Rolling Mean Loss = 0.026 , Batch Accuracy = 83.0
# 	Batch 200, Loss = 0.0484 , Rolling Mean Loss = 0.0311 , Batch Accuracy = 86.25
# 	Batch 220, Loss = 0.0271 , Rolling Mean Loss = 0.0374 , Batch Accuracy = 88.0
# 	Train Accuracy (mean) =  85.61
# 	Test Accuracy         =  39.8
# Epoch 92
# 	Batch   0, Loss = 0.0326 , Rolling Mean Loss = 0.0405 , Batch Accuracy = 85.75
# 	Batch  20, Loss = 0.022 , Rolling Mean Loss = 0.0435 , Batch Accuracy = 85.0
# 	Batch  40, Loss = 0.0959 , Rolling Mean Loss = 0.0443 , Batch Accuracy = 84.5
# 	Batch  60, Loss = 0.0393 , Rolling Mean Loss = 0.0468 , Batch Accuracy = 83.75
# 	Batch  80, Loss = 0.0578 , Rolling Mean Loss = 0.0509 , Batch Accuracy = 83.75
# 	Batch 100, Loss = 0.0426 , Rolling Mean Loss = 0.0528 , Batch Accuracy = 84.75
# 	Batch 120, Loss = 0.077 , Rolling Mean Loss = 0.0589 , Batch Accuracy = 84.0
# 	Batch 140, Loss = 0.0612 , Rolling Mean Loss = 0.0634 , Batch Accuracy = 83.5
# 	Batch 160, Loss = 0.0997 , Rolling Mean Loss = 0.0689 , Batch Accuracy = 86.25
# 	Batch 180, Loss = 0.0621 , Rolling Mean Loss = 0.0716 , Batch Accuracy = 84.75
# 	Batch 200, Loss = 0.0812 , Rolling Mean Loss = 0.0751 , Batch Accuracy = 81.5
# 	Batch 220, Loss = 0.129 , Rolling Mean Loss = 0.0774 , Batch Accuracy = 85.25
# 	Train Accuracy (mean) =  84.59
# 	Test Accuracy         =  39.1
# Epoch 93
# 	Batch   0, Loss = 0.0276 , Rolling Mean Loss = 0.0808 , Batch Accuracy = 87.75
# 	Batch  20, Loss = 0.0292 , Rolling Mean Loss = 0.0775 , Batch Accuracy = 83.0
# 	Batch  40, Loss = 0.0386 , Rolling Mean Loss = 0.0742 , Batch Accuracy = 85.0
# 	Batch  60, Loss = 0.0338 , Rolling Mean Loss = 0.0696 , Batch Accuracy = 86.25
# 	Batch  80, Loss = 0.0438 , Rolling Mean Loss = 0.063 , Batch Accuracy = 85.0
# 	Batch 100, Loss = 0.0769 , Rolling Mean Loss = 0.0559 , Batch Accuracy = 81.75
# 	Batch 120, Loss = 0.036 , Rolling Mean Loss = 0.057 , Batch Accuracy = 84.5
# 	Batch 140, Loss = 0.0393 , Rolling Mean Loss = 0.0561 , Batch Accuracy = 86.75
# 	Batch 160, Loss = 0.0454 , Rolling Mean Loss = 0.0556 , Batch Accuracy = 88.75
# 	Batch 180, Loss = 0.0192 , Rolling Mean Loss = 0.0576 , Batch Accuracy = 82.5
# 	Batch 200, Loss = 0.1214 , Rolling Mean Loss = 0.0599 , Batch Accuracy = 85.0
# 	Batch 220, Loss = 0.067 , Rolling Mean Loss = 0.0611 , Batch Accuracy = 86.5
# 	Train Accuracy (mean) =  84.74
# 	Test Accuracy         =  39.1
# Epoch 94
# 	Batch   0, Loss = 0.0277 , Rolling Mean Loss = 0.0593 , Batch Accuracy = 85.25
# 	Batch  20, Loss = 0.0183 , Rolling Mean Loss = 0.0548 , Batch Accuracy = 86.25
# 	Batch  40, Loss = 0.0191 , Rolling Mean Loss = 0.0478 , Batch Accuracy = 88.5
# 	Batch  60, Loss = 0.0568 , Rolling Mean Loss = 0.0418 , Batch Accuracy = 84.0
# 	Batch  80, Loss = 0.0234 , Rolling Mean Loss = 0.033 , Batch Accuracy = 87.0
# 	Batch 100, Loss = 0.0091 , Rolling Mean Loss = 0.0257 , Batch Accuracy = 89.0
# 	Batch 120, Loss = 0.0172 , Rolling Mean Loss = 0.0243 , Batch Accuracy = 86.25
# 	Batch 140, Loss = 0.012 , Rolling Mean Loss = 0.025 , Batch Accuracy = 84.25
# 	Batch 160, Loss = 0.0485 , Rolling Mean Loss = 0.025 , Batch Accuracy = 83.75
# 	Batch 180, Loss = 0.0132 , Rolling Mean Loss = 0.0252 , Batch Accuracy = 84.0
# 	Batch 200, Loss = 0.0598 , Rolling Mean Loss = 0.028 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0431 , Rolling Mean Loss = 0.0296 , Batch Accuracy = 82.0
# 	Train Accuracy (mean) =  85.54
# 	Test Accuracy         =  39.7
# Epoch 95
# 	Batch   0, Loss = 0.0049 , Rolling Mean Loss = 0.0285 , Batch Accuracy = 87.0
# 	Batch  20, Loss = 0.0122 , Rolling Mean Loss = 0.0254 , Batch Accuracy = 87.25
# 	Batch  40, Loss = 0.0066 , Rolling Mean Loss = 0.0227 , Batch Accuracy = 85.25
# 	Batch  60, Loss = 0.0053 , Rolling Mean Loss = 0.0189 , Batch Accuracy = 86.75
# 	Batch  80, Loss = 0.0108 , Rolling Mean Loss = 0.0148 , Batch Accuracy = 87.0
# 	Batch 100, Loss = 0.0032 , Rolling Mean Loss = 0.012 , Batch Accuracy = 84.5
# 	Batch 120, Loss = 0.0103 , Rolling Mean Loss = 0.0121 , Batch Accuracy = 84.75
# 	Batch 140, Loss = 0.0045 , Rolling Mean Loss = 0.0124 , Batch Accuracy = 84.25
# 	Batch 160, Loss = 0.0085 , Rolling Mean Loss = 0.0129 , Batch Accuracy = 86.25
# 	Batch 180, Loss = 0.0078 , Rolling Mean Loss = 0.0137 , Batch Accuracy = 85.0
# 	Batch 200, Loss = 0.0348 , Rolling Mean Loss = 0.0137 , Batch Accuracy = 85.25
# 	Batch 220, Loss = 0.0056 , Rolling Mean Loss = 0.0126 , Batch Accuracy = 86.75
# 	Train Accuracy (mean) =  85.97
# 	Test Accuracy         =  41.8
# Epoch 96
# 	Batch   0, Loss = 0.0142 , Rolling Mean Loss = 0.0129 , Batch Accuracy = 86.5
# 	Batch  20, Loss = 0.0091 , Rolling Mean Loss = 0.0118 , Batch Accuracy = 86.25
# 	Batch  40, Loss = 0.0015 , Rolling Mean Loss = 0.0101 , Batch Accuracy = 87.75
# 	Batch  60, Loss = 0.0017 , Rolling Mean Loss = 0.008 , Batch Accuracy = 83.5
# 	Batch  80, Loss = 0.0028 , Rolling Mean Loss = 0.0067 , Batch Accuracy = 85.5
# 	Batch 100, Loss = 0.0017 , Rolling Mean Loss = 0.0057 , Batch Accuracy = 83.25
# 	Batch 120, Loss = 0.0018 , Rolling Mean Loss = 0.0059 , Batch Accuracy = 87.75
# 	Batch 140, Loss = 0.0033 , Rolling Mean Loss = 0.0049 , Batch Accuracy = 87.5
# 	Batch 160, Loss = 0.0006 , Rolling Mean Loss = 0.0049 , Batch Accuracy = 88.0
# 	Batch 180, Loss = 0.0124 , Rolling Mean Loss = 0.0049 , Batch Accuracy = 84.5
# 	Batch 200, Loss = 0.0062 , Rolling Mean Loss = 0.0048 , Batch Accuracy = 88.5
# 	Batch 220, Loss = 0.0046 , Rolling Mean Loss = 0.0047 , Batch Accuracy = 85.5
# 	Train Accuracy (mean) =  86.15
# 	Test Accuracy         =  40.4
# Epoch 97
# 	Batch   0, Loss = 0.0182 , Rolling Mean Loss = 0.0055 , Batch Accuracy = 86.25
# 	Batch  20, Loss = 0.0017 , Rolling Mean Loss = 0.0053 , Batch Accuracy = 86.25
# 	Batch  40, Loss = 0.0019 , Rolling Mean Loss = 0.0052 , Batch Accuracy = 85.75
# 	Batch  60, Loss = 0.0007 , Rolling Mean Loss = 0.0043 , Batch Accuracy = 84.0
# 	Batch  80, Loss = 0.001 , Rolling Mean Loss = 0.0036 , Batch Accuracy = 87.25
# 	Batch 100, Loss = 0.0007 , Rolling Mean Loss = 0.0029 , Batch Accuracy = 86.0
# 	Batch 120, Loss = 0.0034 , Rolling Mean Loss = 0.003 , Batch Accuracy = 87.0
# 	Batch 140, Loss = 0.001 , Rolling Mean Loss = 0.0031 , Batch Accuracy = 84.0
# 	Batch 160, Loss = 0.0008 , Rolling Mean Loss = 0.0039 , Batch Accuracy = 87.0
# 	Batch 180, Loss = 0.0064 , Rolling Mean Loss = 0.0041 , Batch Accuracy = 86.5
# 	Batch 200, Loss = 0.0022 , Rolling Mean Loss = 0.0038 , Batch Accuracy = 84.75
# 	Batch 220, Loss = 0.0008 , Rolling Mean Loss = 0.0033 , Batch Accuracy = 87.0
# 	Train Accuracy (mean) =  86.2
# 	Test Accuracy         =  40.6
# Epoch 98
# 	Batch   0, Loss = 0.0006 , Rolling Mean Loss = 0.0035 , Batch Accuracy = 86.0
# 	Batch  20, Loss = 0.0021 , Rolling Mean Loss = 0.0028 , Batch Accuracy = 86.0
# 	Batch  40, Loss = 0.0095 , Rolling Mean Loss = 0.0024 , Batch Accuracy = 86.0
# 	Batch  60, Loss = 0.001 , Rolling Mean Loss = 0.0019 , Batch Accuracy = 85.75
# 	Batch  80, Loss = 0.0002 , Rolling Mean Loss = 0.0014 , Batch Accuracy = 90.5
# 	Batch 100, Loss = 0.0004 , Rolling Mean Loss = 0.0011 , Batch Accuracy = 87.5
# 	Batch 120, Loss = 0.0002 , Rolling Mean Loss = 0.0014 , Batch Accuracy = 85.5
# 	Batch 140, Loss = 0.0003 , Rolling Mean Loss = 0.0016 , Batch Accuracy = 88.75
# 	Batch 160, Loss = 0.0003 , Rolling Mean Loss = 0.0016 , Batch Accuracy = 85.25
# 	Batch 180, Loss = 0.0003 , Rolling Mean Loss = 0.0018 , Batch Accuracy = 86.0
# 	Batch 200, Loss = 0.007 , Rolling Mean Loss = 0.0019 , Batch Accuracy = 84.0
# 	Batch 220, Loss = 0.0004 , Rolling Mean Loss = 0.0015 , Batch Accuracy = 87.25
# 	Train Accuracy (mean) =  86.23
# 	Test Accuracy         =  40.7
# Epoch 99
# 	Batch   0, Loss = 0.0002 , Rolling Mean Loss = 0.0019 , Batch Accuracy = 86.25
# 	Batch  20, Loss = 0.0001 , Rolling Mean Loss = 0.0016 , Batch Accuracy = 85.25
# 	Batch  40, Loss = 0.0003 , Rolling Mean Loss = 0.002 , Batch Accuracy = 82.0
# 	Batch  60, Loss = 0.0007 , Rolling Mean Loss = 0.0019 , Batch Accuracy = 88.75
# 	Batch  80, Loss = 0.0015 , Rolling Mean Loss = 0.0021 , Batch Accuracy = 84.5
# 	Batch 100, Loss = 0.0002 , Rolling Mean Loss = 0.0016 , Batch Accuracy = 89.25
# 	Batch 120, Loss = 0.0045 , Rolling Mean Loss = 0.0018 , Batch Accuracy = 88.25
# 	Batch 140, Loss = 0.0006 , Rolling Mean Loss = 0.0014 , Batch Accuracy = 87.0
# 	Batch 160, Loss = 0.0005 , Rolling Mean Loss = 0.0013 , Batch Accuracy = 84.0
# 	Batch 180, Loss = 0.0002 , Rolling Mean Loss = 0.0011 , Batch Accuracy = 84.5
# 	Batch 200, Loss = 0.0011 , Rolling Mean Loss = 0.0013 , Batch Accuracy = 87.75
# 	Batch 220, Loss = 0.0003 , Rolling Mean Loss = 0.0018 , Batch Accuracy = 85.25
# 	Train Accuracy (mean) =  86.23
# 	Test Accuracy         =  40.5
#
# Final Loss = 0.0009
# Final Rolling Loss = 0.0022
#
# Final Test Accuracy  = 40.50%
# Final Train Accuracy = 86.24%
#
# Running Time = 43 min, 20 sec.

# %%
import pandas as pd

df = pd.DataFrame(L)
Lmean = df.rolling(100).mean().values

plt.figure(figsize=(15,7.5))
plt.title('Model Loss During Training')
plt.scatter(range(len(L)),L,5,alpha=.5,color='C1',label='Loss')
plt.scatter(range(len(Lmean)),Lmean,1,color='C0',label='Loss (100 Iteration Rolling Mean)')
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.ylim([-0.1,5])
plt.legend()
#plt.show()
plt.savefig('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/VGG_ReLU_hidden0_noActivationEmbeddig_Loss.png')

# %%
plt.figure(figsize=(15,7.5))
plt.title('Model Loss During Training')
plt.plot(range(len(L[::228])),L[::228],color='C0',label='Traing Loss')
plt.plot(range(len(test_epoch_loss)),test_epoch_loss,color='C1',label='Test Loss')
plt.ylabel('Loss')
plt.xlabel('Iteration')
#plt.ylim([0,5])
plt.legend()
#plt.show()

print(final_train_loss)
print(final_test_loss)

plt.savefig('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/VGG_ReLU_hidden0_noActivationEmbeddig_Losses.png')
# Out:
# 0.0010652557310159114
# 6.5150346755981445

# %%
plt.figure(figsize=(15,7.5))
plt.title('Model Accuracy During Training')
plt.plot([tmea*100 for tmea in train_mean_epoch_accuracy],label='Train Mean Epoch Accuracy')
plt.plot([tea*100 for tea in test_epoch_accuracy],label='Test Epoch Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/VGG_ReLU_hidden0_noActivationEmbeddig_Accuracy.png')

# %%
max([tea*100 for tea in test_epoch_accuracy])
# Out:
# 41.9

# %%
import pickle

LA = test_epoch_loss

file_name = 'VGG_ReLU_hidden0_noActivationEmbeddig'
variables_list = [L,LA,
                  train_mean_epoch_accuracy,test_epoch_accuracy,
                  final_train_accuracy,final_test_accuracy,
                  word2idx]

with open('/content/gdrive/My Drive/aidl/VQA2015_PreProcessed_Images/' + file_name + '.pkl','wb') as file:
  pickle.dump(variables_list,file)
